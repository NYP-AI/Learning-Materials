# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.drop(columns=['PassengerId', 'Name', 'Ticket'], inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
# Counting out how many missing values per column
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# Imputation: Fill in missing values

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
#fillna.(x) means fill all missing values with the value x
 
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
df['Embarked'] = df['Embarked'].fillna('S')

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
#One hot encode the Embarked column
df = pd.get_dummies(df, columns=['Sex','Embarked'])

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  ...  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         0       3  22.0      1  ...         1           0           0           1
# 1         1       1  38.0      1  ...         0           1           0           0
# 2         1       3  26.0      0  ...         0           0           0           1
# 3         1       1  35.0      1  ...         0           0           0           1
# 4         0       3  35.0      0  ...         1           0           0           1
#
# [5 rows x 11 columns]

# %%
dfc = df.copy()

# %%
ycopy = df['Survived']
xcopy = df.values

# %%
y = df.pop('Survived').values
x = df.values

# %%
from sklearn.linear_model import LogisticRegression

# %%
model
# Out:
# LogisticRegression(C=20, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model = LogisticRegression(C=20)
model.fit(x,y)
sc = model.score(x,y)
print(sc)
# Out:
# 0.8013468013468014
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
dft = pd.read_csv('test.csv')

# %%
dft.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
dft.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'],inplace=True)

dft = dft.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])

# %%
dft.isna().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
dft['Age'] = dft['Age'].fillna(dft['Age'].mean())
dft['Fare'] = dft['Fare'].fillna(dft['Fare'].mean())

# %%
dft.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
dft.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  34.5      0      0   7.8292        Q
# 1       3  female  47.0      1      0   7.0000        S
# 2       2    male  62.0      0      0   9.6875        Q
# 3       3    male  27.0      0      0   8.6625        S
# 4       3  female  22.0      1      1  12.2875        S

# %%
dft = pd.get_dummies(dft, columns=['Sex', 'Embarked'])

# %%
dft.head()
# Out:
#    Pclass   Age  SibSp  Parch  ...  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0       3  34.5      0      0  ...         1           0           1           0
# 1       3  47.0      1      0  ...         0           0           0           1
# 2       2  62.0      0      0  ...         1           0           1           0
# 3       3  27.0      0      0  ...         1           0           0           1
# 4       3  22.0      1      1  ...         0           0           0           1
#
# [5 rows x 10 columns]

# %%
xt = dft.values

# %%
preds = model.predict(xt)

# %%
pd.DataFrame(preds, columns=['Survived']).to_csv('final.csv')

# %%
df2 = pd.read_csv('test.csv')

# %%
df2.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
pid = df2['PassengerId'].values

# %%
pd.DataFrame(preds, columns=['Survived'])
# Out:
#      Survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 1 columns]

# %%
#Column name should follow the gender_submission column name
df3 = pd.DataFrame(preds, columns=['Survived'], index=pid)
df3.head()
# Out:
#      Survived
# 892         0
# 893         0
# 894         0
# 895         0
# 896         1

# %%
#Naming the index column (This should follow the gender_submission column name)
df3.index.name = 'PassengerId'

# %%
df3.head()
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 1

# %%
df3.to_csv('updated.csv')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = 0

# %%
model = RandomForestClassifier(n_estimators=5000)
model.fit(x,y)
model.score(x,y)
# Out:
# 0.9820426487093153
