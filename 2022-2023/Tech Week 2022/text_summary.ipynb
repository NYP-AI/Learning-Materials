# %% [markdown]
# # **SUMMER CAMP 2022**
# ## DAY 4: TEXT SUMMARIZATION

# %% [markdown]
# ## What we are going to do in this project
#
# - Data collection
# - Text cleaning
#
# - Extractive text summary
#   - Sentence Tokenization
#   - Word frequency table
#   - Clustering
#   - Summarization
#
#
# - Abstractive text summary
#   - Introduction to Hugging face transformers library

# %% [markdown]
# ## Learning points
# - learning how to scrape data from the web using requests and beautiful soup
# - preprocessing text data
# - using models from the HF transformers library

# %% [markdown]
# ### Step 0: Import and configure modules

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Step 1: Gather text data through web scraping

# %%
# enter the URL of the article you want to summarize
url = "https://en.wikipedia.org/wiki/Amazon_(company)"
# send a request to the URL and save the response as a variable
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
# get the html content of the page
r.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Amazon (company) - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"04612bff-af4c-4259-874a-6cbbfa6b4e11","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Amazon_(company)","wgTitle":"Amazon (company)","wgCurRevisionId":1115387317,"wgRevisionId":1115387317,"wgArticleId":90451,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: bot: original URL status unknown","CS1 maint: url-status","Webarchive template wayback links","CS1 French-language sources (fr)","Articles with short description","Short description matches Wikidata","Wikipedia indefinitely semi-protected pages",\n"Use American English from June 2018","All Wikipedia articles written in American English","Use mdy dates from June 2021","Articles containing potentially dated statements from October 2017","All articles containing potentially dated statements","Articles containing potentially dated statements from June 2022","Articles containing potentially dated statements from 2018","Articles containing potentially dated statements from 2015","Articles containing potentially dated statements from September 2013","Commons category link from Wikidata","OpenCorporates groupings","Articles with ISNI identifiers","Articles with VIAF identifiers","Articles with WORLDCATID identifiers","Articles with BNF identifiers","Articles with GND identifiers","Articles with J9U identifiers","Articles with LCCN identifiers","Articles with NDL identifiers","Articles with NKC identifiers","Articles with MusicBrainz label identifiers","Articles with SUDOC identifiers","Companies in the Nasdaq-100",\n"Companies listed on the Nasdaq","Amazon (company)","1994 establishments in Washington (state)","1997 initial public offerings","3D publishing","American companies established in 1994","Android (operating system) software","Arts and crafts retailers","Bookstores of the United States","Cloud computing providers","Ebook suppliers","Internet properties established in 1994","IOS software","Logistics companies of the United States","Mobile phone manufacturers","Multinational companies headquartered in the United States","Online music stores of the United States","Online retailers of the United States","Retail companies established in 1994","Self-publishing companies","Software companies based in Seattle","Software companies established in 1994","Software companies of the United States","Technology companies established in 1994","Transportation companies based in Washington (state)","TvOS software","Universal Windows Platform apps","Webby Award winners"],"wgPageContentLanguage":"en",\n"wgPageContentModel":"wikitext","wgRelevantPageName":"Amazon_(company)","wgRelevantArticleId":90451,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":100000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q3884","GE ...

# %%
# find all the paragraph tags <p> in the page
soup = BeautifulSoup(r.text)
results = soup.find_all("p")

results
# Out:
# [<p class="mw-empty-elt">
#  </p>,
#  <p><b>Amazon.com, Inc.</b><sup class="reference" id="cite_ref-10K_1-1"><a href="#cite_note-10K-1">[1]</a></sup> (<span class="rt-commentedText nowrap"><span class="IPA nopopups noexcerpt" lang="en-fonipa"><a href="/wiki/Help:IPA/English" title="Help:IPA/English">/<span style="border-bottom:1px dotted"><span title="/ˈ/: primary stress follows">ˈ</span><span title="/æ/: 'a' in 'bad'">æ</span><span title="'m' in 'my'">m</span><span title="/ə/: 'a' in 'about'">ə</span><span title="'z' in 'zoom'">z</span><span title="/ɒ/: 'o' in 'body'">ɒ</span><span title="'n' in 'nigh'">n</span></span>/</a></span></span> <a href="/wiki/Help:Pronunciation_respelling_key" title="Help:Pronunciation respelling key"><i title="English pronunciation respelling"><span style="font-size:90%">AM</span>-ə-zon</i></a>) is an American <a href="/wiki/Multinational_corporation" title="Multinational corporation">multinational</a> <a href="/wiki/Technology_company" title="Technology company">technology company</a> that focuses on <a href="/wiki/E-commerce" title="E-commerce">e-commerce</a>, <a href="/wiki/Cloud_computing" title="Cloud computing">cloud computing</a>, <a href="/wiki/Online_advertising" title="Online advertising">online advertising</a>, <a class="mw-redirect" href="/wiki/Digital_streaming" title="Digital streaming">digital streaming</a>, and <a href="/wiki/Artificial_intelligence" title="Artificial intelligence">artificial intelligence</a>. It has been referred to as "one of the most influential economic and cultural forces in the world",<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup> and is one of the <a href="/wiki/List_of_most_valuable_brands" title="List of most valuable brands">world's most valuable brands</a>.<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup> It is one of the <a href="/wiki/Big_Tech" title="Big Tech">Big Five</a> American <a href="/wiki/Information_technology" title="Information technology">information technology</a> companies, alongside <a href="/wiki/Alphabet_Inc." title="Alphabet Inc.">Alphabet</a>, <a href="/wiki/Apple_Inc." title="Apple Inc.">Apple</a>, <a href="/wiki/Meta_Platforms" title="Meta Platforms">Meta</a>, and <a href="/wiki/Microsoft" title="Microsoft">Microsoft</a>.
#  </p>,
#  <p>Amazon was founded by <a href="/wiki/Jeff_Bezos" title="Jeff Bezos">Jeff Bezos</a> from his garage in <a href="/wiki/Bellevue,_Washington" title="Bellevue, Washington">Bellevue</a>, Washington,<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup> on July 5, 1994. Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker <i>The Everything Store</i>.<sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup> It has multiple <a href="/wiki/Subsidiary" title="Subsidiary">subsidiaries</a> including <a class="mw-redirect" href="/wiki/AWS" title="AWS">Amazon Web Services</a> (cloud computing), <a href="/wiki/Zoox_(company)" title="Zoox (company)">Zoox</a> (<a href="/wiki/Self-driving_car" title="Self-driving car">autonomous vehicles</a>), <a href="/wiki/Kuiper_Systems" title="Kuiper Systems">Kuiper Systems</a> (satellite Internet), and <a href="/wiki/Amazon_Lab126" title="Amazon Lab126">Amazon Lab126</a> (computer hardware <a href="/wiki/Research_and_development" title="Research and development">R&amp;D</a>). Its other subsidiaries include <a href="/wiki/Ring_(company)" title="Ring (company)">Ring</a>, <a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a>, <a href="/wiki/IMDb" title="IMDb">IMDb</a>, and <a href="/wiki/Whole_Foods_Market" title="Whole Foods Market">Whole Foods Market</a>. Its acquisition of Whole Foods in August 2017 for <span style="white-space: nowrap">US$</span>13.4 billion substantially increased its footprint as a <a class="mw-redirect" href="/wiki/Physical_retailer" title="Physical retailer">physical retailer</a>.<sup class="reference" id="cite_ref-wf_9-0"><a href="#cite_note-wf-9">[9]</a></sup>
#  </p>,
#  <p>Amazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup><sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup><sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup> As of 2021, it is the world's largest <a href="/wiki/Online_shopping" title="Online shopping">online retailer</a> and <a href="/wiki/Online_marketplace" title="Online marketplace">marketplace</a>, <a href="/wiki/Smart_speaker" title="Smart speaker">smart speaker</a> provider, <a href="/wiki/Cloud_computing" title="Cloud computing">cloud computing</a> service through AWS,<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup> <a class="mw-redirect" href="/wiki/Live_streaming" title="Live streaming">live-streaming</a> service through Twitch, and <a class="mw-redirect" href="/wiki/Largest_Internet_company_by_revenue" title="Largest Internet company by revenue">Internet company</a> as measured by <a href="/wiki/Revenue" title="Revenue">revenue</a> and <a href="/wiki/Market_share" title="Market share">market share</a>.<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> In 2021, it surpassed <a href="/wiki/Walmart" title="Walmart">Walmart</a> as the world's largest retailer outside of <a href="/wiki/China" title="China">China</a>, driven in large part by its paid subscription plan, <a href="/wiki/Amazon_Prime" title="Amazon Prime">Amazon Prime</a>, which has over 200 million subscribers worldwide.<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup><sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup> It is the <a class="mw-redirect" href="/wiki/List_of_largest_employers_in_the_United_States" title="List of largest employers in the United States">second-largest private employer in the United States</a>.<sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup>
#  </p>,
#  <p>Amazon also distributes a variety of downloadable and streaming content through its <a href="/wiki/Amazon_Prime_Video" title="Amazon Prime Video">Amazon Prime Video</a>, <a href="/wiki/Amazon_Music" title="Amazon Music">Amazon Music</a>, <a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a>, and <a class="mw-redirect" href="/wiki/Audible_(store)" title="Audible (store)">Audible</a> units. It publishes books through its publishing arm, <a href="/wiki/Amazon_Publishing" title="Amazon Publishing">Amazon Publishing</a>, film and television content through <a href="/wiki/Amazon_Studios" title="Amazon Studios">Amazon Studios</a>, and has been the owner of film and television studio <a href="/wiki/Metro-Goldwyn-Mayer" title="Metro-Goldwyn-Mayer">Metro-Goldwyn-Mayer</a> since March 2022. It also produces <a href="/wiki/Consumer_electronics" title="Consumer electronics">consumer electronics</a>—most notably, <a href="/wiki/Amazon_Kindle" title="Amazon Kindle">Kindle</a> <a href="/wiki/E-reader" title="E-reader">e-readers</a>, <a href="/wiki/Amazon_Echo" title="Amazon Echo">Echo</a> devices, <a class="mw-redirect" href="/wiki/Kindle_Fire" title="Kindle Fire">Fire</a> <a href="/wiki/Tablet_computer" title="Tablet computer">tablets</a>, and <a class="mw-redirect" href="/wiki/Fire_TV" title="Fire TV">Fire TVs</a>.
#  </p>,
#  <p>Amazon <a href="/wiki/Criticism_of_Amazon" title="Criticism of Amazon">has been criticized</a> for customer data collection practices,<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup> a toxic work culture,<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup> <a href="/wiki/Tax_avoidance" title="Tax avoidance">tax avoidance</a>,<sup class="reference" id="cite_ref-fortune_21-0"><a href="#cite_note-fortune-21">[21]</a></sup><sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup> and <a href="/wiki/Anti-competitive_practices" title="Anti-competitive practices">anti-competitive</a> behavior.<sup class="reference" id="cite_ref-:6_23-0"><a href="#cite_note-:6-23">[23]</a></sup><sup class="reference" id="cite_ref-baum_24-0"><a href="#cite_note-baum-24">[24]</a></sup>
#  </p>,
#  <p>Amazon was founded in July 1994 by <a href="/wiki/Jeff_Bezos" title="Jeff Bezos">Jeff Bezos</a>, who chose the <a href="/wiki/Seattle" title="Seattle">Seattle</a> area for its abundance of technical talent, as <a href="/wiki/Microsoft" title="Microsoft">Microsoft</a> was in the area.<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[25]</a></sup>
#  </p>,
#  <p>Amazon went <a href="/wiki/Public_company" title="Public company">public</a> in May 1997. It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany. The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[26]</a></sup><sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[27]</a></sup>
#  </p>,
#  <p>In 2002, it launched <a href="/wiki/Amazon_Web_Services" title="Amazon Web Services">Amazon Web Services</a> (AWS), which initially focused on providing APIs for web developers to build <a href="/wiki/Web_application" title="Web application">web applications</a> on top of Amazon's ecommerce platform.<sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[28]</a></sup><sup class="reference" id="cite_ref-29"><a href="#cite_note-29">[29]</a></sup> In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service.<sup class="reference" id="cite_ref-30"><a href="#cite_note-30">[30]</a></sup> AWS later shifted toward providing enterprise services with <a class="mw-redirect" href="/wiki/Simple_Storage_Service" title="Simple Storage Service">Simple Storage Service</a> (S3) in 2006,<sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup> and <a href="/wiki/Amazon_Elastic_Compute_Cloud" title="Amazon Elastic Compute Cloud">Elastic Compute Cloud</a> (EC2) in 2008,<sup class="reference" id="cite_ref-32"><a href="#cite_note-32">[32]</a></sup> allowing companies to rent data storage and computing power from Amazon. In 2006, Amazon also launched the<i> Fulfillment by Amazon </i>program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon's warehouses and fulfillment infrastructure.<sup class="reference" id="cite_ref-33"><a href="#cite_note-33">[33]</a></sup>
#  </p>,
#  <p>Amazon purchased the <a href="/wiki/Whole_Foods_Market" title="Whole Foods Market">Whole Foods Market</a> supermarket chain in 2017.<sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup>
#  </p>,
#  <p>During the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020. The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022.<sup class="reference" id="cite_ref-35"><a href="#cite_note-35">[35]</a></sup><sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[36]</a></sup> Amazon also introduced temporary restrictions on the sale of non-essential goods, and hired 100,000 more staff in the US and Canada.<sup class="reference" id="cite_ref-37"><a href="#cite_note-37">[37]</a></sup> Some Amazon workers in the US, France, and Italy protested the company's decision to "run normal shifts" despite many positive COVID-19 cases.<sup class="reference" id="cite_ref-auto_38-0"><a href="#cite_note-auto-38">[38]</a></sup><sup class="reference" id="cite_ref-FTMarch19_39-0"><a href="#cite_note-FTMarch19-39">[39]</a></sup> In Spain, the company has faced legal complaints over its policies.<sup class="reference" id="cite_ref-BBCMarch31_40-0"><a href="#cite_note-BBCMarch31-40">[40]</a></sup> A group of US Senators wrote an open letter to Bezos in March 2020, expressing concerns about worker safety.<sup class="reference" id="cite_ref-TheVergeMarch31_41-0"><a href="#cite_note-TheVergeMarch31-41">[41]</a></sup>
#  </p>,
#  <p>On February 2, 2021, Amazon announced that Jeff Bezos would step down as CEO to become executive chair of Amazon's board in Q3 of 2021. Andy Jassy, previously CEO of AWS, became Amazon's CEO.<sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[42]</a></sup><sup class="reference" id="cite_ref-43"><a href="#cite_note-43">[43]</a></sup>
#  </p>,
#  <p>Amazon.com is an ecommerce platform that sells many product lines, include media (<a href="/wiki/Book" title="Book">books</a>, movies, music, and software), apparel, baby products, <a href="/wiki/Consumer_electronics" title="Consumer electronics">consumer electronics</a>, <a href="/wiki/Cosmetics" title="Cosmetics">beauty products</a>, gourmet food, groceries, health and personal care products, industrial &amp; scientific supplies, kitchen items, <a class="mw-redirect" href="/wiki/Jewelry" title="Jewelry">jewelry</a>, watches, lawn and garden items, musical instruments, <a href="/wiki/Sports_equipment" title="Sports equipment">sporting goods</a>, tools, automotive items, toys and games, and farm <a href="/wiki/Agrochemical" title="Agrochemical">supplies</a><sup class="reference" id="cite_ref-45"><a href="#cite_note-45">[45]</a></sup> and <a href="/wiki/Agronomy" title="Agronomy">consulting services</a>.<sup class="reference" id="cite_ref-Rai_46-0"><a href="#cite_note-Rai-46">[46]</a></sup> Amazon websites are country-specific (for example, amazon.com for the U.S. and amazon.fr for France), though some offer international shipping.<sup class="reference" id="cite_ref-47"><a href="#cite_note-47">[47]</a></sup>
#  </p>,
#  <p>Visits to <i>amazon.com</i> grew from 615 million annual visitors in 2008,<sup class="reference" id="cite_ref-48"><a href="#cite_note-48">[48]</a></sup> to more than 2 billion per month in 2022.<sup class="reference" id="cite_ref-49"><a href="#cite_note-49">[49]</a></sup> The company has invested heavily in server capacity and redundancy to handle increased traffic during the <a class="mw-redirect" href="/wiki/Christmas_holiday_season" title="Christmas holiday season">Christmas holiday season</a>.<sup class="reference" id="cite_ref-50"><a href="#cite_note-50">[50]</a></sup> The ecommerce platform is the 14th most visited website in the world.<sup class="reference" id="cite_ref-51"><a href="#cite_note-51">[51]</a></sup>
#  </p>,
#  <p>In 2000, U.S. toy retailer <a href="/wiki/Toys_%22R%22_Us" title='Toys "R" Us'>Toys "R" Us</a> entered into a 10-year agreement with Amazon, valued at $50 million per year plus a cut of sales, under which Toys "R" Us would be the exclusive supplier of toys and baby products on the service, and the chain's website would redirect to Amazon's Toys &amp; Games category. In 2004, Toys "R" Us sued Amazon, claiming that because of a perceived lack of variety in Toys "R" Us stock, Amazon had knowingly allowed third-party sellers to offer items on the service in categories that Toys "R" Us had been granted exclusivity. In 2006, a court ruled in favor of Toys "R" Us, giving it the right to unwind its agreement with Amazon and establish its independent e-commerce website. The company was later awarded $51 million in damages.<sup class="reference" id="cite_ref-52"><a href="#cite_note-52">[52]</a></sup><sup class="reference" id="cite_ref-53"><a href="#cite_note-53">[53]</a></sup><sup class="reference" id="cite_ref-54"><a href="#cite_note-54">[54]</a></sup>
#  </p>,
#  <p>In 2001, Amazon entered into a similar agreement with <a href="/wiki/Borders_Group" title="Borders Group">Borders Group</a>, under which Amazon would comanage Borders.com as a co-branded service.<sup class="reference" id="cite_ref-55"><a href="#cite_note-55">[55]</a></sup> Borders pulled out of the arrangement in 2007, with plans to also launch its own online store.<sup class="reference" id="cite_ref-56"><a href="#cite_note-56">[56]</a></sup>
#  </p>,
#  <p>On October 18, 2011, Amazon.com announced a partnership with <a href="/wiki/DC_Comics" title="DC Comics">DC Comics</a> for the exclusive digital rights to many popular comics, including <i><a href="/wiki/Superman" title="Superman">Superman</a></i>, <i><a href="/wiki/Batman" title="Batman">Batman</a></i>, <i><a href="/wiki/Green_Lantern" title="Green Lantern">Green Lantern</a></i>, <i><a class="mw-redirect" href="/wiki/The_Sandman_(Vertigo)" title="The Sandman (Vertigo)">The Sandman</a>,</i> and <i><a href="/wiki/Watchmen" title="Watchmen">Watchmen</a></i>. The partnership has caused well-known bookstores like Barnes &amp; Noble to remove these titles from their shelves.<sup class="reference" id="cite_ref-57"><a href="#cite_note-57">[57]</a></sup>
#  </p>,
#  <p>In November 2013, Amazon announced a partnership with the <a href="/wiki/United_States_Postal_Service" title="United States Postal Service">United States Postal Service</a> to begin delivering orders on Sundays. The service, included in Amazon's standard shipping rates, initiated in metropolitan areas of <a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a> and <a class="mw-redirect" href="/wiki/New_York,_New_York" title="New York, New York">New York</a> because of the high-volume and inability to deliver in a timely way, with plans to expand into <a class="mw-redirect" href="/wiki/Dallas,_Texas" title="Dallas, Texas">Dallas</a>, <a href="/wiki/Houston" title="Houston">Houston</a>, <a href="/wiki/New_Orleans" title="New Orleans">New Orleans</a> and <a href="/wiki/Phoenix,_Arizona" title="Phoenix, Arizona">Phoenix</a> by 2014.<sup class="reference" id="cite_ref-58"><a href="#cite_note-58">[58]</a></sup>
#  </p>,
#  <p>In June 2017, <a href="/wiki/Nike,_Inc." title="Nike, Inc.">Nike</a> agreed to sell products through Amazon in exchange for better policing of counterfeit goods.<sup class="reference" id="cite_ref-59"><a href="#cite_note-59">[59]</a></sup><sup class="reference" id="cite_ref-CNBC_60-0"><a href="#cite_note-CNBC-60">[60]</a></sup> This proved unsuccessful and Nike withdrew from the partnership in November 2019.<sup class="reference" id="cite_ref-CNBC_60-1"><a href="#cite_note-CNBC-60">[60]</a></sup><sup class="reference" id="cite_ref-61"><a href="#cite_note-61">[61]</a></sup> Companies including <a href="/wiki/IKEA" title="IKEA">IKEA</a> and <a href="/wiki/Birkenstock" title="Birkenstock">Birkenstock</a> also stopped selling through Amazon around the same time, citing similar frustrations over business practices and counterfeit goods.<sup class="reference" id="cite_ref-62"><a href="#cite_note-62">[62]</a></sup>
#  </p>,
#  <p>In September 2017, Amazon ventured with one of its sellers JV Appario Retail owned by Patni Group which has recorded a total income of US$ 104.44 million (<a href="/wiki/Indian_rupee" title="Indian rupee">₹</a> 759 <a href="/wiki/Crore" title="Crore">crore</a>) in financial year 2017–2018.<sup class="reference" id="cite_ref-63"><a href="#cite_note-63">[63]</a></sup>
#  </p>,
#  <p>As of October 11, 2017<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Amazon_(company)&amp;action=edit">[update]</a></sup>, <a class="mw-redirect" href="/wiki/AmazonFresh" title="AmazonFresh">AmazonFresh</a> sold a range of <a class="mw-redirect" href="/wiki/Booths_Supermarkets" title="Booths Supermarkets">Booths</a> branded products for home delivery in selected areas.<sup class="reference" id="cite_ref-64"><a href="#cite_note-64">[64]</a></sup>
#  </p>,
#  <p>In November 2018, Amazon reached an agreement with <a href="/wiki/Apple_Inc." title="Apple Inc.">Apple Inc.</a> to sell selected products through the service, via the company and selected Apple Authorized Resellers. As a result of this partnership, only Apple Authorized Resellers may sell Apple products on Amazon effective January 4, 2019.<sup class="reference" id="cite_ref-65"><a href="#cite_note-65">[65]</a></sup><sup class="reference" id="cite_ref-66"><a href="#cite_note-66">[66]</a></sup>
#  </p>,
#  <p>Amazon sells many products <a href="/wiki/Private_label" title="Private label">under its own brand names</a>, including phone chargers, batteries, an diaper wipes. The <a class="mw-redirect" href="/wiki/AmazonBasics" title="AmazonBasics">AmazonBasics</a> brand was introduced in 2009, and now features hundreds of product lines, including smartphone cases, computer mice, batteries, dumbbells, and dog crates. Amazon owned 34 private-label brands as of 2019. These brands account for 0.15% of Amazon's global sales, whereas the average for other large retailers is 18%.<sup class="reference" id="cite_ref-67"><a href="#cite_note-67">[67]</a></sup> Other Amazon retail brands include <a href="/wiki/List_of_Amazon_brands#Presto!" title="List of Amazon brands">Presto!</a>, <a href="/wiki/List_of_Amazon_brands#Mama_Bear" title="List of Amazon brands">Mama Bear</a>, and <a href="/wiki/List_of_Amazon_brands" title="List of Amazon brands">Amazon Essentials</a>.<sup class="reference" id="cite_ref-68"><a href="#cite_note-68">[68]</a></sup>
#  </p>,
#  <p>Amazon derives many of its sales (around 40% in 2008) from third-party sellers who sell products on Amazon.<sup class="reference" id="cite_ref-69"><a href="#cite_note-69">[69]</a></sup> Some other large e-commerce sellers use Amazon to sell their products in addition to selling them through their websites. The sales are processed through Amazon.com and end up at individual sellers for processing and order fulfillment and Amazon leases space for these retailers. Small sellers of used and new goods go to Amazon Marketplace to offer goods at a fixed price.<sup class="reference" id="cite_ref-70"><a href="#cite_note-70">[70]</a></sup>
#  </p>,
#  <p>Publishers can signup as affiliates and receive a commission for referring customers to Amazon by placing links to Amazon on their websites if the referral results in a sale. Worldwide, Amazon has "over 900,000 members" in its affiliate programs.<sup class="reference" id="cite_ref-71"><a href="#cite_note-71">[71]</a></sup> In the middle of 2014, the Amazon Affiliate Program is used by 1.2% of all websites and it is the second most popular advertising network after Google Ads.<sup class="reference" id="cite_ref-72"><a href="#cite_note-72">[72]</a></sup> It is frequently used by websites and non-profits to provide a way for supporters to earn them a commission.<sup class="reference" id="cite_ref-73"><a href="#cite_note-73">[73]</a></sup>
#  </p>,
#  <p>Associates can access the Amazon catalog directly on their websites by using the <a href="/wiki/Amazon_Web_Services" title="Amazon Web Services">Amazon Web Services</a> (AWS) <a href="/wiki/XML" title="XML">XML</a> service. A new affiliate product, aStore, allows Associates to embed a subset of Amazon products within another website, or linked to another website. In June 2010, Amazon Seller Product Suggestions was launched (rumored to be internally called "Project Genesis") to provide more transparency to sellers by recommending specific products to third-party sellers to sell on Amazon. Products suggested are based on customers' browsing history.<sup class="reference" id="cite_ref-74"><a href="#cite_note-74">[74]</a></sup> In 2019, Amazon launched a bigger local online store in <a href="/wiki/Singapore" title="Singapore">Singapore</a> to expand its product selection in the face of intensifying competition with competitors in the region.<sup class="reference" id="cite_ref-75"><a href="#cite_note-75">[75]</a></sup>
#  </p>,
#  <p>In July 2019, the 3rd U.S. City Court of Appeals in Philadelphia ruled that Amazon can be held accountable for faulty third-party sales.<sup class="reference" id="cite_ref-76"><a href="#cite_note-76">[76]</a></sup> The decision ran counter to a past lower court ruling that had favored Amazon. Heather Oberdorf had sued the company in 2016 over a dog leash that snapped, causing permanent loss of vision in one eye. If upheld, the decision would expose Amazon and similar platform businesses to strict liability lawsuits for defective products, which represents a major change in the law.<sup class="reference" id="cite_ref-77"><a href="#cite_note-77">[77]</a></sup> The panel sent the case back to the lower court, to decide whether the leash was defective.<sup class="reference" id="cite_ref-78"><a href="#cite_note-78">[78]</a></sup>
#  </p>,
#  <p>Amazon allows users to submit reviews to the web page of each product. Reviewers must rate the product on a <a href="/wiki/Rating_scale" title="Rating scale">rating scale</a> from one to five stars. Amazon provides a badging option for reviewers which indicates the real name of the reviewer (based on confirmation of a credit card account) or which indicates that the reviewer is one of the top reviewers by popularity. As of December 16, 2020, Amazon removed the ability of sellers and customers to comment on product reviews and purged their websites of all posted product review comments. In an email to sellers Amazon gave its rationale for removing this feature: "... <i>the comments feature on customer reviews was rarely used</i>." The remaining review response options are to indicate whether the reader finds the review helpful or to report that it violates Amazon policies (abuse). If a review is given enough "helpful" hits, it appears on the front page of the product. In 2010, Amazon was reported as being the largest single source of Internet consumer reviews.<sup class="reference" id="cite_ref-79"><a href="#cite_note-79">[79]</a></sup>
#  </p>,
#  <p>When publishers asked Bezos why Amazon would publish negative reviews, he defended the practice by claiming that Amazon.com was "taking a different approach ... we want to make every book available—the good, the bad and the ugly ... to let truth loose".<sup class="reference" id="cite_ref-80"><a href="#cite_note-80">[80]</a></sup>
#  </p>,
#  <p>There have been cases of positive reviews being written and posted by <a href="/wiki/Public_relations" title="Public relations">public relations</a> companies on behalf of their clients<sup class="reference" id="cite_ref-81"><a href="#cite_note-81">[81]</a></sup> and instances of writers using pseudonyms to leave negative reviews of their rivals' works
#  </p>,
#  <p>The Amazon sales rank (ASR) indicates the popularity of a product sold on any Amazon locale. It is a relative indicator of popularity that is updated hourly. Effectively, it is a "best sellers list" for the millions of products stocked by Amazon.<sup class="reference" id="cite_ref-amazon_82-0"><a href="#cite_note-amazon-82">[82]</a></sup> While the ASR has no direct effect on the sales of a product, it is used by Amazon to determine which products to include in its bestsellers lists.<sup class="reference" id="cite_ref-amazon_82-1"><a href="#cite_note-amazon-82">[82]</a></sup> Products that appear in these lists enjoy additional exposure on the Amazon website and this may lead to an increase in sales. In particular, products that experience large jumps (up or down) in their sales ranks may be included within Amazon's lists of "movers and shakers"; such a listing provides additional exposure that might lead to an increase in sales.<sup class="reference" id="cite_ref-83"><a href="#cite_note-83">[83]</a></sup> For competitive reasons, Amazon does not release actual sales figures to the public. However, Amazon has now begun to release <a href="/wiki/Point_of_sale" title="Point of sale">point of sale</a> data via the <a class="mw-redirect" href="/wiki/Nielsen_BookScan" title="Nielsen BookScan">Nielsen BookScan</a> service to verified authors.<sup class="reference" id="cite_ref-84"><a href="#cite_note-84">[84]</a></sup> While the ASR has been the source of much speculation by publishers, manufacturers, and marketers, Amazon itself does not release the details of its sales rank calculation algorithm. Some companies have analyzed Amazon sales data to generate sales estimates based on the ASR,<sup class="reference" id="cite_ref-85"><a href="#cite_note-85">[85]</a></sup> though Amazon states:
#  </p>,
#  <p>Please keep in mind that our sales rank figures are simply meant to be a guide of general interest for the customer and not definitive sales information for publishers—we assume you have this information regularly from your distribution sources</p>,
#  <p>"Search Inside the Book" is a feature which allows customers to search for keywords in the full text of many books in the catalog.<sup class="reference" id="cite_ref-87"><a href="#cite_note-87">[87]</a></sup><sup class="reference" id="cite_ref-88"><a href="#cite_note-88">[88]</a></sup> The feature started with 120,000 titles (or 33 million pages of text) on October 23, 2003.<sup class="reference" id="cite_ref-89"><a href="#cite_note-89">[89]</a></sup>
#  </p>,
#  <p>In November 2020, the company started an online delivery service dedicated to prescription drugs. The service provides discounts up to 80% for generic drugs and up to 40% for branded drugs for Prime subscribe users. The products can be purchased on the company's website or at over 50,000 bricks-and-mortar pharmacies in the United States.<sup class="reference" id="cite_ref-90"><a href="#cite_note-90">[90]</a></sup>
#  </p>,
#  <p>In November 2015, Amazon opened a physical Amazon Books store in <a href="/wiki/University_Village,_Seattle" title="University Village, Seattle">University Village</a> in Seattle. The store is 5,500 square feet and prices for all products match those on its website.<sup class="reference" id="cite_ref-:1_91-0"><a href="#cite_note-:1-91">[91]</a></sup> Amazon will open its tenth physical book store in 2017;<sup class="reference" id="cite_ref-92"><a href="#cite_note-92">[92]</a></sup> media speculation suggests Amazon plans to eventually roll out 300 to 400 bookstores around the country.<sup class="reference" id="cite_ref-:1_91-1"><a href="#cite_note-:1-91">[91]</a></sup>
#  </p>,
#  <p>In June 2018, it was reported that Amazon planned to open brick and mortar bookstores in Germany.<sup class="reference" id="cite_ref-93"><a href="#cite_note-93">[93]</a></sup>
#  </p>,
#  <p>In August 2019, Amazon applied to have a liquor store in <a href="/wiki/San_Francisco" title="San Francisco">San Francisco</a>, CA as a means to ship beer and alcohol within the city.<sup class="reference" id="cite_ref-94"><a href="#cite_note-94">[94]</a></sup>
#  </p>,
#  <p>In 2020, <a href="/wiki/Amazon_Fresh" title="Amazon Fresh">Amazon Fresh</a> opened several physical stores in the U.S. and the United Kingdom.<sup class="reference" id="cite_ref-95"><a href="#cite_note-95">[95]</a></sup>
#  </p>,
#  <p>In September 2020, Amazon launched Luxury Stores on its mobile app, where <a href="/wiki/Oscar_de_la_Renta" title="Oscar de la Renta">Oscar de la Renta</a> become the first and only label to partner with the firm.<sup class="reference" id="cite_ref-96"><a href="#cite_note-96">[96]</a></sup>
#  </p>,
#  <p>Amazon Web Services (AWS) is a subsidiary of that provides <a href="/wiki/Software_as_a_service" title="Software as a service">on-demand</a> <a href="/wiki/Cloud_computing" title="Cloud computing">cloud computing</a> <a href="/wiki/Computing_platform" title="Computing platform">platforms</a> and <a class="mw-redirect" href="/wiki/Application_programming_interface" title="Application programming interface">APIs</a> to individuals, companies, and governments, on a metered pay-as-you-go basis. These cloud computing <a class="mw-redirect" href="/wiki/Web_services" title="Web services">web services</a> provide <a href="/wiki/Distributed_computing" title="Distributed computing">distributed computing</a> processing capacity and software tools via AWS <a class="mw-redirect" href="/wiki/Server_farms" title="Server farms">server farms</a>. One of these services is <a href="/wiki/Amazon_Elastic_Compute_Cloud" title="Amazon Elastic Compute Cloud">Amazon Elastic Compute Cloud</a> (EC2), which allows users to have at their disposal a <a href="/wiki/Virtualization" title="Virtualization">virtual</a> <a href="/wiki/Computer_cluster" title="Computer cluster">cluster of computers</a>, available all the time, through the Internet. AWS's virtual computers emulate most of the attributes of a real computer, including hardware <a href="/wiki/Central_processing_unit" title="Central processing unit">central processing units</a> (CPUs) and <a href="/wiki/Graphics_processing_unit" title="Graphics processing unit">graphics processing units</a> (GPUs) for processing; local/<a href="/wiki/Random-access_memory" title="Random-access memory">RAM</a> memory; hard-disk/<a href="/wiki/Solid-state_drive" title="Solid-state drive">SSD storage</a>; a choice of operating systems; networking; and pre-loaded application software such as <a href="/wiki/Web_server" title="Web server">web servers</a>, <a href="/wiki/Database" title="Database">databases</a>, and <a href="/wiki/Customer_relationship_management" title="Customer relationship management">customer relationship management</a> (CRM).
#  </p>,
#  <p>AWS services are delivered to customers via a network of AWS server farms located throughout the world. Fees are based on a combination of usage (known as a "Pay-as-you-go" model), hardware, operating system, software, or networking features chosen by the subscriber required <a href="/wiki/Availability_(system)" title="Availability (system)">availability</a>, <a href="/wiki/Redundancy_(engineering)" title="Redundancy (engineering)">redundancy</a>, <a href="/wiki/Computer_security" title="Computer security">security</a>, and service options. Subscribers can pay for a single virtual AWS computer, a dedicated physical computer, or clusters of either.<sup class="reference" id="cite_ref-AWSagreement_97-0"><a href="#cite_note-AWSagreement-97">[97]</a></sup> Amazon provides select portions of security for subscribers (e.g. physical security of the data centers) while other aspects of security are the responsibility of the subscriber (e.g. account management, vulnerability scanning, patching). AWS operates from many global geographical regions including 6 in North America.<sup class="reference" id="cite_ref-GlobalInfrastructure_98-0"><a href="#cite_note-GlobalInfrastructure-98">[98]</a></sup>
#  </p>,
#  <p>Amazon markets AWS to subscribers as a way of obtaining large-scale computing capacity more quickly and cheaply than building an actual physical server farm.<sup class="reference" id="cite_ref-99"><a href="#cite_note-99">[99]</a></sup> All services are billed based on usage, but each service measures usage in varying ways. As of 2021 Q4, AWS has 33% market share for cloud infrastructure while the next two competitors <a href="/wiki/Microsoft_Azure" title="Microsoft Azure">Microsoft Azure</a> and <a href="/wiki/Google_Cloud_Platform" title="Google Cloud Platform">Google Cloud</a> have 21%, and 10% respectively, according to Synergy Group.<sup class="reference" id="cite_ref-100"><a href="#cite_note-100">[100]</a></sup><sup class="reference" id="cite_ref-101"><a href="#cite_note-101">[101]</a></sup>
#  </p>,
#  <p>Amazon has a number of products and services available, including its digital assistant <a href="/wiki/Amazon_Alexa" title="Amazon Alexa">Alexa</a>, <a href="/wiki/Amazon_Music" title="Amazon Music">Amazon Music</a> and <a href="/wiki/Amazon_Prime_Video" title="Amazon Prime Video">Prime Video</a> for music and videos respectively, the <a href="/wiki/Amazon_Appstore" title="Amazon Appstore">Amazon Appstore</a> for Android apps, and its <a href="/wiki/Amazon_Kindle" title="Amazon Kindle">Kindle</a> hardware line of e-readers and tablets. <a href="/wiki/Audible_(service)" title="Audible (service)">Audible</a> provides audiobooks for purchase and listening.
#  </p>,
#  <p>In September 2021, Amazon announced the launch of Astro, its first household robot, powered by its Alexa smart home technology. This can be remote-controlled when not at home, to check on pets, people, or home security. It will send owners a notification if it detects something unusual.<sup class="reference" id="cite_ref-102"><a href="#cite_note-102">[102]</a></sup>
#  </p>,
#  <p>Amazon uses many different transportation services to deliver packages. Amazon-branded services include:
#  </p>,
#  <p>Amazon directly employs people to work at its warehouses, bulk distribution centers, staffed "<a class="mw-redirect" href="/wiki/Amazon_Hub" title="Amazon Hub">Amazon Hub</a> Locker+" locations, and delivery stations where drivers pick up packages. As of December 2020, it is not hiring delivery drivers as employees.<sup class="reference" id="cite_ref-105"><a href="#cite_note-105">[105]</a></sup>
#  </p>,
#  <p>Rakuten Intelligence estimated that in 2020 in the United States, the proportion of last-mile deliveries was 56% by Amazon's directly contracted services (mostly in urban areas), 30% by the U.S. Postal Service (mostly in rural areas), and 14% by <a href="/wiki/United_Parcel_Service" title="United Parcel Service">UPS</a>.<sup class="reference" id="cite_ref-106"><a href="#cite_note-106">[106]</a></sup> In April 2021, Amazon reported to investors it had increased its in-house delivery capacity by 50% in the last 12 months (which included the first year of the <a href="/wiki/COVID-19_pandemic_in_the_United_States" title="COVID-19 pandemic in the United States">COVID-19 pandemic in the United States</a>).<sup class="reference" id="cite_ref-107"><a href="#cite_note-107">[107]</a></sup>
#  </p>,
#  <p>Amazon first launched its distribution network in 1997 with two fulfillment centers in Seattle and <a href="/wiki/New_Castle,_Delaware" title="New Castle, Delaware">New Castle</a>, Delaware. Amazon has several types of distribution facilities consisting of cross-dock centers, fulfillment centers, sortation centers, delivery stations, Prime now hubs, and Prime air hubs. There are 75 fulfillment centers and 25 sortation centers with over 125,000 employees.<sup class="reference" id="cite_ref-108"><a href="#cite_note-108">[108]</a></sup><sup class="reference" id="cite_ref-109"><a href="#cite_note-109">[109]</a></sup> Employees are responsible for five basic tasks: unpacking and inspecting incoming goods; placing goods in storage and recording their location; picking goods from their computer recorded locations to make up an individual shipment; sorting and packing orders; and shipping. A computer that records the location of goods and maps out routes for pickers plays a key role: employees carry hand-held computers which communicate with the central computer and monitor their rate of progress. Some warehouses are partially automated with systems built by <a href="/wiki/Amazon_Robotics" title="Amazon Robotics">Amazon Robotics</a>.
#  </p>,
#  <p>In September 2006, Amazon launched a program called FBA (Fulfillment By Amazon) whereby it could handle storage, packing and distribution of products and services for small sellers.<sup class="reference" id="cite_ref-110"><a href="#cite_note-110">[110]</a></sup>
#  </p>,
#  <p>Amazon.fr fulfillment center in <a href="/wiki/Lauwin-Planque" title="Lauwin-Planque">Lauwin-Planque</a>, France
#  </p>,
#  <p>Amazon.es fulfillment center in <a href="/wiki/San_Fernando_de_Henares" title="San Fernando de Henares">San Fernando de Henares</a>, Spain
#  </p>,
#  <p>Amazon.co.uk fulfillment center in <a href="/wiki/Glenrothes" title="Glenrothes">Glenrothes</a>, Scotland, UK
#  </p>,
#  <p>Amazon.de fulfillment center in <a href="/wiki/Graben,_Bavaria" title="Graben, Bavaria">Graben</a>, Germany
#  </p>,
#  <p>Amazon.co.jp fulfillment center in <a href="/wiki/Ichikawa,_Chiba" title="Ichikawa, Chiba">Ichikawa</a>, Japan
#  </p>,
#  <p>Amazon fulfillment center in <a href="/wiki/Macon,_Georgia" title="Macon, Georgia">Macon</a>, Georgia, U.S.
#  </p>,
#  <p>During his tenure, Jeff Bezos had become renowned for his annual shareholder letters, which have gained similar notability to those of <a href="/wiki/Warren_Buffett" title="Warren Buffett">Warren Buffett</a>.<sup class="reference" id="cite_ref-:7_111-0"><a href="#cite_note-:7-111">[111]</a></sup> These annual letters gave an "invaluable window" into the famously "secretive" company, and revealed Bezos's perspectives and strategic focus.<sup class="reference" id="cite_ref-:7_111-1"><a href="#cite_note-:7-111">[111]</a></sup><sup class="reference" id="cite_ref-112"><a href="#cite_note-112">[112]</a></sup> A common theme of these letters is Bezos's desire to instill customer-centricity (in his words, "customer obsession") at all levels of Amazon, notably by making all senior executives field customer support queries for a short time at Amazon call centers. He also read many emails addressed by customers to his public email address.<sup class="reference" id="cite_ref-113"><a href="#cite_note-113">[113]</a></sup> One of Bezos's most well-known internal memos was his mandate for "all teams" to "expose their data and functionality" through service interfaces "designed from the ground up to be externalizable". This process, commonly known as a <a href="/wiki/Service-oriented_architecture" title="Service-oriented architecture">service-oriented architecture</a> (SOA), resulted in mandatory <a class="mw-redirect" href="/wiki/Dogfooding" title="Dogfooding">dogfooding</a> of services that would later be commercialized as part of AWS.<sup class="reference" id="cite_ref-114"><a href="#cite_note-114">[114]</a></sup>
#  </p>,
#  <p>As of June 2022<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Amazon_(company)&amp;action=edit">[update]</a></sup>, Amazon's board of directors were:<sup class="reference" id="cite_ref-115"><a href="#cite_note-115">[115]</a></sup>
#  </p>,
#  <p>Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products.<sup class="reference" id="cite_ref-116"><a href="#cite_note-116">[116]</a></sup> As of 2018<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Amazon_(company)&amp;action=edit">[update]</a></sup>, Amazon.com is ranked 8th on the <a href="/wiki/Fortune_500" title="Fortune 500">Fortune 500</a> rankings of the largest United States corporations by total revenue.<sup class="reference" id="cite_ref-117"><a href="#cite_note-117">[117]</a></sup>
#  </p>,
#  <p>For the fiscal year 2021, Amazon reported earnings of US$33.36 billion, with an annual revenue of US$469.82 billion, an increase of 21.7% over the previous fiscal cycle. Since 2007 sales increased from 14.835 billion to 469.822 billion, due to continued business expansion.<sup class="reference" id="cite_ref-118"><a href="#cite_note-118">[118]</a></sup>
#  </p>,
#  <p>Amazon's market capitalization went over US$1 trillion again in early February 2020 after the announcement of the fourth quarter 2019 results.<sup class="reference" id="cite_ref-4Q_2020_119-0"><a href="#cite_note-4Q_2020-119">[119]</a></sup>
#  </p>,
#  <p>Amazon owns over 40 subsidiaries, including <a href="/wiki/Amazon_Web_Services" title="Amazon Web Services">Amazon Web Services</a>, <a class="mw-redirect" href="/wiki/Audible_(store)" title="Audible (store)">Audible</a>, Diapers.com, <a href="/wiki/Goodreads" title="Goodreads">Goodreads</a>, <a href="/wiki/IMDb" title="IMDb">IMDb</a>, Kiva Systems (now <a href="/wiki/Amazon_Robotics" title="Amazon Robotics">Amazon Robotics</a>), <a href="/wiki/Shopbop" title="Shopbop">Shopbop</a>, Teachstreet, <a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a>, <a href="/wiki/Zappos" title="Zappos">Zappos</a>, and <a href="/wiki/Zoox_(company)" title="Zoox (company)">Zoox</a>.<sup class="reference" id="cite_ref-137"><a href="#cite_note-137">[137]</a></sup>
#  </p>,
#  <p><a href="/wiki/Goodreads" title="Goodreads">Goodreads</a> is a "<a class="mw-redirect" href="/wiki/Social_cataloging" title="Social cataloging">social cataloging</a>" website founded in December 2006 and launched in January 2007 by Otis Chandler, a software engineer, and entrepreneur, and Elizabeth Khuri. The website allows individuals to freely search Goodreads' extensive user-populated database of books, annotations, and reviews. Users can sign up and register books to generate library catalogs and reading lists. They can also create their groups of book suggestions and discussions. In December 2007, the site had over 650,000 members, and over a million books had been added. Amazon bought the company in March 2013.<sup class="reference" id="cite_ref-:0_138-0"><a href="#cite_note-:0-138">[138]</a></sup>
#  </p>,
#  <p>Kuiper Systems LLC, is a subsidiary of Amazon, set up to deploy a <a href="/wiki/Broadband" title="Broadband">broadband</a> <a href="/wiki/Satellite_internet_constellation" title="Satellite internet constellation">satellite internet constellation</a> with an announced 3,236 <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">Low Earth orbit</a> <a href="/wiki/Satellite" title="Satellite">satellites</a> to provide satellite based Internet connectivity.<sup class="reference" id="cite_ref-cnbc20190404_139-0"><a href="#cite_note-cnbc20190404-139">[139]</a></sup><sup class="reference" id="cite_ref-sn20190404_140-0"><a href="#cite_note-sn20190404-140">[140]</a></sup><sup class="reference" id="cite_ref-ars20190708_141-0"><a href="#cite_note-ars20190708-141">[141]</a></sup>
#  </p>,
#  <p>Ring is a <a href="/wiki/Home_automation" title="Home automation">home automation</a> company founded by Jamie Siminoff in 2013. It is primarily known for its WiFi powered <a href="/wiki/Smart_doorbell" title="Smart doorbell">smart doorbells</a>, but manufactures other devices such as security cameras. Amazon bought Ring for US$1 billion in 2018.<sup class="reference" id="cite_ref-142"><a href="#cite_note-142">[142]</a></sup>
#  </p>,
#  <p><a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a> is a <a class="mw-redirect" href="/wiki/Live_streaming" title="Live streaming">live streaming</a> platform for video, primarily oriented towards video gaming content. The service was first established as a spin-off of a general-interest streaming service known as <a href="/wiki/Justin.tv" title="Justin.tv">Justin.tv</a>. Its prominence was eclipsed by that of Twitch, and Justin.tv was eventually shut down by its parent company in August 2014 in order to focus exclusively on Twitch.<sup class="reference" id="cite_ref-143"><a href="#cite_note-143">[143]</a></sup> Later that month, Twitch was acquired by Amazon for $970 million.<sup class="reference" id="cite_ref-144"><a href="#cite_note-144">[144]</a></sup> Through Twitch, Amazon also owns <a class="mw-redirect" href="/wiki/Curse,_Inc." title="Curse, Inc.">Curse, Inc.</a>, an operator of video gaming communities and a provider of <a class="mw-redirect" href="/wiki/VoIP" title="VoIP">VoIP</a> services for gaming.<sup class="reference" id="cite_ref-145"><a href="#cite_note-145">[145]</a></sup> Since the acquisition, Twitch began to sell games directly through the platform,<sup class="reference" id="cite_ref-146"><a href="#cite_note-146">[146]</a></sup> and began offering special features for Amazon Prime subscribers.<sup class="reference" id="cite_ref-147"><a href="#cite_note-147">[147]</a></sup>
#  </p>,
#  <p>The site's rapid growth had been boosted primarily by the prominence of major <a href="/wiki/Esports" title="Esports">esports</a> competitions on the service, leading <a href="/wiki/GameSpot" title="GameSpot">GameSpot</a> senior esports editor Rod Breslau to have described the service as "the <a href="/wiki/ESPN" title="ESPN">ESPN</a> of esports".<sup class="reference" id="cite_ref-148"><a href="#cite_note-148">[148]</a></sup> As of 2015<sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;"><a class="external text" href="https://en.wikipedia.org/w/index.php?title=Amazon_(company)&amp;action=edit">[update]</a></sup>, the service had over 1.5 million broadcasters and 100 million monthly viewers.<sup class="reference" id="cite_ref-149"><a href="#cite_note-149">[149]</a></sup>
#  </p>,
#  <p>On August 10, 2020, Amazon announced the rebranding of <a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch Prime</a>, the live-streaming site, renaming it <a class="mw-redirect" href="/wiki/Prime_Gaming" title="Prime Gaming">Prime Gaming</a> in another attempt to crack the <a href="/wiki/Video_game" title="Video game">video game</a> market after failing a big-budget game effort. With Twitch Prime, users will be given a free subscription to Twitch, with free games from small studios and discounts for larger titles like <a href="/wiki/Grand_Theft_Auto" title="Grand Theft Auto">Grand Theft Auto</a> and <a href="/wiki/League_of_Legends" title="League of Legends">League of Legends</a>.<sup class="reference" id="cite_ref-150"><a href="#cite_note-150">[150]</a></sup>
#  </p>,
#  <p>On November 2, 2020, <a href="/wiki/Twitch_(service)" title="Twitch (service)">Twitch</a> announced a virtual flagship conference and named it GlitchCon instead of TwitchCon to be held on November 14. The main aim of the conference will be to bring its numerous, disparate communities of streamers and fans together where they can be real-life confidants.<sup class="reference" id="cite_ref-151"><a href="#cite_note-151">[151]</a></sup>
#  </p>,
#  <p><a href="/wiki/Whole_Foods_Market" title="Whole Foods Market">Whole Foods Market</a> is an American <a href="/wiki/Supermarket" title="Supermarket">supermarket</a> <a href="/wiki/Chain_store" title="Chain store">chain</a> exclusively featuring foods without artificial preservatives, colors, flavors, sweeteners, and hydrogenated fats.<sup class="reference" id="cite_ref-152"><a href="#cite_note-152">[152]</a></sup>
#  </p>,
#  <p>Amazon acquired Whole Foods for $13.7 billion in August 2017.<sup class="reference" id="cite_ref-153"><a href="#cite_note-153">[153]</a></sup><sup class="reference" id="cite_ref-154"><a href="#cite_note-154">[154]</a></sup><sup class="reference" id="cite_ref-wf_9-1"><a href="#cite_note-wf-9">[9]</a></sup>
#  </p>,
#  <p>Other Amazon subsidiaries include:
#  </p>,
#  <p>Amazon also has investments in renewable energy and plans to expand its position into the Canadian market through an investment in a new plant in Alberta.<sup class="reference" id="cite_ref-183"><a href="#cite_note-183">[183]</a></sup>
#  </p>,
#  <p>Amazon lobbies the United States federal government and state governments on multiple issues such as the enforcement of sales taxes on online sales, transportation safety, privacy and <a href="/wiki/Information_privacy" title="Information privacy">data protection</a> and intellectual property. According to regulatory filings, Amazon.com focuses its lobbying on the <a href="/wiki/United_States_Congress" title="United States Congress">United States Congress</a>, the <a href="/wiki/Federal_Communications_Commission" title="Federal Communications Commission">Federal Communications Commission</a> and the <a class="mw-redirect" href="/wiki/Federal_Reserve_System" title="Federal Reserve System">Federal Reserve</a>. Amazon.com spent roughly $3.5 million, $5 million and $9.5 million on lobbying, in 2013, 2014 and 2015, respectively.<sup class="reference" id="cite_ref-184"><a href="#cite_note-184">[184]</a></sup>
#  </p>,
#  <p>Amazon.com was a corporate member of the <a href="/wiki/American_Legislative_Exchange_Council" title="American Legislative Exchange Council">American Legislative Exchange Council</a> (ALEC) until it dropped membership following protests at its shareholders' meeting on May 24, 2012.<sup class="reference" id="cite_ref-185"><a href="#cite_note-185">[185]</a></sup>
#  </p>,
#  <p>In 2014, Amazon expanded its lobbying practices as it prepared to lobby the <a href="/wiki/Federal_Aviation_Administration" title="Federal Aviation Administration">Federal Aviation Administration</a> to approve its drone delivery program, hiring the <a href="/wiki/Akin_Gump_Strauss_Hauer_%26_Feld" title="Akin Gump Strauss Hauer &amp; Feld">Akin Gump Strauss Hauer &amp; Feld</a> lobbying firm in June.<sup class="reference" id="cite_ref-186"><a href="#cite_note-186">[186]</a></sup> Amazon and its lobbyists have visited with Federal Aviation Administration officials and aviation committees in Washington, D.C. to explain its plans to deliver packages.<sup class="reference" id="cite_ref-187"><a href="#cite_note-187">[187]</a></sup> In September 2020 this moved one step closer with the granting of a critical certificate by the FAA.<sup class="reference" id="cite_ref-188"><a href="#cite_note-188">[188]</a></sup>
#  </p>,
#  <p>In 2019, it spent $16.8m and had a team of 104 lobbyists, up from $14.4m and 103 lobbyists in 2018.<sup class="reference" id="cite_ref-189"><a href="#cite_note-189">[189]</a></sup>
#  </p>,
#  <p>Amazon has attracted criticism for its actions, including: supplying law enforcement with facial recognition surveillance tools;<sup class="reference" id="cite_ref-washingtonpost.com_190-0"><a href="#cite_note-washingtonpost.com-190">[190]</a></sup> forming cloud computing partnerships with the <a class="mw-redirect" href="/wiki/CIA" title="CIA">CIA</a>;<sup class="reference" id="cite_ref-vanity-fair_191-0"><a href="#cite_note-vanity-fair-191">[191]</a></sup> leading customers away from bookshops;<sup class="reference" id="cite_ref-192"><a href="#cite_note-192">[192]</a></sup> adversely impacting the environment;<sup class="reference" id="cite_ref-Cavaillez_193-0"><a href="#cite_note-Cavaillez-193">[193]</a></sup> placing a low priority on warehouse conditions for workers;<sup class="reference" id="cite_ref-194"><a href="#cite_note-194">[194]</a></sup> actively opposing unionization efforts;<sup class="reference" id="cite_ref-195"><a href="#cite_note-195">[195]</a></sup> remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its <a href="/wiki/1-Click" title="1-Click">1-Click</a> technology; engaging in anti-competitive actions and <a href="/wiki/Price_discrimination" title="Price discrimination">price discrimination</a>;<sup class="reference" id="cite_ref-:6_23-1"><a href="#cite_note-:6-23">[23]</a></sup><sup class="reference" id="cite_ref-baum_24-1"><a href="#cite_note-baum-24">[24]</a></sup> and reclassifying <a href="/wiki/LGBT" title="LGBT">LGBT</a> books as adult content.<sup class="reference" id="cite_ref-196"><a href="#cite_note-196">[196]</a></sup><sup class="reference" id="cite_ref-197"><a href="#cite_note-197">[197]</a></sup> Criticism has also concerned various decisions over whether to censor or publish content such as the <a href="/wiki/WikiLeaks" title="WikiLeaks">WikiLeaks</a> website, works containing <a href="/wiki/Defamation" title="Defamation">libel</a> and material facilitating <a href="/wiki/Dog_fighting" title="Dog fighting">dogfight</a>, <a href="/wiki/Cockfight" title="Cockfight">cockfight</a>, or <a href="/wiki/Pedophilia" title="Pedophilia">pedophile</a> activities. In December 2011, Amazon faced a backlash from small businesses for running a one-day deal to promote its new Price Check app. Shoppers who used the app to check prices in a brick-and-mortar store were offered a 5% discount to purchase the same item from Amazon.<sup class="reference" id="cite_ref-198"><a href="#cite_note-198">[198]</a></sup> Companies like <a href="/wiki/Groupon" title="Groupon">Groupon</a>, <a href="/wiki/EBay" title="EBay">eBay</a> and Taap.it countered Amazon's promotion by offering $10 off from their products.<sup class="reference" id="cite_ref-199"><a href="#cite_note-199">[199]</a></sup><sup class="reference" id="cite_ref-200"><a href="#cite_note-200">[200]</a></sup>
#  </p>,
#  <p>The company has also faced accusations of putting undue pressure on suppliers to maintain and extend its profitability. One effort to squeeze the most vulnerable book publishers was known within the company as the Gazelle Project, after Bezos suggested, according to <a href="/wiki/Brad_Stone_(journalist)" title="Brad Stone (journalist)">Brad Stone</a>, "that Amazon should approach these small publishers the way a cheetah would pursue a sickly gazelle."<sup class="reference" id="cite_ref-New_Yorker_201-0"><a href="#cite_note-New_Yorker-201">[201]</a></sup> In July 2014, the <a href="/wiki/Federal_Trade_Commission" title="Federal Trade Commission">Federal Trade Commission</a> launched a lawsuit against the company alleging it was promoting in-app purchases to children, which were being transacted without parental consent.<sup class="reference" id="cite_ref-202"><a href="#cite_note-202">[202]</a></sup> In 2019, Amazon banned selling <a href="/wiki/Skin_whitening" title="Skin whitening">skin-lightening</a> and <a href="/wiki/Racism" title="Racism">racist</a> products that might affect the consumer's health.<sup class="reference" id="cite_ref-203"><a href="#cite_note-203">[203]</a></sup> In 2022, a lawsuit filed by state attorney-general Letitia James was dismissed by the New York state court of appeals.<sup class="reference" id="cite_ref-204"><a href="#cite_note-204">[204]</a></sup>
#  </p>]

# %%
# extract the text from the paragraph tags and join them together
text = ""
for sent in results:
    text += sent.get_text()
text
# Out:
# '\nAmazon.com, Inc.[1] (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence. It has been referred to as "one of the most influential economic and cultural forces in the world",[5] and is one of the world\'s most valuable brands.[6] It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.\nAmazon was founded by Jeff Bezos from his garage in Bellevue, Washington,[7] on July 5, 1994. Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store.[8] It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D). Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market. Its acquisition of Whole Foods in August 2017 for US$13.4\xa0billion substantially increased its footprint as a physical retailer.[9]\nAmazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures.[10][11][12][13] As of 2021, it is the world\'s largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS,[14] live-streaming service through Twitch, and Internet company as measured by revenue and market share.[15] In 2021, it surpassed Walmart as the world\'s largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200\xa0million subscribers worldwide.[16][17] It is the second-largest private employer in the United States.[18]\nAmazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units. It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022. It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.\nAmazon has been criticized for customer data collection practices,[19] a toxic work culture,[20] tax avoidance,[21][22] and anti-competitive behavior.[23][24]\nAmazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.[25]\nAmazon went public in May 1997. It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany. The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.[26][27]\nIn 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon\'s ecommerce platform.[28][29] In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service.[30] AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006,[31] and Elastic Compute Cloud (EC2) in 2008,[32] allowing companies to rent data storage and computing power from Amazon. In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon\'s warehouses and fulfillment infrastructure.[33]\nAmazon purchased the Whole Foods Market supermarket chain in 2017.[34]\nDuring the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020. The hazard pay increase expired in June 2020, and the paid  ...

# %% [markdown]
# ### Step 2: Text cleaning

# %%
import re
# used this to remove the references/citations from the wikipedia text
pattern = "\[\d*?\]"

# %%
text = re.sub(pattern, '', text)
text
# Out:
# '\nAmazon.com, Inc. (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence. It has been referred to as "one of the most influential economic and cultural forces in the world", and is one of the world\'s most valuable brands. It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.\nAmazon was founded by Jeff Bezos from his garage in Bellevue, Washington, on July 5, 1994. Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store. It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D). Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market. Its acquisition of Whole Foods in August 2017 for US$13.4\xa0billion substantially increased its footprint as a physical retailer.\nAmazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures. As of 2021, it is the world\'s largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS, live-streaming service through Twitch, and Internet company as measured by revenue and market share. In 2021, it surpassed Walmart as the world\'s largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200\xa0million subscribers worldwide. It is the second-largest private employer in the United States.\nAmazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units. It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022. It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.\nAmazon has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior.\nAmazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.\nAmazon went public in May 1997. It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany. The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.\nIn 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon\'s ecommerce platform. In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service. AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006, and Elastic Compute Cloud (EC2) in 2008, allowing companies to rent data storage and computing power from Amazon. In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon\'s warehouses and fulfillment infrastructure.\nAmazon purchased the Whole Foods Market supermarket chain in 2017.\nDuring the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020. The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022. Amazon also introduced temporary restrictions on the sale of non-essential goods, and hir ...

# %%
text = text.replace("\n", "")
text
# Out:
# 'Amazon.com, Inc. (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence. It has been referred to as "one of the most influential economic and cultural forces in the world", and is one of the world\'s most valuable brands. It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.Amazon was founded by Jeff Bezos from his garage in Bellevue, Washington, on July 5, 1994. Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store. It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D). Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market. Its acquisition of Whole Foods in August 2017 for US$13.4\xa0billion substantially increased its footprint as a physical retailer.Amazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures. As of 2021, it is the world\'s largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS, live-streaming service through Twitch, and Internet company as measured by revenue and market share. In 2021, it surpassed Walmart as the world\'s largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200\xa0million subscribers worldwide. It is the second-largest private employer in the United States.Amazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units. It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022. It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.Amazon has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior.Amazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.Amazon went public in May 1997. It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany. The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.In 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon\'s ecommerce platform. In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service. AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006, and Elastic Compute Cloud (EC2) in 2008, allowing companies to rent data storage and computing power from Amazon. In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon\'s warehouses and fulfillment infrastructure.Amazon purchased the Whole Foods Market supermarket chain in 2017.During the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020. The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022. Amazon also introduced temporary restrictions on the sale of non-essential goods, and hired 100,000 more staf ...

# %% [markdown]
# ## **PART 1**
# ### EXTRACTIVE TEXT SUMMARY

# %% [markdown]
# ### Step 1: Sentence Tokenization

# %%
# !pip install -U pip setuptools wheel
# !pip install -U 'spacy[apple]'
# !python -m spacy download en_core_web_sm
import spacy
from string import punctuation
sp = spacy.load('en_core_web_sm')

# %%
# returning a list of stopwords 
all_stopwords = sp.Defaults.stop_words
list(all_stopwords)
# Out:
# ['another',
#  'along',
#  "'ve",
#  '‘ll',
#  'hereafter',
#  'by',
#  'down',
#  'themselves',
#  'has',
#  'empty',
#  'and',
#  'everything',
#  'did',
#  'towards',
#  'however',
#  'top',
#  'without',
#  'forty',
#  'whole',
#  'first',
#  'us',
#  'the',
#  'while',
#  'beyond',
#  'get',
#  'so',
#  'both',
#  'became',
#  'in',
#  'even',
#  'ever',
#  'put',
#  'after',
#  'four',
#  'well',
#  'how',
#  'now',
#  'across',
#  'very',
#  'amount',
#  'them',
#  'on',
#  'you',
#  'whither',
#  'name',
#  'least',
#  'serious',
#  'three',
#  'latter',
#  'various',
#  'together',
#  'therein',
#  'above',
#  'anything',
#  'cannot',
#  'thus',
#  'sometimes',
#  'yours',
#  'meanwhile',
#  'keep',
#  'more',
#  'several',
#  'someone',
#  'besides',
#  'perhaps',
#  'do',
#  'of',
#  'whatever',
#  'go',
#  'against',
#  'throughout',
#  'wherever',
#  'becoming',
#  'anywhere',
#  'at',
#  'what',
#  'beside',
#  'who',
#  'her',
#  'though',
#  'six',
#  'their',
#  "'s",
#  'every',
#  'wherein',
#  'elsewhere',
#  'full',
#  'whereby',
#  '‘s',
#  'twelve',
#  'your',
#  'itself',
#  'n’t',
#  'per',
#  '‘re',
#  'become',
#  "'d",
#  'ourselves',
#  'his',
#  'whether',
#  '’ve',
#  'before',
#  'eight',
#  'never',
#  'also',
#  'bottom',
#  'already',
#  'should',
#  'own',
#  'ten',
#  'fifteen',
#  '‘m',
#  'front',
#  'due',
#  'be',
#  'nothing',
#  'than',
#  'anyway',
#  'something',
#  'latterly',
#  'indeed',
#  'becomes',
#  'then',
#  'move',
#  'hereby',
#  'fifty',
#  'had',
#  'same',
#  "'re",
#  'made',
#  'make',
#  'him',
#  'its',
#  'thereupon',
#  "'ll",
#  'enough',
#  'still',
#  'noone',
#  'off',
#  'some',
#  'have',
#  'none',
#  'anyone',
#  'really',
#  'they',
#  'less',
#  'all',
#  'back',
#  'neither',
#  'namely',
#  'call',
#  'will',
#  'may',
#  'out',
#  'my',
#  'to',
#  'toward',
#  'nowhere',
#  'thence',
#  'anyhow',
#  'most',
#  'regarding',
#  'am',
#  'five',
#  'either',
#  'would',
#  'between',
#  'much',
#  'third',
#  'everywhere',
#  'often',
#  'mine',
#  '’ll',
#  'almost',
#  'seems',
#  'over',
#  'just',
#  'say',
#  'herself',
#  'nobody',
#  '‘ve',
#  'somehow',
#  'our',
#  'whence',
#  'two',
#  'last',
#  'side',
#  'that',
#  'please',
#  'using',
#  'where',
#  'seemed',
#  'which',
#  'nine',
#  'any',
#  'such',
#  'each',
#  'part',
#  'there',
#  'once',
#  '’re',
#  'only',
#  'further',
#  'but',
#  'it',
#  'too',
#  'up',
#  'or',
#  'unless',
#  '‘d',
#  'sometime',
#  'afterwards',
#  'hereupon',
#  'ours',
#  'mostly',
#  'formerly',
#  'from',
#  'yourselves',
#  'others',
#  'under',
#  'somewhere',
#  'those',
#  'was',
#  'again',
#  'many',
#  'why',
#  'for',
#  'else',
#  'thereafter',
#  'herein',
#  'whereafter',
#  'take',
#  'thereby',
#  'a',
#  'upon',
#  'alone',
#  'is',
#  'being',
#  'seem',
#  'since',
#  'rather',
#  'hers',
#  'otherwise',
#  'whoever',
#  'therefore',
#  'whom',
#  'quite',
#  'can',
#  'an',
#  'used',
#  'until',
#  "'m",
#  'always',
#  'whereas',
#  'although',
#  'amongst',
#  'were',
#  'see',
#  'must',
#  'everyone',
#  'sixty',
#  'next',
#  'if',
#  'when',
#  'during',
#  'as',
#  're',
#  'onto',
#  'one',
#  'whose',
#  'through',
#  'been',
#  'hundred',
#  'not',
#  'except',
#  '’d',
#  'about',
#  'give',
#  'with',
#  'these',
#  'ca',
#  'nor',
#  'former',
#  'yet',
#  'doing',
#  'twenty',
#  'whereupon',
#  'moreover',
#  'seeming',
#  'n‘t',
#  'nevertheless',
#  'via',
#  'might',
#  'myself',
#  'are',
#  'himself',
#  'here',
#  'me',
#  'hence',
#  'beforehand',
#  'within',
#  'i',
#  'thru',
#  'she',
#  'into',
#  'he',
#  'among',
#  'around',
#  'because',
#  'we',
#  'could',
#  'behind',
#  'done',
#  'does',
#  '’m',
#  'few',
#  'eleven',
#  'other',
#  'whenever',
#  'below',
#  'yourself',
#  'show',
#  'this',
#  "n't",
#  '’s',
#  'no']

# %%
doc = sp(text)

# %%
# tokenizing the original text
tokens = [token.text for token in doc]
tokens
# Out:
# ['Amazon.com',
#  ',',
#  'Inc.',
#  '(',
#  '/ˈæməzɒn/',
#  'AM',
#  '-',
#  'ə',
#  '-',
#  'zon',
#  ')',
#  'is',
#  'an',
#  'American',
#  'multinational',
#  'technology',
#  'company',
#  'that',
#  'focuses',
#  'on',
#  'e',
#  '-',
#  'commerce',
#  ',',
#  'cloud',
#  'computing',
#  ',',
#  'online',
#  'advertising',
#  ',',
#  'digital',
#  'streaming',
#  ',',
#  'and',
#  'artificial',
#  'intelligence',
#  '.',
#  'It',
#  'has',
#  'been',
#  'referred',
#  'to',
#  'as',
#  '"',
#  'one',
#  'of',
#  'the',
#  'most',
#  'influential',
#  'economic',
#  'and',
#  'cultural',
#  'forces',
#  'in',
#  'the',
#  'world',
#  '"',
#  ',',
#  'and',
#  'is',
#  'one',
#  'of',
#  'the',
#  'world',
#  "'s",
#  'most',
#  'valuable',
#  'brands',
#  '.',
#  'It',
#  'is',
#  'one',
#  'of',
#  'the',
#  'Big',
#  'Five',
#  'American',
#  'information',
#  'technology',
#  'companies',
#  ',',
#  'alongside',
#  'Alphabet',
#  ',',
#  'Apple',
#  ',',
#  'Meta',
#  ',',
#  'and',
#  'Microsoft',
#  '.',
#  'Amazon',
#  'was',
#  'founded',
#  'by',
#  'Jeff',
#  'Bezos',
#  'from',
#  'his',
#  'garage',
#  'in',
#  'Bellevue',
#  ',',
#  'Washington',
#  ',',
#  'on',
#  'July',
#  '5',
#  ',',
#  '1994',
#  '.',
#  'Initially',
#  'an',
#  'online',
#  'marketplace',
#  'for',
#  'books',
#  ',',
#  'it',
#  'has',
#  'expanded',
#  'into',
#  'a',
#  'multitude',
#  'of',
#  'product',
#  'categories',
#  ',',
#  'a',
#  'strategy',
#  'that',
#  'has',
#  'earned',
#  'it',
#  'the',
#  'moniker',
#  'The',
#  'Everything',
#  'Store',
#  '.',
#  'It',
#  'has',
#  'multiple',
#  'subsidiaries',
#  'including',
#  'Amazon',
#  'Web',
#  'Services',
#  '(',
#  'cloud',
#  'computing',
#  ')',
#  ',',
#  'Zoox',
#  '(',
#  'autonomous',
#  'vehicles',
#  ')',
#  ',',
#  'Kuiper',
#  'Systems',
#  '(',
#  'satellite',
#  'Internet',
#  ')',
#  ',',
#  'and',
#  'Amazon',
#  'Lab126',
#  '(',
#  'computer',
#  'hardware',
#  'R&D',
#  ')',
#  '.',
#  'Its',
#  'other',
#  'subsidiaries',
#  'include',
#  'Ring',
#  ',',
#  'Twitch',
#  ',',
#  'IMDb',
#  ',',
#  'and',
#  'Whole',
#  'Foods',
#  'Market',
#  '.',
#  'Its',
#  'acquisition',
#  'of',
#  'Whole',
#  'Foods',
#  'in',
#  'August',
#  '2017',
#  'for',
#  'US$',
#  '13.4',
#  '\xa0',
#  'billion',
#  'substantially',
#  'increased',
#  'its',
#  'footprint',
#  'as',
#  'a',
#  'physical',
#  'retailer',
#  '.',
#  'Amazon',
#  'has',
#  'earned',
#  'a',
#  'reputation',
#  'as',
#  'a',
#  'disruptor',
#  'of',
#  'well',
#  '-',
#  'established',
#  'industries',
#  'through',
#  'technological',
#  'innovation',
#  'and',
#  '"',
#  'aggressive',
#  '"',
#  'reinvestment',
#  'of',
#  'profits',
#  'into',
#  'capital',
#  'expenditures',
#  '.',
#  'As',
#  'of',
#  '2021',
#  ',',
#  'it',
#  'is',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'online',
#  'retailer',
#  'and',
#  'marketplace',
#  ',',
#  'smart',
#  'speaker',
#  'provider',
#  ',',
#  'cloud',
#  'computing',
#  'service',
#  'through',
#  'AWS',
#  ',',
#  'live',
#  '-',
#  'streaming',
#  'service',
#  'through',
#  'Twitch',
#  ',',
#  'and',
#  'Internet',
#  'company',
#  'as',
#  'measured',
#  'by',
#  'revenue',
#  'and',
#  'market',
#  'share',
#  '.',
#  'In',
#  '2021',
#  ',',
#  'it',
#  'surpassed',
#  'Walmart',
#  'as',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'retailer',
#  'outside',
#  'of',
#  'China',
#  ',',
#  'driven',
#  'in',
#  'large',
#  'part',
#  'by',
#  'its',
#  'paid',
#  'subscription',
#  'plan',
#  ',',
#  'Amazon',
#  'Prime',
#  ',',
#  'which',
#  'has',
#  'over',
#  '200',
#  '\xa0',
#  'million',
#  'subscribers',
#  'worldwide',
#  '.',
#  'It',
#  'is',
#  'the',
#  'second',
#  '-',
#  'largest',
#  'private',
#  'employer',
#  'in',
#  'the',
#  'United',
#  'States',
#  '.',
#  'Amazon',
#  'also',
#  'distributes',
#  'a',
#  'variety',
#  'of',
#  'downloadable',
#  'and',
#  'streaming',
#  'content',
#  'through',
#  'its',
#  'Amazon',
#  'Prime',
#  'Video',
#  ',',
#  'Amazon',
#  'Music',
#  ',',
#  'Twitch',
#  ',',
#  'and',
#  'Audible',
#  'units',
#  '.',
#  'It',
#  'publishes',
#  'books',
#  'through',
#  'its',
#  'publishing',
#  'arm',
#  ',',
#  'Amazon',
#  'Publishing',
#  ',',
#  'film',
#  'and',
#  'television',
#  'content',
#  'through',
#  'Amazon',
#  'Studios',
#  ',',
#  'and',
#  'has',
#  'been',
#  'the',
#  'owner',
#  'of',
#  'film',
#  'and',
#  'television',
#  'studio',
#  'Metro',
#  '-',
#  'Goldwyn',
#  '-',
#  'Mayer',
#  'since',
#  'March',
#  '2022',
#  '.',
#  'It',
#  'also',
#  'produces',
#  'consumer',
#  'electronics',
#  '—',
#  'most',
#  'notably',
#  ',',
#  'Kindle',
#  'e',
#  '-',
#  'readers',
#  ',',
#  'Echo',
#  'devices',
#  ',',
#  'Fire',
#  'tablets',
#  ',',
#  'and',
#  'Fire',
#  'TVs',
#  '.',
#  'Amazon',
#  'has',
#  'been',
#  'criticized',
#  'for',
#  'customer',
#  'data',
#  'collection',
#  'practices',
#  ',',
#  'a',
#  'toxic',
#  'work',
#  'culture',
#  ',',
#  'tax',
#  'avoidance',
#  ',',
#  'and',
#  'anti',
#  '-',
#  'competitive',
#  'behavior',
#  '.',
#  'Amazon',
#  'was',
#  'founded',
#  'in',
#  'July',
#  '1994',
#  'by',
#  'Jeff',
#  'Bezos',
#  ',',
#  'who',
#  'chose',
#  'the',
#  'Seattle',
#  'area',
#  'for',
#  'its',
#  'abundance',
#  'of',
#  'technical',
#  'talent',
#  ',',
#  'as',
#  'Microsoft',
#  'was',
#  'in',
#  'the',
#  'area',
#  '.',
#  'Amazon',
#  'went',
#  'public',
#  'in',
#  'May',
#  '1997',
#  '.',
#  'It',
#  'began',
#  'selling',
#  'music',
#  'and',
#  'videos',
#  'in',
#  '1998',
#  ',',
#  'and',
#  'began',
#  'international',
#  'operations',
#  'by',
#  'acquiring',
#  'online',
#  'sellers',
#  'of',
#  'books',
#  'in',
#  'the',
#  'United',
#  'Kingdom',
#  'and',
#  'Germany',
#  '.',
#  'The',
#  'following',
#  'year',
#  ',',
#  'it',
#  'began',
#  'selling',
#  'music',
#  ',',
#  'video',
#  'games',
#  ',',
#  'consumer',
#  'electronics',
#  ',',
#  'home',
#  'improvement',
#  'items',
#  ',',
#  'software',
#  ',',
#  'games',
#  ',',
#  'and',
#  'toys',
#  '.',
#  'In',
#  '2002',
#  ',',
#  'it',
#  'launched',
#  'Amazon',
#  'Web',
#  'Services',
#  '(',
#  'AWS',
#  ')',
#  ',',
#  'which',
#  'initially',
#  'focused',
#  'on',
#  'providing',
#  'APIs',
#  'for',
#  'web',
#  'developers',
#  'to',
#  'build',
#  'web',
#  'applications',
#  'on',
#  'top',
#  'of',
#  'Amazon',
#  "'s",
#  'ecommerce',
#  'platform',
#  '.',
#  'In',
#  '2004',
#  ',',
#  'AWS',
#  'was',
#  'expanded',
#  'to',
#  'provide',
#  'website',
#  'popularity',
#  'statistics',
#  'and',
#  'web',
#  'crawler',
#  'data',
#  'from',
#  'the',
#  'Alexa',
#  'Web',
#  'Information',
#  'Service',
#  '.',
#  'AWS',
#  'later',
#  'shifted',
#  'toward',
#  'providing',
#  'enterprise',
#  'services',
#  'with',
#  'Simple',
#  'Storage',
#  'Service',
#  '(',
#  'S3',
#  ')',
#  'in',
#  '2006',
#  ',',
#  'and',
#  'Elastic',
#  'Compute',
#  'Cloud',
#  '(',
#  'EC2',
#  ')',
#  'in',
#  '2008',
#  ',',
#  'allowing',
#  'companies',
#  'to',
#  'rent',
#  'data',
#  'storage',
#  'and',
#  'computing',
#  'power',
#  'from',
#  'Amazon',
#  '.',
#  'In',
#  '2006',
#  ',',
#  'Amazon',
#  'also',
#  'launched',
#  'the',
#  'Fulfillment',
#  'by',
#  'Amazon',
#  'program',
#  ',',
#  'which',
#  'allowed',
#  'individuals',
#  'and',
#  'small',
#  'companies',
#  '(',
#  'called',
#  '"',
#  'third',
#  '-',
#  'party',
#  'sellers',
#  '"',
#  ')',
#  'to',
#  'sell',
#  'products',
#  'through',
#  'Amazon',
#  "'s",
#  'warehouses',
#  'and',
#  'fulfillment',
#  'infrastructure',
#  '.',
#  'Amazon',
#  'purchased',
#  'the',
#  'Whole',
#  'Foods',
#  'Market',
#  'supermarket',
#  'chain',
#  'in',
#  '2017.During',
#  'the',
#  'COVID-19',
#  'pandemic',
#  ',',
#  'Amazon',
#  'introduced',
#  'a',
#  'hazard',
#  'pay',
#  'of',
#  '$',
#  '2',
#  '-',
#  'per',
#  '-',
#  'hour',
#  ',',
#  'changes',
#  'to',
#  'overtime',
#  'pay',
#  ',',
#  'and',
#  'a',
#  'policy',
#  'of',
#  'unlimited',
#  ',',
#  'unpaid',
#  'time',
#  'off',
#  'until',
#  'April',
#  '30',
#  ',',
#  '2020',
#  '.',
#  'The',
#  'hazard',
#  'pay',
#  'increase',
#  'expired',
#  'in',
#  'June',
#  '2020',
#  ',',
#  'and',
#  'the',
#  'paid',
#  'time',
#  '-',
#  'off',
#  'policy',
#  'in',
#  'May',
#  '2022',
#  '.',
#  'Amazon',
#  'also',
#  'introduced',
#  'temporary',
#  'restrictions',
#  'on',
#  'the',
#  'sale',
#  'of',
#  'non',
#  '-',
#  'essential',
#  'goods',
#  ',',
#  'and',
#  'hired',
#  '100,000',
#  'more',
#  'staff',
#  'in',
#  'the',
#  'US',
#  'and',
#  'Canada',
#  '.',
#  'Some',
#  'Amazon',
#  'workers',
#  'in',
#  'the',
#  'US',
#  ',',
#  'France',
#  ',',
#  'and',
#  'Italy',
#  'protested',
#  'the',
#  'company',
#  "'s",
#  'decision',
#  'to',
#  '"',
#  'run',
#  'normal',
#  'shifts',
#  '"',
#  'despite',
#  'many',
#  'positive',
#  'COVID-19',
#  'cases',
#  '.',
#  'In',
#  'Spain',
#  ',',
#  'the',
#  'company',
#  'has',
#  'faced',
#  'legal',
#  'complaints',
#  'over',
#  'its',
#  'policies',
#  '.',
#  'A',
#  'group',
#  'of',
#  'US',
#  'Senators',
#  'wrote',
#  'an',
#  'open',
#  'letter',
#  'to',
#  'Bezos',
#  'in',
#  'March',
#  '2020',
#  ',',
#  'expressing',
#  'concerns',
#  'about',
#  'worker',
#  'safety',
#  '.',
#  'On',
#  'February',
#  '2',
#  ',',
#  '2021',
#  ',',
#  'Amazon',
#  'announced',
#  'that',
#  'Jeff',
#  'Bezos',
#  'would',
#  'step',
#  'down',
#  'as',
#  'CEO',
#  'to',
#  'become',
#  'executive',
#  'chair',
#  'of',
#  'Amazon',
#  "'s",
#  'board',
#  'in',
#  'Q3',
#  'of',
#  '2021',
#  '.',
#  'Andy',
#  'Jassy',
#  ',',
#  'previously',
#  'CEO',
#  'of',
#  'AWS',
#  ',',
#  'became',
#  'Amazon',
#  "'s",
#  'CEO.Amazon.com',
#  'is',
#  'an',
#  'ecommerce',
#  'platform',
#  'that',
#  'sells',
#  'many',
#  'product',
#  'lines',
#  ',',
#  'include',
#  'media',
#  '(',
#  'books',
#  ',',
#  'movies',
#  ',',
#  'music',
#  ',',
#  'and',
#  'software',
#  ')',
#  ',',
#  'apparel',
#  ',',
#  'baby',
#  'products',
#  ',',
#  'consumer',
#  'electronics',
#  ',',
#  'beauty',
#  'products',
#  ',',
#  'gourmet',
#  'food',
#  ',',
#  'groceries',
#  ',',
#  'health',
#  'and',
#  'personal',
#  'care',
#  'products',
#  ',',
#  'industrial',
#  '&',
#  'scientific',
#  'supplies',
#  ',',
#  'kitchen',
#  'items',
#  ',',
#  'jewelry',
#  ',',
#  'watches',
#  ',',
#  'lawn',
#  'and',
#  'garden',
#  'items',
#  ',',
#  'musical',
#  'instruments',
#  ',',
#  'sporting',
#  'goods',
#  ',',
#  'tools',
#  ',',
#  'automotive',
#  'items',
#  ',',
#  'toys',
#  'and',
#  'games',
#  ',',
#  'and',
#  'farm',
#  'supplies',
#  'and',
#  'consulting',
#  'services',
#  '.',
#  'Amazon',
#  'websites',
#  'are',
#  'country',
#  '-',
#  'specific',
#  '(',
#  'for',
#  'example',
#  ',',
#  'amazon.com',
#  'for',
#  'the',
#  'U.S.',
#  'and',
#  'amazon.fr',
#  'for',
#  'France',
#  ')',
#  ',',
#  'though',
#  'some',
#  'offer',
#  'international',
#  'shipping',
#  '.',
#  'Visits',
#  'to',
#  'amazon.com',
#  'grew',
#  'from',
#  '615',
#  '\xa0',
#  'million',
#  'annual',
#  'visitors',
#  'in',
#  '2008',
#  ',',
#  'to',
#  'more',
#  'than',
#  '2',
#  'billion',
#  'per',
#  'month',
#  'in',
#  '2022',
#  '.',
#  'The',
#  'company',
#  'has',
#  'invested',
#  'heavily',
#  'in',
#  'server',
#  'capacity',
#  ...]

# %%
sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# [Amazon.com, Inc. (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence.,
#  It has been referred to as "one of the most influential economic and cultural forces in the world", and is one of the world's most valuable brands.,
#  It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.,
#  Amazon was founded by Jeff Bezos from his garage in Bellevue, Washington, on July 5, 1994.,
#  Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store.,
#  It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D).,
#  Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market.,
#  Its acquisition of Whole Foods in August 2017 for US$13.4 billion substantially increased its footprint as a physical retailer.,
#  Amazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures.,
#  As of 2021, it is the world's largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS, live-streaming service through Twitch, and Internet company as measured by revenue and market share.,
#  In 2021, it surpassed Walmart as the world's largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200 million subscribers worldwide.,
#  It is the second-largest private employer in the United States.,
#  Amazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units.,
#  It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022.,
#  It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.,
#  Amazon has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior.,
#  Amazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.,
#  Amazon went public in May 1997.,
#  It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany.,
#  The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.,
#  In 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon's ecommerce platform.,
#  In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service.,
#  AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006, and Elastic Compute Cloud (EC2) in 2008, allowing companies to rent data storage and computing power from Amazon.,
#  In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon's warehouses and fulfillment infrastructure.,
#  Amazon purchased the Whole Foods Market supermarket chain in 2017.During the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020.,
#  The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022.,
#  Amazon also introduced temporary restrictions on the sale of non-essential goods, and hired 100,000 more staff in the US and Canada.,
#  Some Amazon workers in the US, France, and Italy protested the company's decision to "run normal shifts" despite many positive COVID-19 cases.,
#  In Spain, the company has faced legal complaints over its policies.,
#  A group of US Senators wrote an open letter to Bezos in March 2020, expressing concerns about worker safety.,
#  On February 2, 2021, Amazon announced that Jeff Bezos would step down as CEO to become executive chair of Amazon's board in Q3 of 2021.,
#  Andy Jassy, previously CEO of AWS, became Amazon's CEO.Amazon.com is an ecommerce platform that sells many product lines, include media (books, movies, music, and software), apparel, baby products, consumer electronics, beauty products, gourmet food, groceries, health and personal care products, industrial & scientific supplies, kitchen items, jewelry, watches, lawn and garden items, musical instruments, sporting goods, tools, automotive items, toys and games, and farm supplies and consulting services.,
#  Amazon websites are country-specific (for example, amazon.com for the U.S. and amazon.fr for France), though some offer international shipping.,
#  Visits to amazon.com grew from 615 million annual visitors in 2008, to more than 2 billion per month in 2022.,
#  The company has invested heavily in server capacity and redundancy to handle increased traffic during the Christmas holiday season.,
#  The ecommerce platform is the 14th most visited website in the world.,
#  In 2000, U.S. toy retailer Toys "R" Us entered into a 10-year agreement with Amazon, valued at $50 million per year plus a cut of sales, under which Toys "R" Us would be the exclusive supplier of toys and baby products on the service, and the chain's website would redirect to Amazon's Toys & Games category.,
#  In 2004, Toys "R" Us sued Amazon, claiming that because of a perceived lack of variety in Toys "R" Us stock, Amazon had knowingly allowed third-party sellers to offer items on the service in categories that Toys "R" Us had been granted exclusivity.,
#  In 2006, a court ruled in favor of Toys "R" Us, giving it the right to unwind its agreement with Amazon and establish its independent e-commerce website.,
#  The company was later awarded $51 million in damages.,
#  In 2001, Amazon entered into a similar agreement with Borders Group, under which Amazon would comanage Borders.com as a co-branded service.,
#  Borders pulled out of the arrangement in 2007, with plans to also launch its own online store.,
#  On October 18, 2011, Amazon.com announced a partnership with DC Comics for the exclusive digital rights to many popular comics, including Superman, Batman, Green Lantern, The Sandman, and Watchmen.,
#  The partnership has caused well-known bookstores like Barnes & Noble to remove these titles from their shelves.,
#  In November 2013, Amazon announced a partnership with the United States Postal Service to begin delivering orders on Sundays.,
#  The service, included in Amazon's standard shipping rates, initiated in metropolitan areas of Los Angeles and New York because of the high-volume and inability to deliver in a timely way, with plans to expand into Dallas, Houston, New Orleans and Phoenix by 2014.In June 2017, Nike agreed to sell products through Amazon in exchange for better policing of counterfeit goods.,
#  This proved unsuccessful and Nike withdrew from the partnership in November 2019.,
#  Companies including IKEA and Birkenstock also stopped selling through Amazon around the same time, citing similar frustrations over business practices and counterfeit goods.,
#  In September 2017, Amazon ventured with one of its sellers JV Appario Retail owned by Patni Group which has recorded a total income of US$ 104.44 million (₹ 759 crore) in financial year 2017–2018.As of October 11, 2017[update], AmazonFresh sold a range of Booths branded products for home delivery in selected areas.,
#  In November 2018, Amazon reached an agreement with Apple Inc. to sell selected products through the service, via the company and selected Apple Authorized Resellers.,
#  As a result of this partnership, only Apple Authorized Resellers may sell Apple products on Amazon effective January 4, 2019.Amazon sells many products under its own brand names, including phone chargers, batteries, an diaper wipes.,
#  The AmazonBasics brand was introduced in 2009, and now features hundreds of product lines, including smartphone cases, computer mice, batteries, dumbbells, and dog crates.,
#  Amazon owned 34 private-label brands as of 2019.,
#  These brands account for 0.15% of Amazon's global sales, whereas the average for other large retailers is 18%.,
#  Other Amazon retail brands include Presto!, Mama Bear, and Amazon Essentials.,
#  Amazon derives many of its sales (around 40% in 2008) from third-party sellers who sell products on Amazon.,
#  Some other large e-commerce sellers use Amazon to sell their products in addition to selling them through their websites.,
#  The sales are processed through Amazon.com and end up at individual sellers for processing and order fulfillment and Amazon leases space for these retailers.,
#  Small sellers of used and new goods go to Amazon Marketplace to offer goods at a fixed price.,
#  Publishers can signup as affiliates and receive a commission for referring customers to Amazon by placing links to Amazon on their websites if the referral results in a sale.,
#  Worldwide, Amazon has "over 900,000 members" in its affiliate programs.,
#  In the middle of 2014, the Amazon Affiliate Program is used by 1.2% of all websites and it is the second most popular advertising network after Google Ads.,
#  It is frequently used by websites and non-profits to provide a way for supporters to earn them a commission.,
#  Associates can access the Amazon catalog directly on their websites by using the Amazon Web Services (AWS) XML service.,
#  A new affiliate product, aStore, allows Associates to embed a subset of Amazon products within another website, or linked to another website.,
#  In June 2010, Amazon Seller Product Suggestions was launched (rumored to be internally called "Project Genesis") to provide more transparency to sellers by recommending specific products to third-party sellers to sell on Amazon.,
#  Products suggested are based on customers' browsing history.,
#  In 2019, Amazon launched a bigger local online store in Singapore to expand its product selection in the face of intensifying competition with competitors in the region.,
#  In July 2019, the 3rd U.S. City Court of Appeals in Philadelphia ruled that Amazon can be held accountable for faulty third-party sales.,
#  The decision ran counter to a past lower court ruling that had favored Amazon.,
#  Heather Oberdorf had sued the company in 2016 over a dog leash that snapped, causing permanent loss of vision in one eye.,
#  If upheld, the decision would expose Amazon and similar platform businesses to strict liability lawsuits for defective products, which represents a major change in the law.,
#  The panel sent the case back to the lower court, to decide whether the leash was defective.,
#  Amazon allows users to submit reviews to the web page of each product.,
#  Reviewers must rate the product on a rating scale from one to five stars.,
#  Amazon provides a badging option for reviewers which indicates the real name of the reviewer (based on confirmation of a credit card account) or which indicates that the reviewer is one of the top reviewers by popularity.,
#  As of December 16, 2020, Amazon removed the ability of sellers and customers to comment on product reviews and purged their websites of all posted product review comments.,
#  In an email to sellers Amazon gave its rationale for removing this feature: "... the comments feature on customer reviews was rarely used.",
#  The remaining review response options are to indicate whether the reader finds the review helpful or to report that it violates Amazon policies (abuse).,
#  If a review is given enough "helpful" hits, it appears on the front page of the product.,
#  In 2010, Amazon was reported as being the largest single source of Internet consumer reviews.,
#  When publishers asked Bezos why Amazon would publish negative reviews, he defended the practice by claiming that Amazon.com was "taking a different approach ...,
#  we want to make every book available—the good, the bad and the ugly ... to let truth loose".,
#  There have been cases of positive reviews being written and posted by public relations companies on behalf of their clients and instances of writers using pseudonyms to leave negative reviews of their rivals' worksThe Amazon sales rank (ASR) indicates the popularity of a product sold on any Amazon locale.,
#  It is a relative indicator of popularity that is updated hourly.,
#  Effectively, it is a "best sellers list" for the millions of products stocked by Amazon.,
#  While the ASR has no direct effect on the sales of a product, it is used by Amazon to determine which products to include in its bestsellers lists.,
#  Products that appear in these lists enjoy additional exposure on the Amazon website and this may lead to an increase in sales.,
#  In particular, products that experience large jumps (up or down) in their sales ranks may be included within Amazon's lists of "movers and shakers"; such a listing provides additional exposure that might lead to an increase in sales.,
#  For competitive reasons, Amazon does not release actual sales figures to the public.,
#  However, Amazon has now begun to release point of sale data via the Nielsen BookScan service to verified authors.,
#  While the ASR has been the source of much speculation by publishers, manufacturers, and marketers, Amazon itself does not release the details of its sales rank calculation algorithm.,
#  Some companies have analyzed Amazon sales data to generate sales estimates based on the ASR, though Amazon states:Please keep in mind that our sales rank figures are simply meant to be a guide of general interest for the customer and not definitive sales information for publishers—we assume you have this information regularly from your distribution sources"Search Inside the Book" is a feature which allows customers to search for keywords in the full text of many books in the catalog.,
#  The feature started with 120,000 titles (or 33 million pages of text) on October 23, 2003.In November 2020, the company started an online delivery service dedicated to prescription drugs.,
#  The service provides discounts up to 80% for generic drugs and up to 40% for branded drugs for Prime subscribe users.,
#  The products can be purchased on the company's website or at over 50,000 bricks-and-mortar pharmacies in the United States.,
#  In November 2015, Amazon opened a physical Amazon Books store in University Village in Seattle.,
#  The store is 5,500 square feet and prices for all products match those on its website.,
#  Amazon will open its tenth physical book store in 2017; media speculation suggests Amazon plans to eventually roll out 300 to 400 bookstores around the country.,
#  In June 2018, it was reported that Amazon planned to open brick and mortar bookstores in Germany.,
#  In August 2019, Amazon applied to have a liquor store in San Francisco, CA as a means to ship beer and alcohol within the city.,
#  In 2020, Amazon Fresh opened several physical stores in the U.S. and the United Kingdom.,
#  In September 2020, Amazon launched Luxury Stores on its mobile app, where Oscar de la Renta become the first and only label to partner with the firm.,
#  Amazon Web Services (AWS) is a subsidiary of that provides on-demand cloud computing platforms and APIs to individuals, companies, and governments, on a metered pay-as-you-go basis.,
#  These cloud computing web services provide distributed computing processing capacity and software tools via AWS server farms.,
#  One of these services is Amazon Elastic Compute Cloud (EC2), which allows users to have at their disposal a virtual cluster of computers, available all the time, through the Internet.,
#  AWS's virtual computers emulate most of the attributes of a real computer, including hardware central processing units (CPUs) and graphics processing units (GPUs) for processing; local/RAM memory; hard-disk/SSD storage; a choice of operating systems; networking; and pre-loaded application software such as web servers, databases, and customer relationship management (CRM).AWS services are delivered to customers via a network of AWS server farms located throughout the world.,
#  Fees are based on a combination of usage (known as a "Pay-as-you-go" model), hardware, operating system, software, or networking features chosen by the subscriber required availability, redundancy, security, and service options.,
#  Subscribers can pay for a single virtual AWS computer, a dedicated physical computer, or clusters of either.,
#  Amazon provides select portions of security for subscribers (e.g. physical security of the data centers) while other aspects of security are the responsibility of the subscriber (e.g. account management, vulnerability scanning, patching).,
#  AWS operates from many global geographical regions including 6 in North America.,
#  Amazon markets AWS to subscribers as a way of obtaining large-scale computing capacity more quickly and cheaply than building an actual physical server farm.,
#  All services are billed based on usage, but each service measures usage in varying ways.,
#  As of 2021 Q4, AWS has 33% market share for cloud infrastructure while the next two competitors Microsoft Azure and Google Cloud have 21%, and 10% respectively, according to Synergy Group.,
#  Amazon has a number of products and services available, including its digital assistant Alexa, Amazon Music and Prime Video for music and videos respectively, the Amazon Appstore for Android apps, and its Kindle hardware line of e-readers and tablets.,
#  Audible provides audiobooks for purchase and listening.,
#  In September 2021, Amazon announced the launch of Astro, its first household robot, powered by its Alexa smart home technology.,
#  This can be remote-controlled when not at home, to check on pets, people, or home security.,
#  It will send owners a notification if it detects something unusual.,
#  Amazon uses many different transportation services to deliver packages.,
#  Amazon-branded services include:Amazon directly employs people to work at its warehouses, bulk distribution centers, staffed "Amazon Hub Locker+" locations, and delivery stations where drivers pick up packages.,
#  As of December 2020, it is not hiring delivery drivers as employees.,
#  Rakuten Intelligence estimated that in 2020 in the United States, the proportion of last-mile deliveries was 56% by Amazon's directly contracted services (mostly in urban areas), 30% by the U.S. Postal Service (mostly in rural areas), and 14% by UPS.,
#  In April 2021, Amazon reported to investors it had increased its in-house delivery capacity by 50% in the last 12 months (which included the first year of the COVID-19 pandemic in the United States).Amazon first launched its distribution network in 1997 with two fulfillment centers in Seattle and New Castle, Delaware.,
#  Amazon has several types of distribution facilities consisting of cross-dock centers, fulfillment centers, sortation centers, delivery stations, Prime now hubs, and Prime air hubs.,
#  There are 75 fulfillment centers and 25 sortation centers with over 125,000 employees.,
#  Employees are responsible for five basic tasks: unpacking and inspecting incoming goods; placing goods in storage and recording their location; picking goods from their computer recorded locations to make up an individual shipment; sorting and packing orders; and shipping.,
#  A computer that records the location of goods and maps out routes for pickers plays a key role: employees carry hand-held computers which communicate with the central computer and monitor their rate of progress.,
#  Some warehouses are partially automated with systems built by Amazon Robotics.,
#  In September 2006, Amazon launched a program called FBA (Fulfillment By Amazon) whereby it could handle storage, packing and distribution of products and services for small sellers.Amazon.fr fulfillment center in Lauwin-Planque, FranceAmazon.es fulfillment center in San Fernando de Henares, SpainAmazon.co.uk fulfillment center in Glenrothes, Scotland, UKAmazon.de fulfillment center in Graben, GermanyAmazon.co.jp fulfillment center in Ichikawa, JapanAmazon fulfillment center in Macon, Georgia, U.S.During his tenure, Jeff Bezos had become renowned for his annual shareholder letters, which have gained similar notability to those of Warren Buffett.,
#  These annual letters gave an "invaluable window" into the famously "secretive" company, and revealed Bezos's perspectives and strategic focus.,
#  A common theme of these letters is Bezos's desire to instill customer-centricity (in his words, "customer obsession") at all levels of Amazon, notably by making all senior executives field customer support queries for a short time at Amazon call centers.,
#  He also read many emails addressed by customers to his public email address.,
#  One of Bezos's most well-known internal memos was his mandate for "all teams" to "expose their data and functionality" through service interfaces "designed from the ground up to be externalizable".,
#  This process, commonly known as a service-oriented architecture (SOA), resulted in mandatory dogfooding of services that would later be commercialized as part of AWS.As of June 2022[update], Amazon's board of directors were:Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products.,
#  As of 2018[update], Amazon.com is ranked 8th on the Fortune 500 rankings of the largest United States corporations by total revenue.,
#  For the fiscal year 2021, Amazon reported earnings of US$33.36 billion, with an annual revenue of US$469.82 billion, an increase of 21.7% over the previous fiscal cycle.,
#  Since 2007 sales increased from 14.835 billion to 469.822 billion, due to continued business expansion.,
#  Amazon's market capitalization went over US$1 trillion again in early February 2020 after the announcement of the fourth quarter 2019 results.,
#  Amazon owns over 40 subsidiaries, including Amazon Web Services, Audible, Diapers.com, Goodreads, IMDb, Kiva Systems (now Amazon Robotics), Shopbop, Teachstreet, Twitch, Zappos, and Zoox.,
#  Goodreads is a "social cataloging" website founded in December 2006 and launched in January 2007 by Otis Chandler, a software engineer, and entrepreneur, and Elizabeth Khuri.,
#  The website allows individuals to freely search Goodreads' extensive user-populated database of books, annotations, and reviews.,
#  Users can sign up and register books to generate library catalogs and reading lists.,
#  They can also create their groups of book suggestions and discussions.,
#  In December 2007, the site had over 650,000 members, and over a million books had been added.,
#  Amazon bought the company in March 2013.Kuiper Systems LLC, is a subsidiary of Amazon, set up to deploy a broadband satellite internet constellation with an announced 3,236 Low Earth orbit satellites to provide satellite based Internet connectivity.,
#  Ring is a home automation company founded by Jamie Siminoff in 2013.,
#  It is primarily known for its WiFi powered smart doorbells, but manufactures other devices such as security cameras.,
#  Amazon bought Ring for US$1 billion in 2018.Twitch is a live streaming platform for video, primarily oriented towards video gaming content.,
#  The service was first established as a spin-off of a general-interest streaming service known as Justin.tv.,
#  Its prominence was eclipsed by that of Twitch, and Justin.tv was eventually shut down by its parent company in August 2014 in order to focus exclusively on Twitch.,
#  Later that month, Twitch was acquired by Amazon for $970 million.,
#  Through Twitch, Amazon also owns Curse, Inc., an operator of video gaming communities and a provider of VoIP services for gaming.,
#  Since the acquisition, Twitch began to sell games directly through the platform, and began offering special features for Amazon Prime subscribers.,
#  The site's rapid growth had been boosted primarily by the prominence of major esports competitions on the service, leading GameSpot senior esports editor Rod Breslau to have described the service as "the ESPN of esports".,
#  As of 2015[update], the service had over 1.5 million broadcasters and 100 million monthly viewers.,
#  On August 10, 2020, Amazon announced the rebranding of Twitch Prime, the live-streaming site, renaming it Prime Gaming in another attempt to crack the video game market after failing a big-budget game effort.,
#  With Twitch Prime, users will be given a free subscription to Twitch, with free games from small studios and discounts for larger titles like Grand Theft Auto and League of Legends.,
#  On November 2, 2020, Twitch announced a virtual flagship conference and named it GlitchCon instead of TwitchCon to be held on November 14.,
#  The main aim of the conference will be to bring its numerous, disparate communities of streamers and fans together where they can be real-life confidants.,
#  Whole Foods Market is an American supermarket chain exclusively featuring foods without artificial preservatives, colors, flavors, sweeteners, and hydrogenated fats.,
#  Amazon acquired Whole Foods for $13.7 billion in August 2017.Other Amazon subsidiaries include:Amazon also has investments in renewable energy and plans to expand its position into the Canadian market through an investment in a new plant in Alberta.,
#  Amazon lobbies the United States federal government and state governments on multiple issues such as the enforcement of sales taxes on online sales, transportation safety, privacy and data protection and intellectual property.,
#  According to regulatory filings, Amazon.com focuses its lobbying on the United States Congress, the Federal Communications Commission and the Federal Reserve.,
#  Amazon.com spent roughly $3.5 million, $5 million and $9.5 million on lobbying, in 2013, 2014 and 2015, respectively.Amazon.com was a corporate member of the American Legislative Exchange Council (ALEC) until it dropped membership following protests at its shareholders' meeting on May 24, 2012.In 2014, Amazon expanded its lobbying practices as it prepared to lobby the Federal Aviation Administration to approve its drone delivery program, hiring the Akin Gump Strauss Hauer & Feld lobbying firm in June.,
#  Amazon and its lobbyists have visited with Federal Aviation Administration officials and aviation committees in Washington, D.C. to explain its plans to deliver packages.,
#  In September 2020 this moved one step closer with the granting of a critical certificate by the FAA.In 2019, it spent $16.8m and had a team of 104 lobbyists, up from $14.4m and 103 lobbyists in 2018.Amazon has attracted criticism for its actions, including: supplying law enforcement with facial recognition surveillance tools; forming cloud computing partnerships with the CIA; leading customers away from bookshops; adversely impacting the environment; placing a low priority on warehouse conditions for workers; actively opposing unionization efforts; remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its 1-Click technology; engaging in anti-competitive actions and price discrimination; and reclassifying LGBT books as adult content.,
#  Criticism has also concerned various decisions over whether to censor or publish content such as the WikiLeaks website, works containing libel and material facilitating dogfight, cockfight, or pedophile activities.,
#  In December 2011, Amazon faced a backlash from small businesses for running a one-day deal to promote its new Price Check app.,
#  Shoppers who used the app to check prices in a brick-and-mortar store were offered a 5% discount to purchase the same item from Amazon.,
#  Companies like Groupon, eBay and Taap.it countered Amazon's promotion by offering $10 off from their products.,
#  The company has also faced accusations of putting undue pressure on suppliers to maintain and extend its profitability.,
#  One effort to squeeze the most vulnerable book publishers was known within the company as the Gazelle Project, after Bezos suggested, according to Brad Stone, "that Amazon should approach these small publishers the way a cheetah would pursue a sickly gazelle.",
#  In July 2014, the Federal Trade Commission launched a lawsuit against the company alleging it was promoting in-app purchases to children, which were being transacted without parental consent.,
#  In 2019, Amazon banned selling skin-lightening and racist products that might affect the consumer's health.,
#  In 2022, a lawsuit filed by state attorney-general Letitia James was dismissed by the New York state court of appeals.]

# %% [markdown]
# ### Step 2: Word frequency table

# %%
word_frequencies = {}
for word in doc:
    if word.text.lower() not in all_stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

word_frequencies
# Out:
# {'Amazon.com': 8,
#  'Inc.': 3,
#  '/ˈæməzɒn/': 1,
#  'ə': 1,
#  'zon': 1,
#  'American': 4,
#  'multinational': 1,
#  'technology': 4,
#  'company': 17,
#  'focuses': 2,
#  'e': 5,
#  'commerce': 3,
#  'cloud': 7,
#  'computing': 9,
#  'online': 8,
#  'advertising': 2,
#  'digital': 3,
#  'streaming': 6,
#  'artificial': 2,
#  'intelligence': 1,
#  'referred': 1,
#  'influential': 1,
#  'economic': 1,
#  'cultural': 1,
#  'forces': 1,
#  'world': 6,
#  'valuable': 1,
#  'brands': 4,
#  'Big': 1,
#  'information': 3,
#  'companies': 7,
#  'alongside': 1,
#  'Alphabet': 1,
#  'Apple': 5,
#  'Meta': 1,
#  'Microsoft': 3,
#  'Amazon': 135,
#  'founded': 4,
#  'Jeff': 4,
#  'Bezos': 10,
#  'garage': 1,
#  'Bellevue': 1,
#  'Washington': 2,
#  'July': 4,
#  '5': 3,
#  '1994': 2,
#  'Initially': 1,
#  'marketplace': 2,
#  'books': 9,
#  'expanded': 3,
#  'multitude': 1,
#  'product': 12,
#  'categories': 2,
#  'strategy': 1,
#  'earned': 2,
#  'moniker': 1,
#  'Store': 1,
#  'multiple': 2,
#  'subsidiaries': 4,
#  'including': 10,
#  'Web': 6,
#  'Services': 5,
#  'Zoox': 2,
#  'autonomous': 1,
#  'vehicles': 1,
#  'Kuiper': 1,
#  'Systems': 3,
#  'satellite': 3,
#  'Internet': 5,
#  'Lab126': 1,
#  'computer': 8,
#  'hardware': 4,
#  'R&D': 1,
#  'include': 6,
#  'Ring': 3,
#  'Twitch': 13,
#  'IMDb': 2,
#  'Foods': 5,
#  'Market': 3,
#  'acquisition': 2,
#  'August': 5,
#  '2017': 4,
#  'US$': 6,
#  '13.4': 1,
#  '\xa0': 20,
#  'billion': 8,
#  'substantially': 1,
#  'increased': 4,
#  'footprint': 1,
#  'physical': 7,
#  'retailer': 4,
#  'reputation': 1,
#  'disruptor': 1,
#  'established': 2,
#  'industries': 1,
#  'technological': 1,
#  'innovation': 1,
#  'aggressive': 1,
#  'reinvestment': 1,
#  'profits': 2,
#  'capital': 1,
#  'expenditures': 1,
#  '2021': 8,
#  'largest': 5,
#  'smart': 3,
#  'speaker': 1,
#  'provider': 2,
#  'service': 20,
#  'AWS': 14,
#  'live': 3,
#  'measured': 1,
#  'revenue': 4,
#  'market': 5,
#  'share': 2,
#  'surpassed': 1,
#  'Walmart': 1,
#  'outside': 1,
#  'China': 1,
#  'driven': 1,
#  'large': 5,
#  'paid': 2,
#  'subscription': 2,
#  'plan': 1,
#  'Prime': 10,
#  '200': 1,
#  'million': 13,
#  'subscribers': 4,
#  'worldwide': 1,
#  'second': 2,
#  'private': 2,
#  'employer': 1,
#  'United': 10,
#  'States': 7,
#  'distributes': 1,
#  'variety': 2,
#  'downloadable': 1,
#  'content': 6,
#  'Video': 2,
#  'Music': 2,
#  'Audible': 3,
#  'units': 3,
#  'publishes': 1,
#  'publishing': 1,
#  'arm': 1,
#  'Publishing': 1,
#  'film': 2,
#  'television': 2,
#  'Studios': 1,
#  'owner': 1,
#  'studio': 1,
#  'Metro': 1,
#  'Goldwyn': 1,
#  'Mayer': 1,
#  'March': 3,
#  '2022': 4,
#  'produces': 1,
#  'consumer': 5,
#  'electronics': 3,
#  '—': 3,
#  'notably': 2,
#  'Kindle': 3,
#  'readers': 2,
#  'Echo': 1,
#  'devices': 2,
#  'Fire': 2,
#  'tablets': 2,
#  'TVs': 1,
#  'criticized': 1,
#  'customer': 7,
#  'data': 8,
#  'collection': 1,
#  'practices': 3,
#  'toxic': 1,
#  'work': 2,
#  'culture': 1,
#  'tax': 1,
#  'avoidance': 1,
#  'anti': 2,
#  'competitive': 3,
#  'behavior': 1,
#  'chose': 1,
#  'Seattle': 3,
#  'area': 2,
#  'abundance': 1,
#  'technical': 1,
#  'talent': 1,
#  'went': 2,
#  'public': 5,
#  '1997': 2,
#  'began': 5,
#  'selling': 5,
#  'music': 4,
#  'videos': 2,
#  '1998': 1,
#  'international': 2,
#  'operations': 1,
#  'acquiring': 1,
#  'sellers': 13,
#  'Kingdom': 2,
#  'Germany': 2,
#  'following': 2,
#  'year': 6,
#  'video': 5,
#  'games': 5,
#  'home': 6,
#  'improvement': 1,
#  'items': 5,
#  'software': 6,
#  'toys': 3,
#  '2002': 1,
#  'launched': 9,
#  'initially': 1,
#  'focused': 1,
#  'providing': 2,
#  'APIs': 2,
#  'web': 6,
#  'developers': 1,
#  'build': 1,
#  'applications': 1,
#  'ecommerce': 3,
#  'platform': 6,
#  '2004': 2,
#  'provide': 5,
#  'website': 13,
#  'popularity': 4,
#  'statistics': 1,
#  'crawler': 1,
#  'Alexa': 3,
#  'Information': 1,
#  'Service': 4,
#  'later': 3,
#  'shifted': 1,
#  'enterprise': 1,
#  'services': 13,
#  'Simple': 1,
#  'Storage': 1,
#  'S3': 1,
#  '2006': 5,
#  'Elastic': 2,
#  'Compute': 2,
#  'Cloud': 3,
#  'EC2': 2,
#  '2008': 3,
#  'allowing': 2,
#  'rent': 1,
#  'storage': 4,
#  'power': 1,
#  'Fulfillment': 2,
#  'program': 3,
#  'allowed': 2,
#  'individuals': 3,
#  'small': 6,
#  'called': 3,
#  'party': 5,
#  'sell': 8,
#  'products': 26,
#  'warehouses': 3,
#  'fulfillment': 11,
#  'infrastructure': 2,
#  'purchased': 3,
#  'supermarket': 2,
#  'chain': 3,
#  '2017.During': 1,
#  'COVID-19': 3,
#  'pandemic': 2,
#  'introduced': 3,
#  'hazard': 2,
#  'pay': 5,
#  '2': 4,
#  'hour': 1,
#  'changes': 1,
#  'overtime': 1,
#  'policy': 2,
#  'unlimited': 1,
#  'unpaid': 1,
#  'time': 5,
#  'April': 2,
#  '30': 2,
#  '2020': 13,
#  'increase': 4,
#  'expired': 1,
#  'June': 6,
#  'temporary': 1,
#  'restrictions': 1,
#  'sale': 4,
#  'non': 2,
#  'essential': 1,
#  'goods': 10,
#  'hired': 1,
#  '100,000': 1,
#  'staff': 1,
#  'Canada': 1,
#  'workers': 2,
#  'France': 2,
#  'Italy': 1,
#  'protested': 1,
#  'decision': 3,
#  'run': 1,
#  'normal': 1,
#  'shifts': 1,
#  'despite': 1,
#  'positive': 2,
#  'cases': 3,
#  'Spain': 1,
#  'faced': 3,
#  'legal': 1,
#  'complaints': 1,
#  'policies': 2,
#  'group': 1,
#  'Senators': 1,
#  'wrote': 1,
#  'open': 3,
#  'letter': 1,
#  'expressing': 1,
#  'concerns': 1,
#  'worker': 1,
#  'safety': 2,
#  'February': 2,
#  'announced': 7,
#  'step': 2,
#  'CEO': 2,
#  'executive': 1,
#  'chair': 1,
#  'board': 2,
#  'Q3': 1,
#  'Andy': 1,
#  'Jassy': 1,
#  'previously': 1,
#  'CEO.Amazon.com': 1,
#  'sells': 2,
#  'lines': 2,
#  'media': 2,
#  'movies': 1,
#  'apparel': 1,
#  'baby': 2,
#  'beauty': 1,
#  'gourmet': 1,
#  'food': 1,
#  'groceries': 1,
#  'health': 2,
#  'personal': 1,
#  'care': 1,
#  'industrial': 1,
#  'scientific': 1,
#  'supplies': 2,
#  'kitchen': 1,
#  'jewelry': 1,
#  'watches': 1,
#  'lawn': 1,
#  'garden': 1,
#  'musical': 1,
#  'instruments': 1,
#  'sporting': 1,
#  'tools': 3,
#  'automotive': 1,
#  'farm': 2,
#  'consulting': 1,
#  'websites': 7,
#  'country': 2,
#  'specific': 2,
#  'example': 1,
#  'amazon.com': 2,
#  'U.S.': 5,
#  'amazon.fr': 1,
#  'offer': 3,
#  'shipping': 3,
#  'Visits': 1,
#  'grew': 1,
#  '615': 1,
#  'annual': 4,
#  'visitors': 1,
#  'month': 2,
#  'invested': 1,
#  'heavily': 1,
#  'server': 4,
#  'capacity': 4,
#  'redundancy': 2,
#  'handle': 2,
#  'traffic': 1,
#  'Christmas': 1,
#  'holiday': 1,
#  'season': 1,
#  '14th': 1,
#  'visited': 2,
#  '2000': 1,
#  'toy': 1,
#  'Toys': 7,
#  'R': 6,
#  'entered': 2,
#  '10': 4,
#  'agreement': 4,
#  'valued': 1,
#  '50': 2,
#  'plus': 1,
#  'cut': 1,
#  'sales': 20,
#  'exclusive': 2,
#  'supplier': 1,
#  'redirect': 1,
#  'Games': 1,
#  'category': 1,
#  'sued': 2,
#  'claiming': 2,
#  'perceived': 1,
#  'lack': 1,
#  'stock': 1,
#  'knowingly': 1,
#  'granted': 1,
#  'exclusivity': 1,
#  'court': 4,
#  'ruled': 2,
#  'favor': 1,
#  'giving': 1,
#  'right': 1,
#  'unwind': 1,
#  'establish': 1,
#  'independent': 1,
#  'awarded': 1,
#  '51': 1,
#  'damages': 1,
#  '2001': 1,
#  'similar': 4,
#  'Borders': 2,
#  'Group': 3,
#  'comanage': 1,
#  'Borders.com': 1,
#  'co': 1,
#  'branded': 4,
#  'pulled': 1,
#  'arrangement': 1,
#  '2007': 4,
#  'plans': 5,
#  'launch': 2,
#  'store': 7,
#  'October': 3,
#  '18': 2,
#  '2011': 2,
#  'partnership': 5,
#  'DC': 1,
#  'Comics': 1,
#  'rights': 1,
#  'popular': 2,
#  'comics': 1,
#  'Superman': 1,
#  'Batman': 1,
#  'Green': 1,
#  'Lantern': 1,
#  'Sandman': 1,
#  'Watchmen': 1,
#  'caused': 1,
#  'known': 7,
#  'bookstores': 3,
#  'like': 3,
#  'Barnes': 1,
#  'Noble': 1,
#  'remove': 1,
#  'titles': 3,
#  'shelves': 1,
#  'November': 7,
#  '2013': 3,
#  'Postal': 2,
#  'begin': 1,
#  'delivering': 1,
#  'orders': 2,
#  'Sundays': 1,
#  'included': 3,
#  'standard': 1,
#  'rates': 1,
#  'initiated': 1,
#  'metropolitan': 1,
#  'areas': 4,
#  'Los': 1,
#  'Angeles': 1,
#  'New': 4,
#  'York': 2,
#  'high': 1,
#  'volume': 1,
#  'inability': 1,
#  'deliver': 3,
#  'timely': 1,
#  'way': 4,
#  'expand': 3,
#  'Dallas': 1,
#  'Houston': 1,
#  'Orleans': 1,
#  'Phoenix': 1,
#  '2014.In': 1,
#  'Nike': 2,
#  'agreed': 1,
#  'exchange': 1,
#  'better': 1,
#  'policing': 1,
#  'counterfeit': 2,
#  'proved': 1,
#  'unsuccessful': 1,
#  'withdrew': 1,
#  '2019': 8,
#  'Companies': 2,
#  'IKEA': 1,
#  'Birkenstock': 1,
#  'stopped': 1,
#  'citing': 1,
#  'frustrations': 1,
#  'business': 2,
#  'September': 5,
#  'ventured': 1,
#  'JV': 1,
#  'Appario': 1,
#  'Retail': 1,
#  'owned': 2,
#  'Patni': 1,
#  'recorded': 2,
#  'total': 2,
#  'income': 1,
#  '\u2009': 4,
#  '104.44': 1,
#  '₹': 1,
#  '759': 1,
#  'crore': 1,
#  'financial': 1,
#  '2017–2018.As': 1,
#  '11': 1,
#  '2017[update': 1,
#  'AmazonFresh': 1,
#  'sold': 3,
#  'range': 1,
#  'Booths': 1,
#  'delivery': 7,
#  'selected': 3,
#  '2018': 2,
#  'reached': 1,
#  'Authorized': 2,
#  'Resellers': 2,
#  'result': 1,
#  'effective': 1,
#  'January': 2,
#  '4': 1,
#  '2019.Amazon': 1,
#  'brand': 2,
#  'names': 1,
#  'phone': 1,
#  'chargers': 1,
#  'batteries': 2,
#  'diaper': 1,
#  'wipes': 1,
#  'AmazonBasics': 1,
#  '2009': 1,
#  'features': 3,
#  'hundreds': 1,
#  'smartphone': 1,
#  'mice': 1,
#  'dumbbells': 1,
#  'dog': 2,
#  'crates': 1,
#  '34': 1,
#  'label': 2,
#  'account': 3,
#  '0.15': 1,
#  'global': 2,
#  'average': 1,
#  'retailers': 2,
#  'retail': 2,
#  'Presto': 1,
#  'Mama': 1,
#  'Bear': 1,
#  'Essentials': 1,
#  'derives': 1,
#  '40': 3,
#  'use': 1,
#  'addition': 1,
#  'processed': 1,
#  'end': 1,
#  'individual': 2,
#  'processing': 5,
#  'order': 2,
#  'leases': 1,
#  'space': 1,
#  'Small': 1,
#  'new': 4,
#  'Marketplace': 1,
#  'fixed': 1,
#  'price': 3,
#  'Publishers': 1,
#  'signup': 1,
#  'affiliates': 1,
#  'receive': 1,
#  'commission': 2,
#  'referring': 1,
#  'customers': 7,
#  'placing': 3,
#  'links': 1,
#  'referral': 1,
#  'results': 2,
#  'Worldwide': 1,
#  '900,000': 1,
#  'members': 2,
#  'affiliate': 2,
#  'programs': 1,
#  'middle': 1,
#  '2014': 5,
#  'Affiliate': 1,
#  'Program': 1,
#  '1.2': 1,
#  'network': 3,
#  'Google': 2,
#  'Ads': 1,
#  'frequently': 1,
#  'supporters': 1,
#  'earn': 1,
#  'Associates': 2,
#  'access': 1,
#  'catalog': 2,
#  'directly': 4,
#  'XML': 1,
#  'aStore': 1,
#  'allows': 5,
#  'embed': 1,
#  'subset': 1,
#  'linked': 1,
#  '2010': 2,
#  'Seller': 1,
#  'Product': 1,
#  'Suggestions': 1,
#  'rumored': 1,
#  'internally': 1,
#  'Project': 2,
#  'Genesis': 1,
#  'transparency': 1,
#  'recommending': 1,
#  'Products': 2,
#  'suggested': 2,
#  'based': 6,
#  'browsing': 1,
#  'history': 1,
#  'bigger': 1,
#  'local': 2,
#  'Singapore': 1,
#  'selection': 1,
#  'face': 1,
#  'intensifying': 1,
#  'competition': 1,
#  'competitors': 2,
#  'region': 1,
#  '3rd': 1,
#  'City': 1,
#  'Court': 1,
#  'Appeals': 1,
#  'Philadelphia': 1,
#  'held': 3,
#  'accountable': 1,
#  'faulty': 1,
#  'ran': 1,
#  'counter': 1,
#  'past': 1,
#  'lower': 2,
#  'ruling': 1,
#  'favored': 1,
#  'Heather': 1,
#  'Oberdorf': 1,
#  '2016': 1,
#  'leash': 2,
#  'snapped': 1,
#  'causing': 1,
#  'permanent': 1,
#  'loss': 1,
#  'vision': 1,
#  'eye': 1,
#  'upheld': 1,
#  'expose': 2,
#  'businesses': 2,
#  'strict': 1,
#  'liability': 1,
#  'lawsuits': 1,
#  'defective': 2,
#  'represents': 1,
#  'major': 2,
#  'change': 1,
#  'law': 2,
#  'panel': 1,
#  'sent': 1,
#  'case': 1,
#  'decide': 1,
#  'users': 5,
#  'submit': 1,
#  'reviews': 8,
#  'page': 2,
#  'Reviewers': 1,
#  'rate': 2,
#  'rating': 1,
#  'scale': 2,
#  'stars': 1,
#  'provides': 6,
#  'badging': 1,
#  'option': 1,
#  'reviewers': 2,
#  'indicates': 3,
#  'real': 3,
#  'reviewer': 2,
#  'confirmation': 1,
#  'credit': 1,
#  'card': 1,
#  'December': 5,
#  '16': 1,
#  'removed': 1,
#  'ability': 1,
#  'comment': 1,
#  'purged': 1,
#  'posted': 2,
#  'review': 4,
#  'comments': 2,
#  'email': 2,
#  'gave': 2,
#  'rationale': 1,
#  'removing': 1,
#  'feature': 4,
#  '...': 3,
#  'rarely': 1,
#  'remaining': 1,
#  'response': 1,
#  'options': 2,
#  'indicate': 1,
#  'reader': 1,
#  'finds': 1,
#  'helpful': 2,
#  'report': 1,
#  'violates': 1,
#  'abuse': 1,
#  'given': 2,
#  'hits': 1,
#  'appears': 1,
#  'reported': 4,
#  'single': 2,
#  'source': 2,
#  'publishers': 5,
#  'asked': 1,
#  'publish': 2,
#  'negative': 2,
#  'defended': 1,
#  'practice': 1,
#  'taking': 2,
#  'different': 2,
#  'approach': 2,
#  'want': 1,
#  'book': 4,
#  'available': 3,
#  'good': 1,
#  'bad': 1,
#  'ugly': 1,
#  'let': 1,
#  'truth': 1,
#  'loose"': 1,
#  'written': 1,
#  'relations': 1,
#  'behalf': 1,
#  'clients': 1,
#  'instances': 1,
#  'writers': 1,
#  'pseudonyms': 1,
#  'leave': 1,
#  'rivals': 1,
#  'worksThe': 1,
#  'rank': 3,
#  'ASR': 4,
#  'locale': 1,
#  'relative': 1,
#  'indicator': 1,
#  'updated': 1,
#  'hourly': 1,
#  'Effectively': 1,
#  'best': 1,
#  'list': 1,
#  'millions': 1,
#  'stocked': 1,
#  'direct': 1,
#  'effect': 1,
#  'determine': 1,
#  'bestsellers': 1,
#  'lists': 4,
#  'appear': 1,
#  'enjoy': 1,
#  'additional': 2,
#  'exposure': 2,
#  'lead': 2,
#  'particular': 1,
#  'experience': 1,
#  'jumps': 1,
#  'ranks': 1,
#  'movers': 1,
#  'shakers': 1,
#  'listing': 1,
#  'reasons': 1,
#  'release': 3,
#  'actual': 2,
#  'figures': 2,
#  'begun': 1,
#  'point': 1,
#  'Nielsen': 1,
#  'BookScan': 1,
#  'verified': 1,
#  'authors': 1,
#  'speculation': 2,
#  'manufacturers': 1,
#  'marketers': 1,
#  'details': 1,
#  'calculation': 1,
#  'algorithm': 1,
#  'analyzed': 1,
#  'generate': 2,
#  'estimates': 1,
#  'states': 1,
#  'mind': 1,
#  'simply': 1,
#  'meant': 1,
#  'guide': 1,
#  'general': 3,
#  'interest': 2,
#  'definitive': 1,
#  'assume': 1,
#  'regularly': 1,
#  'distribution': 5,
#  'sources"Search': 1,
#  'Inside': 1,
#  'Book': 1,
#  'search': 2,
#  'keywords': 1,
#  'text': 2,
#  'started': 2,
#  '120,000': 1,
#  '33': 2,
#  'pages': 1,
#  '23': 1,
#  '2003.In': 1,
#  'dedicated': 2,
#  'prescription': 1,
#  'drugs': 3,
#  'discounts': 2,
#  '80': 1,
#  'generic': 1,
#  'subscribe': 1,
#  '50,000': 1,
#  'bricks': 1,
#  'mortar': 3,
#  'pharmacies': 1,
#  '2015': 2,
#  'opened': 2,
#  'Books': 1,
#  'University': 1,
#  'Village': 1,
#  '5,500': 1,
#  'square': 1,
#  'feet': 1,
#  'prices': 2,
#  'match': 1,
#  'tenth': 1,
#  'suggests': 1,
#  'eventually': 2,
#  'roll': 1,
#  '300': 1,
#  '400': 1,
#  'planned': 1,
#  'brick': 2,
#  'applied': 1,
#  'liquor': 1,
#  'San': 2,
#  'Francisco': 1,
#  'means': 1,
#  'ship': 1,
#  'beer': 1,
#  'alcohol': 1,
#  'city': 1,
#  'Fresh': 1,
#  'stores': 1,
#  'Luxury': 1,
#  'Stores': 1,
#  'mobile': 1,
#  'app': 4,
#  'Oscar': 1,
#  'de': 2,
#  'la': 1,
#  'Renta': 1,
#  'partner': 1,
#  'firm': 2,
#  'subsidiary': 2,
#  'demand': 1,
#  'platforms': 1,
#  'governments': 2,
#  'metered': 1,
#  'basis': 1,
#  'distributed': 1,
#  'farms': 2,
#  'disposal': 1,
#  'virtual': 4,
#  'cluster': 1,
#  'computers': 3,
#  'emulate': 1,
#  'attributes': 1,
#  'central': 2,
#  'CPUs': 1,
#  'graphics': 1,
#  'GPUs': 1,
#  'RAM': 1,
#  'memory': 1,
#  'hard': 1,
#  'disk': 1,
#  'SSD': 1,
#  'choice': 1,
#  'operating': 2,
#  'systems': 2,
#  'networking': 2,
#  'pre': 1,
#  'loaded': 1,
#  'application': 1,
#  'servers': 1,
#  'databases': 1,
#  'relationship': 1,
#  'management': 2,
#  'CRM).AWS': 1,
#  'delivered': 1,
#  'located': 1,
#  'Fees': 1,
#  'combination': 1,
#  'usage': 3,
#  'Pay': 1,
#  'model': 2,
#  'system': 1,
#  'chosen': 1,
#  'subscriber': 2,
#  'required': 1,
#  'availability': 1,
#  'security': 6,
#  'Subscribers': 1,
#  'clusters': 1,
#  'select': 1,
#  'portions': 1,
#  'e.g.': 2,
#  'centers': 9,
#  'aspects': 1,
#  'responsibility': 1,
#  'vulnerability': 1,
#  'scanning': 1,
#  'patching': 1,
#  'operates': 1,
#  'geographical': 1,
#  'regions': 1,
#  '6': 1,
#  'North': 1,
#  'America': 1,
#  'markets': 1,
#  'obtaining': 1,
#  'quickly': 1,
#  'cheaply': 1,
#  'building': 1,
#  'billed': 1,
#  'measures': 1,
#  'varying': 1,
#  'ways': 1,
#  'Q4': 1,
#  'Azure': 1,
#  '21': 1,
#  'respectively': 2,
#  'according': 2,
#  'Synergy': 1,
#  'number': 1,
#  'assistant': 1,
#  'Appstore': 1,
#  'Android': 1,
#  'apps': 1,
#  'line': 1,
#  'audiobooks': 1,
#  'purchase': 2,
#  'listening': 1,
#  'Astro': 1,
#  'household': 1,
#  'robot': 1,
#  'powered': 2,
#  'remote': 1,
#  'controlled': 1,
#  'check': 2,
#  'pets': 1,
#  'people': 2,
#  'send': 1,
#  'owners': 1,
#  'notification': 1,
#  'detects': 1,
#  'unusual': 1,
#  'uses': 1,
#  'transportation': 2,
#  'packages': 3,
#  'employs': 1,
#  'bulk': 1,
#  'staffed': 1,
#  'Hub': 1,
#  'Locker+': 1,
#  'locations': 2,
#  'stations': 2,
#  'drivers': 2,
#  'pick': 1,
#  'hiring': 2,
#  'employees': 3,
#  'Rakuten': 1,
#  ...}

# %%
max_freq = max(word_frequencies.values())
max_freq
# Out:
# 135

# %%
# normalizing the word frequencies
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_freq

word_frequencies
# Out:
# {'Amazon.com': 0.05925925925925926,
#  'Inc.': 0.022222222222222223,
#  '/ˈæməzɒn/': 0.007407407407407408,
#  'ə': 0.007407407407407408,
#  'zon': 0.007407407407407408,
#  'American': 0.02962962962962963,
#  'multinational': 0.007407407407407408,
#  'technology': 0.02962962962962963,
#  'company': 0.1259259259259259,
#  'focuses': 0.014814814814814815,
#  'e': 0.037037037037037035,
#  'commerce': 0.022222222222222223,
#  'cloud': 0.05185185185185185,
#  'computing': 0.06666666666666667,
#  'online': 0.05925925925925926,
#  'advertising': 0.014814814814814815,
#  'digital': 0.022222222222222223,
#  'streaming': 0.044444444444444446,
#  'artificial': 0.014814814814814815,
#  'intelligence': 0.007407407407407408,
#  'referred': 0.007407407407407408,
#  'influential': 0.007407407407407408,
#  'economic': 0.007407407407407408,
#  'cultural': 0.007407407407407408,
#  'forces': 0.007407407407407408,
#  'world': 0.044444444444444446,
#  'valuable': 0.007407407407407408,
#  'brands': 0.02962962962962963,
#  'Big': 0.007407407407407408,
#  'information': 0.022222222222222223,
#  'companies': 0.05185185185185185,
#  'alongside': 0.007407407407407408,
#  'Alphabet': 0.007407407407407408,
#  'Apple': 0.037037037037037035,
#  'Meta': 0.007407407407407408,
#  'Microsoft': 0.022222222222222223,
#  'Amazon': 1.0,
#  'founded': 0.02962962962962963,
#  'Jeff': 0.02962962962962963,
#  'Bezos': 0.07407407407407407,
#  'garage': 0.007407407407407408,
#  'Bellevue': 0.007407407407407408,
#  'Washington': 0.014814814814814815,
#  'July': 0.02962962962962963,
#  '5': 0.022222222222222223,
#  '1994': 0.014814814814814815,
#  'Initially': 0.007407407407407408,
#  'marketplace': 0.014814814814814815,
#  'books': 0.06666666666666667,
#  'expanded': 0.022222222222222223,
#  'multitude': 0.007407407407407408,
#  'product': 0.08888888888888889,
#  'categories': 0.014814814814814815,
#  'strategy': 0.007407407407407408,
#  'earned': 0.014814814814814815,
#  'moniker': 0.007407407407407408,
#  'Store': 0.007407407407407408,
#  'multiple': 0.014814814814814815,
#  'subsidiaries': 0.02962962962962963,
#  'including': 0.07407407407407407,
#  'Web': 0.044444444444444446,
#  'Services': 0.037037037037037035,
#  'Zoox': 0.014814814814814815,
#  'autonomous': 0.007407407407407408,
#  'vehicles': 0.007407407407407408,
#  'Kuiper': 0.007407407407407408,
#  'Systems': 0.022222222222222223,
#  'satellite': 0.022222222222222223,
#  'Internet': 0.037037037037037035,
#  'Lab126': 0.007407407407407408,
#  'computer': 0.05925925925925926,
#  'hardware': 0.02962962962962963,
#  'R&D': 0.007407407407407408,
#  'include': 0.044444444444444446,
#  'Ring': 0.022222222222222223,
#  'Twitch': 0.0962962962962963,
#  'IMDb': 0.014814814814814815,
#  'Foods': 0.037037037037037035,
#  'Market': 0.022222222222222223,
#  'acquisition': 0.014814814814814815,
#  'August': 0.037037037037037035,
#  '2017': 0.02962962962962963,
#  'US$': 0.044444444444444446,
#  '13.4': 0.007407407407407408,
#  '\xa0': 0.14814814814814814,
#  'billion': 0.05925925925925926,
#  'substantially': 0.007407407407407408,
#  'increased': 0.02962962962962963,
#  'footprint': 0.007407407407407408,
#  'physical': 0.05185185185185185,
#  'retailer': 0.02962962962962963,
#  'reputation': 0.007407407407407408,
#  'disruptor': 0.007407407407407408,
#  'established': 0.014814814814814815,
#  'industries': 0.007407407407407408,
#  'technological': 0.007407407407407408,
#  'innovation': 0.007407407407407408,
#  'aggressive': 0.007407407407407408,
#  'reinvestment': 0.007407407407407408,
#  'profits': 0.014814814814814815,
#  'capital': 0.007407407407407408,
#  'expenditures': 0.007407407407407408,
#  '2021': 0.05925925925925926,
#  'largest': 0.037037037037037035,
#  'smart': 0.022222222222222223,
#  'speaker': 0.007407407407407408,
#  'provider': 0.014814814814814815,
#  'service': 0.14814814814814814,
#  'AWS': 0.1037037037037037,
#  'live': 0.022222222222222223,
#  'measured': 0.007407407407407408,
#  'revenue': 0.02962962962962963,
#  'market': 0.037037037037037035,
#  'share': 0.014814814814814815,
#  'surpassed': 0.007407407407407408,
#  'Walmart': 0.007407407407407408,
#  'outside': 0.007407407407407408,
#  'China': 0.007407407407407408,
#  'driven': 0.007407407407407408,
#  'large': 0.037037037037037035,
#  'paid': 0.014814814814814815,
#  'subscription': 0.014814814814814815,
#  'plan': 0.007407407407407408,
#  'Prime': 0.07407407407407407,
#  '200': 0.007407407407407408,
#  'million': 0.0962962962962963,
#  'subscribers': 0.02962962962962963,
#  'worldwide': 0.007407407407407408,
#  'second': 0.014814814814814815,
#  'private': 0.014814814814814815,
#  'employer': 0.007407407407407408,
#  'United': 0.07407407407407407,
#  'States': 0.05185185185185185,
#  'distributes': 0.007407407407407408,
#  'variety': 0.014814814814814815,
#  'downloadable': 0.007407407407407408,
#  'content': 0.044444444444444446,
#  'Video': 0.014814814814814815,
#  'Music': 0.014814814814814815,
#  'Audible': 0.022222222222222223,
#  'units': 0.022222222222222223,
#  'publishes': 0.007407407407407408,
#  'publishing': 0.007407407407407408,
#  'arm': 0.007407407407407408,
#  'Publishing': 0.007407407407407408,
#  'film': 0.014814814814814815,
#  'television': 0.014814814814814815,
#  'Studios': 0.007407407407407408,
#  'owner': 0.007407407407407408,
#  'studio': 0.007407407407407408,
#  'Metro': 0.007407407407407408,
#  'Goldwyn': 0.007407407407407408,
#  'Mayer': 0.007407407407407408,
#  'March': 0.022222222222222223,
#  '2022': 0.02962962962962963,
#  'produces': 0.007407407407407408,
#  'consumer': 0.037037037037037035,
#  'electronics': 0.022222222222222223,
#  '—': 0.022222222222222223,
#  'notably': 0.014814814814814815,
#  'Kindle': 0.022222222222222223,
#  'readers': 0.014814814814814815,
#  'Echo': 0.007407407407407408,
#  'devices': 0.014814814814814815,
#  'Fire': 0.014814814814814815,
#  'tablets': 0.014814814814814815,
#  'TVs': 0.007407407407407408,
#  'criticized': 0.007407407407407408,
#  'customer': 0.05185185185185185,
#  'data': 0.05925925925925926,
#  'collection': 0.007407407407407408,
#  'practices': 0.022222222222222223,
#  'toxic': 0.007407407407407408,
#  'work': 0.014814814814814815,
#  'culture': 0.007407407407407408,
#  'tax': 0.007407407407407408,
#  'avoidance': 0.007407407407407408,
#  'anti': 0.014814814814814815,
#  'competitive': 0.022222222222222223,
#  'behavior': 0.007407407407407408,
#  'chose': 0.007407407407407408,
#  'Seattle': 0.022222222222222223,
#  'area': 0.014814814814814815,
#  'abundance': 0.007407407407407408,
#  'technical': 0.007407407407407408,
#  'talent': 0.007407407407407408,
#  'went': 0.014814814814814815,
#  'public': 0.037037037037037035,
#  '1997': 0.014814814814814815,
#  'began': 0.037037037037037035,
#  'selling': 0.037037037037037035,
#  'music': 0.02962962962962963,
#  'videos': 0.014814814814814815,
#  '1998': 0.007407407407407408,
#  'international': 0.014814814814814815,
#  'operations': 0.007407407407407408,
#  'acquiring': 0.007407407407407408,
#  'sellers': 0.0962962962962963,
#  'Kingdom': 0.014814814814814815,
#  'Germany': 0.014814814814814815,
#  'following': 0.014814814814814815,
#  'year': 0.044444444444444446,
#  'video': 0.037037037037037035,
#  'games': 0.037037037037037035,
#  'home': 0.044444444444444446,
#  'improvement': 0.007407407407407408,
#  'items': 0.037037037037037035,
#  'software': 0.044444444444444446,
#  'toys': 0.022222222222222223,
#  '2002': 0.007407407407407408,
#  'launched': 0.06666666666666667,
#  'initially': 0.007407407407407408,
#  'focused': 0.007407407407407408,
#  'providing': 0.014814814814814815,
#  'APIs': 0.014814814814814815,
#  'web': 0.044444444444444446,
#  'developers': 0.007407407407407408,
#  'build': 0.007407407407407408,
#  'applications': 0.007407407407407408,
#  'ecommerce': 0.022222222222222223,
#  'platform': 0.044444444444444446,
#  '2004': 0.014814814814814815,
#  'provide': 0.037037037037037035,
#  'website': 0.0962962962962963,
#  'popularity': 0.02962962962962963,
#  'statistics': 0.007407407407407408,
#  'crawler': 0.007407407407407408,
#  'Alexa': 0.022222222222222223,
#  'Information': 0.007407407407407408,
#  'Service': 0.02962962962962963,
#  'later': 0.022222222222222223,
#  'shifted': 0.007407407407407408,
#  'enterprise': 0.007407407407407408,
#  'services': 0.0962962962962963,
#  'Simple': 0.007407407407407408,
#  'Storage': 0.007407407407407408,
#  'S3': 0.007407407407407408,
#  '2006': 0.037037037037037035,
#  'Elastic': 0.014814814814814815,
#  'Compute': 0.014814814814814815,
#  'Cloud': 0.022222222222222223,
#  'EC2': 0.014814814814814815,
#  '2008': 0.022222222222222223,
#  'allowing': 0.014814814814814815,
#  'rent': 0.007407407407407408,
#  'storage': 0.02962962962962963,
#  'power': 0.007407407407407408,
#  'Fulfillment': 0.014814814814814815,
#  'program': 0.022222222222222223,
#  'allowed': 0.014814814814814815,
#  'individuals': 0.022222222222222223,
#  'small': 0.044444444444444446,
#  'called': 0.022222222222222223,
#  'party': 0.037037037037037035,
#  'sell': 0.05925925925925926,
#  'products': 0.1925925925925926,
#  'warehouses': 0.022222222222222223,
#  'fulfillment': 0.08148148148148149,
#  'infrastructure': 0.014814814814814815,
#  'purchased': 0.022222222222222223,
#  'supermarket': 0.014814814814814815,
#  'chain': 0.022222222222222223,
#  '2017.During': 0.007407407407407408,
#  'COVID-19': 0.022222222222222223,
#  'pandemic': 0.014814814814814815,
#  'introduced': 0.022222222222222223,
#  'hazard': 0.014814814814814815,
#  'pay': 0.037037037037037035,
#  '2': 0.02962962962962963,
#  'hour': 0.007407407407407408,
#  'changes': 0.007407407407407408,
#  'overtime': 0.007407407407407408,
#  'policy': 0.014814814814814815,
#  'unlimited': 0.007407407407407408,
#  'unpaid': 0.007407407407407408,
#  'time': 0.037037037037037035,
#  'April': 0.014814814814814815,
#  '30': 0.014814814814814815,
#  '2020': 0.0962962962962963,
#  'increase': 0.02962962962962963,
#  'expired': 0.007407407407407408,
#  'June': 0.044444444444444446,
#  'temporary': 0.007407407407407408,
#  'restrictions': 0.007407407407407408,
#  'sale': 0.02962962962962963,
#  'non': 0.014814814814814815,
#  'essential': 0.007407407407407408,
#  'goods': 0.07407407407407407,
#  'hired': 0.007407407407407408,
#  '100,000': 0.007407407407407408,
#  'staff': 0.007407407407407408,
#  'Canada': 0.007407407407407408,
#  'workers': 0.014814814814814815,
#  'France': 0.014814814814814815,
#  'Italy': 0.007407407407407408,
#  'protested': 0.007407407407407408,
#  'decision': 0.022222222222222223,
#  'run': 0.007407407407407408,
#  'normal': 0.007407407407407408,
#  'shifts': 0.007407407407407408,
#  'despite': 0.007407407407407408,
#  'positive': 0.014814814814814815,
#  'cases': 0.022222222222222223,
#  'Spain': 0.007407407407407408,
#  'faced': 0.022222222222222223,
#  'legal': 0.007407407407407408,
#  'complaints': 0.007407407407407408,
#  'policies': 0.014814814814814815,
#  'group': 0.007407407407407408,
#  'Senators': 0.007407407407407408,
#  'wrote': 0.007407407407407408,
#  'open': 0.022222222222222223,
#  'letter': 0.007407407407407408,
#  'expressing': 0.007407407407407408,
#  'concerns': 0.007407407407407408,
#  'worker': 0.007407407407407408,
#  'safety': 0.014814814814814815,
#  'February': 0.014814814814814815,
#  'announced': 0.05185185185185185,
#  'step': 0.014814814814814815,
#  'CEO': 0.014814814814814815,
#  'executive': 0.007407407407407408,
#  'chair': 0.007407407407407408,
#  'board': 0.014814814814814815,
#  'Q3': 0.007407407407407408,
#  'Andy': 0.007407407407407408,
#  'Jassy': 0.007407407407407408,
#  'previously': 0.007407407407407408,
#  'CEO.Amazon.com': 0.007407407407407408,
#  'sells': 0.014814814814814815,
#  'lines': 0.014814814814814815,
#  'media': 0.014814814814814815,
#  'movies': 0.007407407407407408,
#  'apparel': 0.007407407407407408,
#  'baby': 0.014814814814814815,
#  'beauty': 0.007407407407407408,
#  'gourmet': 0.007407407407407408,
#  'food': 0.007407407407407408,
#  'groceries': 0.007407407407407408,
#  'health': 0.014814814814814815,
#  'personal': 0.007407407407407408,
#  'care': 0.007407407407407408,
#  'industrial': 0.007407407407407408,
#  'scientific': 0.007407407407407408,
#  'supplies': 0.014814814814814815,
#  'kitchen': 0.007407407407407408,
#  'jewelry': 0.007407407407407408,
#  'watches': 0.007407407407407408,
#  'lawn': 0.007407407407407408,
#  'garden': 0.007407407407407408,
#  'musical': 0.007407407407407408,
#  'instruments': 0.007407407407407408,
#  'sporting': 0.007407407407407408,
#  'tools': 0.022222222222222223,
#  'automotive': 0.007407407407407408,
#  'farm': 0.014814814814814815,
#  'consulting': 0.007407407407407408,
#  'websites': 0.05185185185185185,
#  'country': 0.014814814814814815,
#  'specific': 0.014814814814814815,
#  'example': 0.007407407407407408,
#  'amazon.com': 0.014814814814814815,
#  'U.S.': 0.037037037037037035,
#  'amazon.fr': 0.007407407407407408,
#  'offer': 0.022222222222222223,
#  'shipping': 0.022222222222222223,
#  'Visits': 0.007407407407407408,
#  'grew': 0.007407407407407408,
#  '615': 0.007407407407407408,
#  'annual': 0.02962962962962963,
#  'visitors': 0.007407407407407408,
#  'month': 0.014814814814814815,
#  'invested': 0.007407407407407408,
#  'heavily': 0.007407407407407408,
#  'server': 0.02962962962962963,
#  'capacity': 0.02962962962962963,
#  'redundancy': 0.014814814814814815,
#  'handle': 0.014814814814814815,
#  'traffic': 0.007407407407407408,
#  'Christmas': 0.007407407407407408,
#  'holiday': 0.007407407407407408,
#  'season': 0.007407407407407408,
#  '14th': 0.007407407407407408,
#  'visited': 0.014814814814814815,
#  '2000': 0.007407407407407408,
#  'toy': 0.007407407407407408,
#  'Toys': 0.05185185185185185,
#  'R': 0.044444444444444446,
#  'entered': 0.014814814814814815,
#  '10': 0.02962962962962963,
#  'agreement': 0.02962962962962963,
#  'valued': 0.007407407407407408,
#  '50': 0.014814814814814815,
#  'plus': 0.007407407407407408,
#  'cut': 0.007407407407407408,
#  'sales': 0.14814814814814814,
#  'exclusive': 0.014814814814814815,
#  'supplier': 0.007407407407407408,
#  'redirect': 0.007407407407407408,
#  'Games': 0.007407407407407408,
#  'category': 0.007407407407407408,
#  'sued': 0.014814814814814815,
#  'claiming': 0.014814814814814815,
#  'perceived': 0.007407407407407408,
#  'lack': 0.007407407407407408,
#  'stock': 0.007407407407407408,
#  'knowingly': 0.007407407407407408,
#  'granted': 0.007407407407407408,
#  'exclusivity': 0.007407407407407408,
#  'court': 0.02962962962962963,
#  'ruled': 0.014814814814814815,
#  'favor': 0.007407407407407408,
#  'giving': 0.007407407407407408,
#  'right': 0.007407407407407408,
#  'unwind': 0.007407407407407408,
#  'establish': 0.007407407407407408,
#  'independent': 0.007407407407407408,
#  'awarded': 0.007407407407407408,
#  '51': 0.007407407407407408,
#  'damages': 0.007407407407407408,
#  '2001': 0.007407407407407408,
#  'similar': 0.02962962962962963,
#  'Borders': 0.014814814814814815,
#  'Group': 0.022222222222222223,
#  'comanage': 0.007407407407407408,
#  'Borders.com': 0.007407407407407408,
#  'co': 0.007407407407407408,
#  'branded': 0.02962962962962963,
#  'pulled': 0.007407407407407408,
#  'arrangement': 0.007407407407407408,
#  '2007': 0.02962962962962963,
#  'plans': 0.037037037037037035,
#  'launch': 0.014814814814814815,
#  'store': 0.05185185185185185,
#  'October': 0.022222222222222223,
#  '18': 0.014814814814814815,
#  '2011': 0.014814814814814815,
#  'partnership': 0.037037037037037035,
#  'DC': 0.007407407407407408,
#  'Comics': 0.007407407407407408,
#  'rights': 0.007407407407407408,
#  'popular': 0.014814814814814815,
#  'comics': 0.007407407407407408,
#  'Superman': 0.007407407407407408,
#  'Batman': 0.007407407407407408,
#  'Green': 0.007407407407407408,
#  'Lantern': 0.007407407407407408,
#  'Sandman': 0.007407407407407408,
#  'Watchmen': 0.007407407407407408,
#  'caused': 0.007407407407407408,
#  'known': 0.05185185185185185,
#  'bookstores': 0.022222222222222223,
#  'like': 0.022222222222222223,
#  'Barnes': 0.007407407407407408,
#  'Noble': 0.007407407407407408,
#  'remove': 0.007407407407407408,
#  'titles': 0.022222222222222223,
#  'shelves': 0.007407407407407408,
#  'November': 0.05185185185185185,
#  '2013': 0.022222222222222223,
#  'Postal': 0.014814814814814815,
#  'begin': 0.007407407407407408,
#  'delivering': 0.007407407407407408,
#  'orders': 0.014814814814814815,
#  'Sundays': 0.007407407407407408,
#  'included': 0.022222222222222223,
#  'standard': 0.007407407407407408,
#  'rates': 0.007407407407407408,
#  'initiated': 0.007407407407407408,
#  'metropolitan': 0.007407407407407408,
#  'areas': 0.02962962962962963,
#  'Los': 0.007407407407407408,
#  'Angeles': 0.007407407407407408,
#  'New': 0.02962962962962963,
#  'York': 0.014814814814814815,
#  'high': 0.007407407407407408,
#  'volume': 0.007407407407407408,
#  'inability': 0.007407407407407408,
#  'deliver': 0.022222222222222223,
#  'timely': 0.007407407407407408,
#  'way': 0.02962962962962963,
#  'expand': 0.022222222222222223,
#  'Dallas': 0.007407407407407408,
#  'Houston': 0.007407407407407408,
#  'Orleans': 0.007407407407407408,
#  'Phoenix': 0.007407407407407408,
#  '2014.In': 0.007407407407407408,
#  'Nike': 0.014814814814814815,
#  'agreed': 0.007407407407407408,
#  'exchange': 0.007407407407407408,
#  'better': 0.007407407407407408,
#  'policing': 0.007407407407407408,
#  'counterfeit': 0.014814814814814815,
#  'proved': 0.007407407407407408,
#  'unsuccessful': 0.007407407407407408,
#  'withdrew': 0.007407407407407408,
#  '2019': 0.05925925925925926,
#  'Companies': 0.014814814814814815,
#  'IKEA': 0.007407407407407408,
#  'Birkenstock': 0.007407407407407408,
#  'stopped': 0.007407407407407408,
#  'citing': 0.007407407407407408,
#  'frustrations': 0.007407407407407408,
#  'business': 0.014814814814814815,
#  'September': 0.037037037037037035,
#  'ventured': 0.007407407407407408,
#  'JV': 0.007407407407407408,
#  'Appario': 0.007407407407407408,
#  'Retail': 0.007407407407407408,
#  'owned': 0.014814814814814815,
#  'Patni': 0.007407407407407408,
#  'recorded': 0.014814814814814815,
#  'total': 0.014814814814814815,
#  'income': 0.007407407407407408,
#  '\u2009': 0.02962962962962963,
#  '104.44': 0.007407407407407408,
#  '₹': 0.007407407407407408,
#  '759': 0.007407407407407408,
#  'crore': 0.007407407407407408,
#  'financial': 0.007407407407407408,
#  '2017–2018.As': 0.007407407407407408,
#  '11': 0.007407407407407408,
#  '2017[update': 0.007407407407407408,
#  'AmazonFresh': 0.007407407407407408,
#  'sold': 0.022222222222222223,
#  'range': 0.007407407407407408,
#  'Booths': 0.007407407407407408,
#  'delivery': 0.05185185185185185,
#  'selected': 0.022222222222222223,
#  '2018': 0.014814814814814815,
#  'reached': 0.007407407407407408,
#  'Authorized': 0.014814814814814815,
#  'Resellers': 0.014814814814814815,
#  'result': 0.007407407407407408,
#  'effective': 0.007407407407407408,
#  'January': 0.014814814814814815,
#  '4': 0.007407407407407408,
#  '2019.Amazon': 0.007407407407407408,
#  'brand': 0.014814814814814815,
#  'names': 0.007407407407407408,
#  'phone': 0.007407407407407408,
#  'chargers': 0.007407407407407408,
#  'batteries': 0.014814814814814815,
#  'diaper': 0.007407407407407408,
#  'wipes': 0.007407407407407408,
#  'AmazonBasics': 0.007407407407407408,
#  '2009': 0.007407407407407408,
#  'features': 0.022222222222222223,
#  'hundreds': 0.007407407407407408,
#  'smartphone': 0.007407407407407408,
#  'mice': 0.007407407407407408,
#  'dumbbells': 0.007407407407407408,
#  'dog': 0.014814814814814815,
#  'crates': 0.007407407407407408,
#  '34': 0.007407407407407408,
#  'label': 0.014814814814814815,
#  'account': 0.022222222222222223,
#  '0.15': 0.007407407407407408,
#  'global': 0.014814814814814815,
#  'average': 0.007407407407407408,
#  'retailers': 0.014814814814814815,
#  'retail': 0.014814814814814815,
#  'Presto': 0.007407407407407408,
#  'Mama': 0.007407407407407408,
#  'Bear': 0.007407407407407408,
#  'Essentials': 0.007407407407407408,
#  'derives': 0.007407407407407408,
#  '40': 0.022222222222222223,
#  'use': 0.007407407407407408,
#  'addition': 0.007407407407407408,
#  'processed': 0.007407407407407408,
#  'end': 0.007407407407407408,
#  'individual': 0.014814814814814815,
#  'processing': 0.037037037037037035,
#  'order': 0.014814814814814815,
#  'leases': 0.007407407407407408,
#  'space': 0.007407407407407408,
#  'Small': 0.007407407407407408,
#  'new': 0.02962962962962963,
#  'Marketplace': 0.007407407407407408,
#  'fixed': 0.007407407407407408,
#  'price': 0.022222222222222223,
#  'Publishers': 0.007407407407407408,
#  'signup': 0.007407407407407408,
#  'affiliates': 0.007407407407407408,
#  'receive': 0.007407407407407408,
#  'commission': 0.014814814814814815,
#  'referring': 0.007407407407407408,
#  'customers': 0.05185185185185185,
#  'placing': 0.022222222222222223,
#  'links': 0.007407407407407408,
#  'referral': 0.007407407407407408,
#  'results': 0.014814814814814815,
#  'Worldwide': 0.007407407407407408,
#  '900,000': 0.007407407407407408,
#  'members': 0.014814814814814815,
#  'affiliate': 0.014814814814814815,
#  'programs': 0.007407407407407408,
#  'middle': 0.007407407407407408,
#  '2014': 0.037037037037037035,
#  'Affiliate': 0.007407407407407408,
#  'Program': 0.007407407407407408,
#  '1.2': 0.007407407407407408,
#  'network': 0.022222222222222223,
#  'Google': 0.014814814814814815,
#  'Ads': 0.007407407407407408,
#  'frequently': 0.007407407407407408,
#  'supporters': 0.007407407407407408,
#  'earn': 0.007407407407407408,
#  'Associates': 0.014814814814814815,
#  'access': 0.007407407407407408,
#  'catalog': 0.014814814814814815,
#  'directly': 0.02962962962962963,
#  'XML': 0.007407407407407408,
#  'aStore': 0.007407407407407408,
#  'allows': 0.037037037037037035,
#  'embed': 0.007407407407407408,
#  'subset': 0.007407407407407408,
#  'linked': 0.007407407407407408,
#  '2010': 0.014814814814814815,
#  'Seller': 0.007407407407407408,
#  'Product': 0.007407407407407408,
#  'Suggestions': 0.007407407407407408,
#  'rumored': 0.007407407407407408,
#  'internally': 0.007407407407407408,
#  'Project': 0.014814814814814815,
#  'Genesis': 0.007407407407407408,
#  'transparency': 0.007407407407407408,
#  'recommending': 0.007407407407407408,
#  'Products': 0.014814814814814815,
#  'suggested': 0.014814814814814815,
#  'based': 0.044444444444444446,
#  'browsing': 0.007407407407407408,
#  'history': 0.007407407407407408,
#  'bigger': 0.007407407407407408,
#  'local': 0.014814814814814815,
#  'Singapore': 0.007407407407407408,
#  'selection': 0.007407407407407408,
#  'face': 0.007407407407407408,
#  'intensifying': 0.007407407407407408,
#  'competition': 0.007407407407407408,
#  'competitors': 0.014814814814814815,
#  'region': 0.007407407407407408,
#  '3rd': 0.007407407407407408,
#  'City': 0.007407407407407408,
#  'Court': 0.007407407407407408,
#  'Appeals': 0.007407407407407408,
#  'Philadelphia': 0.007407407407407408,
#  'held': 0.022222222222222223,
#  'accountable': 0.007407407407407408,
#  'faulty': 0.007407407407407408,
#  'ran': 0.007407407407407408,
#  'counter': 0.007407407407407408,
#  'past': 0.007407407407407408,
#  'lower': 0.014814814814814815,
#  'ruling': 0.007407407407407408,
#  'favored': 0.007407407407407408,
#  'Heather': 0.007407407407407408,
#  'Oberdorf': 0.007407407407407408,
#  '2016': 0.007407407407407408,
#  'leash': 0.014814814814814815,
#  'snapped': 0.007407407407407408,
#  'causing': 0.007407407407407408,
#  'permanent': 0.007407407407407408,
#  'loss': 0.007407407407407408,
#  'vision': 0.007407407407407408,
#  'eye': 0.007407407407407408,
#  'upheld': 0.007407407407407408,
#  'expose': 0.014814814814814815,
#  'businesses': 0.014814814814814815,
#  'strict': 0.007407407407407408,
#  'liability': 0.007407407407407408,
#  'lawsuits': 0.007407407407407408,
#  'defective': 0.014814814814814815,
#  'represents': 0.007407407407407408,
#  'major': 0.014814814814814815,
#  'change': 0.007407407407407408,
#  'law': 0.014814814814814815,
#  'panel': 0.007407407407407408,
#  'sent': 0.007407407407407408,
#  'case': 0.007407407407407408,
#  'decide': 0.007407407407407408,
#  'users': 0.037037037037037035,
#  'submit': 0.007407407407407408,
#  'reviews': 0.05925925925925926,
#  'page': 0.014814814814814815,
#  'Reviewers': 0.007407407407407408,
#  'rate': 0.014814814814814815,
#  'rating': 0.007407407407407408,
#  'scale': 0.014814814814814815,
#  'stars': 0.007407407407407408,
#  'provides': 0.044444444444444446,
#  'badging': 0.007407407407407408,
#  'option': 0.007407407407407408,
#  'reviewers': 0.014814814814814815,
#  'indicates': 0.022222222222222223,
#  'real': 0.022222222222222223,
#  'reviewer': 0.014814814814814815,
#  'confirmation': 0.007407407407407408,
#  'credit': 0.007407407407407408,
#  'card': 0.007407407407407408,
#  'December': 0.037037037037037035,
#  '16': 0.007407407407407408,
#  'removed': 0.007407407407407408,
#  'ability': 0.007407407407407408,
#  'comment': 0.007407407407407408,
#  'purged': 0.007407407407407408,
#  'posted': 0.014814814814814815,
#  'review': 0.02962962962962963,
#  'comments': 0.014814814814814815,
#  'email': 0.014814814814814815,
#  'gave': 0.014814814814814815,
#  'rationale': 0.007407407407407408,
#  'removing': 0.007407407407407408,
#  'feature': 0.02962962962962963,
#  '...': 0.022222222222222223,
#  'rarely': 0.007407407407407408,
#  'remaining': 0.007407407407407408,
#  'response': 0.007407407407407408,
#  'options': 0.014814814814814815,
#  'indicate': 0.007407407407407408,
#  'reader': 0.007407407407407408,
#  'finds': 0.007407407407407408,
#  'helpful': 0.014814814814814815,
#  'report': 0.007407407407407408,
#  'violates': 0.007407407407407408,
#  'abuse': 0.007407407407407408,
#  'given': 0.014814814814814815,
#  'hits': 0.007407407407407408,
#  'appears': 0.007407407407407408,
#  'reported': 0.02962962962962963,
#  'single': 0.014814814814814815,
#  'source': 0.014814814814814815,
#  'publishers': 0.037037037037037035,
#  'asked': 0.007407407407407408,
#  'publish': 0.014814814814814815,
#  'negative': 0.014814814814814815,
#  'defended': 0.007407407407407408,
#  'practice': 0.007407407407407408,
#  'taking': 0.014814814814814815,
#  'different': 0.014814814814814815,
#  'approach': 0.014814814814814815,
#  'want': 0.007407407407407408,
#  'book': 0.02962962962962963,
#  'available': 0.022222222222222223,
#  'good': 0.007407407407407408,
#  'bad': 0.007407407407407408,
#  'ugly': 0.007407407407407408,
#  'let': 0.007407407407407408,
#  'truth': 0.007407407407407408,
#  'loose"': 0.007407407407407408,
#  'written': 0.007407407407407408,
#  'relations': 0.007407407407407408,
#  'behalf': 0.007407407407407408,
#  'clients': 0.007407407407407408,
#  'instances': 0.007407407407407408,
#  'writers': 0.007407407407407408,
#  'pseudonyms': 0.007407407407407408,
#  'leave': 0.007407407407407408,
#  'rivals': 0.007407407407407408,
#  'worksThe': 0.007407407407407408,
#  'rank': 0.022222222222222223,
#  'ASR': 0.02962962962962963,
#  'locale': 0.007407407407407408,
#  'relative': 0.007407407407407408,
#  'indicator': 0.007407407407407408,
#  'updated': 0.007407407407407408,
#  'hourly': 0.007407407407407408,
#  'Effectively': 0.007407407407407408,
#  'best': 0.007407407407407408,
#  'list': 0.007407407407407408,
#  'millions': 0.007407407407407408,
#  'stocked': 0.007407407407407408,
#  'direct': 0.007407407407407408,
#  'effect': 0.007407407407407408,
#  'determine': 0.007407407407407408,
#  'bestsellers': 0.007407407407407408,
#  'lists': 0.02962962962962963,
#  'appear': 0.007407407407407408,
#  'enjoy': 0.007407407407407408,
#  'additional': 0.014814814814814815,
#  'exposure': 0.014814814814814815,
#  'lead': 0.014814814814814815,
#  'particular': 0.007407407407407408,
#  'experience': 0.007407407407407408,
#  'jumps': 0.007407407407407408,
#  'ranks': 0.007407407407407408,
#  'movers': 0.007407407407407408,
#  'shakers': 0.007407407407407408,
#  'listing': 0.007407407407407408,
#  'reasons': 0.007407407407407408,
#  'release': 0.022222222222222223,
#  'actual': 0.014814814814814815,
#  'figures': 0.014814814814814815,
#  'begun': 0.007407407407407408,
#  'point': 0.007407407407407408,
#  'Nielsen': 0.007407407407407408,
#  'BookScan': 0.007407407407407408,
#  'verified': 0.007407407407407408,
#  'authors': 0.007407407407407408,
#  'speculation': 0.014814814814814815,
#  'manufacturers': 0.007407407407407408,
#  'marketers': 0.007407407407407408,
#  'details': 0.007407407407407408,
#  'calculation': 0.007407407407407408,
#  'algorithm': 0.007407407407407408,
#  'analyzed': 0.007407407407407408,
#  'generate': 0.014814814814814815,
#  'estimates': 0.007407407407407408,
#  'states': 0.007407407407407408,
#  'mind': 0.007407407407407408,
#  'simply': 0.007407407407407408,
#  'meant': 0.007407407407407408,
#  'guide': 0.007407407407407408,
#  'general': 0.022222222222222223,
#  'interest': 0.014814814814814815,
#  'definitive': 0.007407407407407408,
#  'assume': 0.007407407407407408,
#  'regularly': 0.007407407407407408,
#  'distribution': 0.037037037037037035,
#  'sources"Search': 0.007407407407407408,
#  'Inside': 0.007407407407407408,
#  'Book': 0.007407407407407408,
#  'search': 0.014814814814814815,
#  'keywords': 0.007407407407407408,
#  'text': 0.014814814814814815,
#  'started': 0.014814814814814815,
#  '120,000': 0.007407407407407408,
#  '33': 0.014814814814814815,
#  'pages': 0.007407407407407408,
#  '23': 0.007407407407407408,
#  '2003.In': 0.007407407407407408,
#  'dedicated': 0.014814814814814815,
#  'prescription': 0.007407407407407408,
#  'drugs': 0.022222222222222223,
#  'discounts': 0.014814814814814815,
#  '80': 0.007407407407407408,
#  'generic': 0.007407407407407408,
#  'subscribe': 0.007407407407407408,
#  '50,000': 0.007407407407407408,
#  'bricks': 0.007407407407407408,
#  'mortar': 0.022222222222222223,
#  'pharmacies': 0.007407407407407408,
#  '2015': 0.014814814814814815,
#  'opened': 0.014814814814814815,
#  'Books': 0.007407407407407408,
#  'University': 0.007407407407407408,
#  'Village': 0.007407407407407408,
#  '5,500': 0.007407407407407408,
#  'square': 0.007407407407407408,
#  'feet': 0.007407407407407408,
#  'prices': 0.014814814814814815,
#  'match': 0.007407407407407408,
#  'tenth': 0.007407407407407408,
#  'suggests': 0.007407407407407408,
#  'eventually': 0.014814814814814815,
#  'roll': 0.007407407407407408,
#  '300': 0.007407407407407408,
#  '400': 0.007407407407407408,
#  'planned': 0.007407407407407408,
#  'brick': 0.014814814814814815,
#  'applied': 0.007407407407407408,
#  'liquor': 0.007407407407407408,
#  'San': 0.014814814814814815,
#  'Francisco': 0.007407407407407408,
#  'means': 0.007407407407407408,
#  'ship': 0.007407407407407408,
#  'beer': 0.007407407407407408,
#  'alcohol': 0.007407407407407408,
#  'city': 0.007407407407407408,
#  'Fresh': 0.007407407407407408,
#  'stores': 0.007407407407407408,
#  'Luxury': 0.007407407407407408,
#  'Stores': 0.007407407407407408,
#  'mobile': 0.007407407407407408,
#  'app': 0.02962962962962963,
#  'Oscar': 0.007407407407407408,
#  'de': 0.014814814814814815,
#  'la': 0.007407407407407408,
#  'Renta': 0.007407407407407408,
#  'partner': 0.007407407407407408,
#  'firm': 0.014814814814814815,
#  'subsidiary': 0.014814814814814815,
#  'demand': 0.007407407407407408,
#  'platforms': 0.007407407407407408,
#  'governments': 0.014814814814814815,
#  'metered': 0.007407407407407408,
#  'basis': 0.007407407407407408,
#  'distributed': 0.007407407407407408,
#  'farms': 0.014814814814814815,
#  'disposal': 0.007407407407407408,
#  'virtual': 0.02962962962962963,
#  'cluster': 0.007407407407407408,
#  'computers': 0.022222222222222223,
#  'emulate': 0.007407407407407408,
#  'attributes': 0.007407407407407408,
#  'central': 0.014814814814814815,
#  'CPUs': 0.007407407407407408,
#  'graphics': 0.007407407407407408,
#  'GPUs': 0.007407407407407408,
#  'RAM': 0.007407407407407408,
#  'memory': 0.007407407407407408,
#  'hard': 0.007407407407407408,
#  'disk': 0.007407407407407408,
#  'SSD': 0.007407407407407408,
#  'choice': 0.007407407407407408,
#  'operating': 0.014814814814814815,
#  'systems': 0.014814814814814815,
#  'networking': 0.014814814814814815,
#  'pre': 0.007407407407407408,
#  'loaded': 0.007407407407407408,
#  'application': 0.007407407407407408,
#  'servers': 0.007407407407407408,
#  'databases': 0.007407407407407408,
#  'relationship': 0.007407407407407408,
#  'management': 0.014814814814814815,
#  'CRM).AWS': 0.007407407407407408,
#  'delivered': 0.007407407407407408,
#  'located': 0.007407407407407408,
#  'Fees': 0.007407407407407408,
#  'combination': 0.007407407407407408,
#  'usage': 0.022222222222222223,
#  'Pay': 0.007407407407407408,
#  'model': 0.014814814814814815,
#  'system': 0.007407407407407408,
#  'chosen': 0.007407407407407408,
#  'subscriber': 0.014814814814814815,
#  'required': 0.007407407407407408,
#  'availability': 0.007407407407407408,
#  'security': 0.044444444444444446,
#  'Subscribers': 0.007407407407407408,
#  'clusters': 0.007407407407407408,
#  'select': 0.007407407407407408,
#  'portions': 0.007407407407407408,
#  'e.g.': 0.014814814814814815,
#  'centers': 0.06666666666666667,
#  'aspects': 0.007407407407407408,
#  'responsibility': 0.007407407407407408,
#  'vulnerability': 0.007407407407407408,
#  'scanning': 0.007407407407407408,
#  'patching': 0.007407407407407408,
#  'operates': 0.007407407407407408,
#  'geographical': 0.007407407407407408,
#  'regions': 0.007407407407407408,
#  '6': 0.007407407407407408,
#  'North': 0.007407407407407408,
#  'America': 0.007407407407407408,
#  'markets': 0.007407407407407408,
#  'obtaining': 0.007407407407407408,
#  'quickly': 0.007407407407407408,
#  'cheaply': 0.007407407407407408,
#  'building': 0.007407407407407408,
#  'billed': 0.007407407407407408,
#  'measures': 0.007407407407407408,
#  'varying': 0.007407407407407408,
#  'ways': 0.007407407407407408,
#  'Q4': 0.007407407407407408,
#  'Azure': 0.007407407407407408,
#  '21': 0.007407407407407408,
#  'respectively': 0.014814814814814815,
#  'according': 0.014814814814814815,
#  'Synergy': 0.007407407407407408,
#  'number': 0.007407407407407408,
#  'assistant': 0.007407407407407408,
#  'Appstore': 0.007407407407407408,
#  'Android': 0.007407407407407408,
#  'apps': 0.007407407407407408,
#  'line': 0.007407407407407408,
#  'audiobooks': 0.007407407407407408,
#  'purchase': 0.014814814814814815,
#  'listening': 0.007407407407407408,
#  'Astro': 0.007407407407407408,
#  'household': 0.007407407407407408,
#  'robot': 0.007407407407407408,
#  'powered': 0.014814814814814815,
#  'remote': 0.007407407407407408,
#  'controlled': 0.007407407407407408,
#  'check': 0.014814814814814815,
#  'pets': 0.007407407407407408,
#  'people': 0.014814814814814815,
#  'send': 0.007407407407407408,
#  'owners': 0.007407407407407408,
#  'notification': 0.007407407407407408,
#  'detects': 0.007407407407407408,
#  'unusual': 0.007407407407407408,
#  'uses': 0.007407407407407408,
#  'transportation': 0.014814814814814815,
#  'packages': 0.022222222222222223,
#  'employs': 0.007407407407407408,
#  'bulk': 0.007407407407407408,
#  'staffed': 0.007407407407407408,
#  'Hub': 0.007407407407407408,
#  'Locker+': 0.007407407407407408,
#  'locations': 0.014814814814814815,
#  'stations': 0.014814814814814815,
#  'drivers': 0.014814814814814815,
#  'pick': 0.007407407407407408,
#  'hiring': 0.014814814814814815,
#  'employees': 0.022222222222222223,
#  'Rakuten': 0.007407407407407408,
#  ...}

# %%
# generating the sentence tokens
sentence_tokens
# Out:
# [Amazon.com, Inc. (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence.,
#  It has been referred to as "one of the most influential economic and cultural forces in the world", and is one of the world's most valuable brands.,
#  It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.,
#  Amazon was founded by Jeff Bezos from his garage in Bellevue, Washington, on July 5, 1994.,
#  Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store.,
#  It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D).,
#  Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market.,
#  Its acquisition of Whole Foods in August 2017 for US$13.4 billion substantially increased its footprint as a physical retailer.,
#  Amazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures.,
#  As of 2021, it is the world's largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS, live-streaming service through Twitch, and Internet company as measured by revenue and market share.,
#  In 2021, it surpassed Walmart as the world's largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200 million subscribers worldwide.,
#  It is the second-largest private employer in the United States.,
#  Amazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units.,
#  It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022.,
#  It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.,
#  Amazon has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior.,
#  Amazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.,
#  Amazon went public in May 1997.,
#  It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany.,
#  The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.,
#  In 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon's ecommerce platform.,
#  In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service.,
#  AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006, and Elastic Compute Cloud (EC2) in 2008, allowing companies to rent data storage and computing power from Amazon.,
#  In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon's warehouses and fulfillment infrastructure.,
#  Amazon purchased the Whole Foods Market supermarket chain in 2017.During the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020.,
#  The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022.,
#  Amazon also introduced temporary restrictions on the sale of non-essential goods, and hired 100,000 more staff in the US and Canada.,
#  Some Amazon workers in the US, France, and Italy protested the company's decision to "run normal shifts" despite many positive COVID-19 cases.,
#  In Spain, the company has faced legal complaints over its policies.,
#  A group of US Senators wrote an open letter to Bezos in March 2020, expressing concerns about worker safety.,
#  On February 2, 2021, Amazon announced that Jeff Bezos would step down as CEO to become executive chair of Amazon's board in Q3 of 2021.,
#  Andy Jassy, previously CEO of AWS, became Amazon's CEO.Amazon.com is an ecommerce platform that sells many product lines, include media (books, movies, music, and software), apparel, baby products, consumer electronics, beauty products, gourmet food, groceries, health and personal care products, industrial & scientific supplies, kitchen items, jewelry, watches, lawn and garden items, musical instruments, sporting goods, tools, automotive items, toys and games, and farm supplies and consulting services.,
#  Amazon websites are country-specific (for example, amazon.com for the U.S. and amazon.fr for France), though some offer international shipping.,
#  Visits to amazon.com grew from 615 million annual visitors in 2008, to more than 2 billion per month in 2022.,
#  The company has invested heavily in server capacity and redundancy to handle increased traffic during the Christmas holiday season.,
#  The ecommerce platform is the 14th most visited website in the world.,
#  In 2000, U.S. toy retailer Toys "R" Us entered into a 10-year agreement with Amazon, valued at $50 million per year plus a cut of sales, under which Toys "R" Us would be the exclusive supplier of toys and baby products on the service, and the chain's website would redirect to Amazon's Toys & Games category.,
#  In 2004, Toys "R" Us sued Amazon, claiming that because of a perceived lack of variety in Toys "R" Us stock, Amazon had knowingly allowed third-party sellers to offer items on the service in categories that Toys "R" Us had been granted exclusivity.,
#  In 2006, a court ruled in favor of Toys "R" Us, giving it the right to unwind its agreement with Amazon and establish its independent e-commerce website.,
#  The company was later awarded $51 million in damages.,
#  In 2001, Amazon entered into a similar agreement with Borders Group, under which Amazon would comanage Borders.com as a co-branded service.,
#  Borders pulled out of the arrangement in 2007, with plans to also launch its own online store.,
#  On October 18, 2011, Amazon.com announced a partnership with DC Comics for the exclusive digital rights to many popular comics, including Superman, Batman, Green Lantern, The Sandman, and Watchmen.,
#  The partnership has caused well-known bookstores like Barnes & Noble to remove these titles from their shelves.,
#  In November 2013, Amazon announced a partnership with the United States Postal Service to begin delivering orders on Sundays.,
#  The service, included in Amazon's standard shipping rates, initiated in metropolitan areas of Los Angeles and New York because of the high-volume and inability to deliver in a timely way, with plans to expand into Dallas, Houston, New Orleans and Phoenix by 2014.In June 2017, Nike agreed to sell products through Amazon in exchange for better policing of counterfeit goods.,
#  This proved unsuccessful and Nike withdrew from the partnership in November 2019.,
#  Companies including IKEA and Birkenstock also stopped selling through Amazon around the same time, citing similar frustrations over business practices and counterfeit goods.,
#  In September 2017, Amazon ventured with one of its sellers JV Appario Retail owned by Patni Group which has recorded a total income of US$ 104.44 million (₹ 759 crore) in financial year 2017–2018.As of October 11, 2017[update], AmazonFresh sold a range of Booths branded products for home delivery in selected areas.,
#  In November 2018, Amazon reached an agreement with Apple Inc. to sell selected products through the service, via the company and selected Apple Authorized Resellers.,
#  As a result of this partnership, only Apple Authorized Resellers may sell Apple products on Amazon effective January 4, 2019.Amazon sells many products under its own brand names, including phone chargers, batteries, an diaper wipes.,
#  The AmazonBasics brand was introduced in 2009, and now features hundreds of product lines, including smartphone cases, computer mice, batteries, dumbbells, and dog crates.,
#  Amazon owned 34 private-label brands as of 2019.,
#  These brands account for 0.15% of Amazon's global sales, whereas the average for other large retailers is 18%.,
#  Other Amazon retail brands include Presto!, Mama Bear, and Amazon Essentials.,
#  Amazon derives many of its sales (around 40% in 2008) from third-party sellers who sell products on Amazon.,
#  Some other large e-commerce sellers use Amazon to sell their products in addition to selling them through their websites.,
#  The sales are processed through Amazon.com and end up at individual sellers for processing and order fulfillment and Amazon leases space for these retailers.,
#  Small sellers of used and new goods go to Amazon Marketplace to offer goods at a fixed price.,
#  Publishers can signup as affiliates and receive a commission for referring customers to Amazon by placing links to Amazon on their websites if the referral results in a sale.,
#  Worldwide, Amazon has "over 900,000 members" in its affiliate programs.,
#  In the middle of 2014, the Amazon Affiliate Program is used by 1.2% of all websites and it is the second most popular advertising network after Google Ads.,
#  It is frequently used by websites and non-profits to provide a way for supporters to earn them a commission.,
#  Associates can access the Amazon catalog directly on their websites by using the Amazon Web Services (AWS) XML service.,
#  A new affiliate product, aStore, allows Associates to embed a subset of Amazon products within another website, or linked to another website.,
#  In June 2010, Amazon Seller Product Suggestions was launched (rumored to be internally called "Project Genesis") to provide more transparency to sellers by recommending specific products to third-party sellers to sell on Amazon.,
#  Products suggested are based on customers' browsing history.,
#  In 2019, Amazon launched a bigger local online store in Singapore to expand its product selection in the face of intensifying competition with competitors in the region.,
#  In July 2019, the 3rd U.S. City Court of Appeals in Philadelphia ruled that Amazon can be held accountable for faulty third-party sales.,
#  The decision ran counter to a past lower court ruling that had favored Amazon.,
#  Heather Oberdorf had sued the company in 2016 over a dog leash that snapped, causing permanent loss of vision in one eye.,
#  If upheld, the decision would expose Amazon and similar platform businesses to strict liability lawsuits for defective products, which represents a major change in the law.,
#  The panel sent the case back to the lower court, to decide whether the leash was defective.,
#  Amazon allows users to submit reviews to the web page of each product.,
#  Reviewers must rate the product on a rating scale from one to five stars.,
#  Amazon provides a badging option for reviewers which indicates the real name of the reviewer (based on confirmation of a credit card account) or which indicates that the reviewer is one of the top reviewers by popularity.,
#  As of December 16, 2020, Amazon removed the ability of sellers and customers to comment on product reviews and purged their websites of all posted product review comments.,
#  In an email to sellers Amazon gave its rationale for removing this feature: "... the comments feature on customer reviews was rarely used.",
#  The remaining review response options are to indicate whether the reader finds the review helpful or to report that it violates Amazon policies (abuse).,
#  If a review is given enough "helpful" hits, it appears on the front page of the product.,
#  In 2010, Amazon was reported as being the largest single source of Internet consumer reviews.,
#  When publishers asked Bezos why Amazon would publish negative reviews, he defended the practice by claiming that Amazon.com was "taking a different approach ...,
#  we want to make every book available—the good, the bad and the ugly ... to let truth loose".,
#  There have been cases of positive reviews being written and posted by public relations companies on behalf of their clients and instances of writers using pseudonyms to leave negative reviews of their rivals' worksThe Amazon sales rank (ASR) indicates the popularity of a product sold on any Amazon locale.,
#  It is a relative indicator of popularity that is updated hourly.,
#  Effectively, it is a "best sellers list" for the millions of products stocked by Amazon.,
#  While the ASR has no direct effect on the sales of a product, it is used by Amazon to determine which products to include in its bestsellers lists.,
#  Products that appear in these lists enjoy additional exposure on the Amazon website and this may lead to an increase in sales.,
#  In particular, products that experience large jumps (up or down) in their sales ranks may be included within Amazon's lists of "movers and shakers"; such a listing provides additional exposure that might lead to an increase in sales.,
#  For competitive reasons, Amazon does not release actual sales figures to the public.,
#  However, Amazon has now begun to release point of sale data via the Nielsen BookScan service to verified authors.,
#  While the ASR has been the source of much speculation by publishers, manufacturers, and marketers, Amazon itself does not release the details of its sales rank calculation algorithm.,
#  Some companies have analyzed Amazon sales data to generate sales estimates based on the ASR, though Amazon states:Please keep in mind that our sales rank figures are simply meant to be a guide of general interest for the customer and not definitive sales information for publishers—we assume you have this information regularly from your distribution sources"Search Inside the Book" is a feature which allows customers to search for keywords in the full text of many books in the catalog.,
#  The feature started with 120,000 titles (or 33 million pages of text) on October 23, 2003.In November 2020, the company started an online delivery service dedicated to prescription drugs.,
#  The service provides discounts up to 80% for generic drugs and up to 40% for branded drugs for Prime subscribe users.,
#  The products can be purchased on the company's website or at over 50,000 bricks-and-mortar pharmacies in the United States.,
#  In November 2015, Amazon opened a physical Amazon Books store in University Village in Seattle.,
#  The store is 5,500 square feet and prices for all products match those on its website.,
#  Amazon will open its tenth physical book store in 2017; media speculation suggests Amazon plans to eventually roll out 300 to 400 bookstores around the country.,
#  In June 2018, it was reported that Amazon planned to open brick and mortar bookstores in Germany.,
#  In August 2019, Amazon applied to have a liquor store in San Francisco, CA as a means to ship beer and alcohol within the city.,
#  In 2020, Amazon Fresh opened several physical stores in the U.S. and the United Kingdom.,
#  In September 2020, Amazon launched Luxury Stores on its mobile app, where Oscar de la Renta become the first and only label to partner with the firm.,
#  Amazon Web Services (AWS) is a subsidiary of that provides on-demand cloud computing platforms and APIs to individuals, companies, and governments, on a metered pay-as-you-go basis.,
#  These cloud computing web services provide distributed computing processing capacity and software tools via AWS server farms.,
#  One of these services is Amazon Elastic Compute Cloud (EC2), which allows users to have at their disposal a virtual cluster of computers, available all the time, through the Internet.,
#  AWS's virtual computers emulate most of the attributes of a real computer, including hardware central processing units (CPUs) and graphics processing units (GPUs) for processing; local/RAM memory; hard-disk/SSD storage; a choice of operating systems; networking; and pre-loaded application software such as web servers, databases, and customer relationship management (CRM).AWS services are delivered to customers via a network of AWS server farms located throughout the world.,
#  Fees are based on a combination of usage (known as a "Pay-as-you-go" model), hardware, operating system, software, or networking features chosen by the subscriber required availability, redundancy, security, and service options.,
#  Subscribers can pay for a single virtual AWS computer, a dedicated physical computer, or clusters of either.,
#  Amazon provides select portions of security for subscribers (e.g. physical security of the data centers) while other aspects of security are the responsibility of the subscriber (e.g. account management, vulnerability scanning, patching).,
#  AWS operates from many global geographical regions including 6 in North America.,
#  Amazon markets AWS to subscribers as a way of obtaining large-scale computing capacity more quickly and cheaply than building an actual physical server farm.,
#  All services are billed based on usage, but each service measures usage in varying ways.,
#  As of 2021 Q4, AWS has 33% market share for cloud infrastructure while the next two competitors Microsoft Azure and Google Cloud have 21%, and 10% respectively, according to Synergy Group.,
#  Amazon has a number of products and services available, including its digital assistant Alexa, Amazon Music and Prime Video for music and videos respectively, the Amazon Appstore for Android apps, and its Kindle hardware line of e-readers and tablets.,
#  Audible provides audiobooks for purchase and listening.,
#  In September 2021, Amazon announced the launch of Astro, its first household robot, powered by its Alexa smart home technology.,
#  This can be remote-controlled when not at home, to check on pets, people, or home security.,
#  It will send owners a notification if it detects something unusual.,
#  Amazon uses many different transportation services to deliver packages.,
#  Amazon-branded services include:Amazon directly employs people to work at its warehouses, bulk distribution centers, staffed "Amazon Hub Locker+" locations, and delivery stations where drivers pick up packages.,
#  As of December 2020, it is not hiring delivery drivers as employees.,
#  Rakuten Intelligence estimated that in 2020 in the United States, the proportion of last-mile deliveries was 56% by Amazon's directly contracted services (mostly in urban areas), 30% by the U.S. Postal Service (mostly in rural areas), and 14% by UPS.,
#  In April 2021, Amazon reported to investors it had increased its in-house delivery capacity by 50% in the last 12 months (which included the first year of the COVID-19 pandemic in the United States).Amazon first launched its distribution network in 1997 with two fulfillment centers in Seattle and New Castle, Delaware.,
#  Amazon has several types of distribution facilities consisting of cross-dock centers, fulfillment centers, sortation centers, delivery stations, Prime now hubs, and Prime air hubs.,
#  There are 75 fulfillment centers and 25 sortation centers with over 125,000 employees.,
#  Employees are responsible for five basic tasks: unpacking and inspecting incoming goods; placing goods in storage and recording their location; picking goods from their computer recorded locations to make up an individual shipment; sorting and packing orders; and shipping.,
#  A computer that records the location of goods and maps out routes for pickers plays a key role: employees carry hand-held computers which communicate with the central computer and monitor their rate of progress.,
#  Some warehouses are partially automated with systems built by Amazon Robotics.,
#  In September 2006, Amazon launched a program called FBA (Fulfillment By Amazon) whereby it could handle storage, packing and distribution of products and services for small sellers.Amazon.fr fulfillment center in Lauwin-Planque, FranceAmazon.es fulfillment center in San Fernando de Henares, SpainAmazon.co.uk fulfillment center in Glenrothes, Scotland, UKAmazon.de fulfillment center in Graben, GermanyAmazon.co.jp fulfillment center in Ichikawa, JapanAmazon fulfillment center in Macon, Georgia, U.S.During his tenure, Jeff Bezos had become renowned for his annual shareholder letters, which have gained similar notability to those of Warren Buffett.,
#  These annual letters gave an "invaluable window" into the famously "secretive" company, and revealed Bezos's perspectives and strategic focus.,
#  A common theme of these letters is Bezos's desire to instill customer-centricity (in his words, "customer obsession") at all levels of Amazon, notably by making all senior executives field customer support queries for a short time at Amazon call centers.,
#  He also read many emails addressed by customers to his public email address.,
#  One of Bezos's most well-known internal memos was his mandate for "all teams" to "expose their data and functionality" through service interfaces "designed from the ground up to be externalizable".,
#  This process, commonly known as a service-oriented architecture (SOA), resulted in mandatory dogfooding of services that would later be commercialized as part of AWS.As of June 2022[update], Amazon's board of directors were:Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products.,
#  As of 2018[update], Amazon.com is ranked 8th on the Fortune 500 rankings of the largest United States corporations by total revenue.,
#  For the fiscal year 2021, Amazon reported earnings of US$33.36 billion, with an annual revenue of US$469.82 billion, an increase of 21.7% over the previous fiscal cycle.,
#  Since 2007 sales increased from 14.835 billion to 469.822 billion, due to continued business expansion.,
#  Amazon's market capitalization went over US$1 trillion again in early February 2020 after the announcement of the fourth quarter 2019 results.,
#  Amazon owns over 40 subsidiaries, including Amazon Web Services, Audible, Diapers.com, Goodreads, IMDb, Kiva Systems (now Amazon Robotics), Shopbop, Teachstreet, Twitch, Zappos, and Zoox.,
#  Goodreads is a "social cataloging" website founded in December 2006 and launched in January 2007 by Otis Chandler, a software engineer, and entrepreneur, and Elizabeth Khuri.,
#  The website allows individuals to freely search Goodreads' extensive user-populated database of books, annotations, and reviews.,
#  Users can sign up and register books to generate library catalogs and reading lists.,
#  They can also create their groups of book suggestions and discussions.,
#  In December 2007, the site had over 650,000 members, and over a million books had been added.,
#  Amazon bought the company in March 2013.Kuiper Systems LLC, is a subsidiary of Amazon, set up to deploy a broadband satellite internet constellation with an announced 3,236 Low Earth orbit satellites to provide satellite based Internet connectivity.,
#  Ring is a home automation company founded by Jamie Siminoff in 2013.,
#  It is primarily known for its WiFi powered smart doorbells, but manufactures other devices such as security cameras.,
#  Amazon bought Ring for US$1 billion in 2018.Twitch is a live streaming platform for video, primarily oriented towards video gaming content.,
#  The service was first established as a spin-off of a general-interest streaming service known as Justin.tv.,
#  Its prominence was eclipsed by that of Twitch, and Justin.tv was eventually shut down by its parent company in August 2014 in order to focus exclusively on Twitch.,
#  Later that month, Twitch was acquired by Amazon for $970 million.,
#  Through Twitch, Amazon also owns Curse, Inc., an operator of video gaming communities and a provider of VoIP services for gaming.,
#  Since the acquisition, Twitch began to sell games directly through the platform, and began offering special features for Amazon Prime subscribers.,
#  The site's rapid growth had been boosted primarily by the prominence of major esports competitions on the service, leading GameSpot senior esports editor Rod Breslau to have described the service as "the ESPN of esports".,
#  As of 2015[update], the service had over 1.5 million broadcasters and 100 million monthly viewers.,
#  On August 10, 2020, Amazon announced the rebranding of Twitch Prime, the live-streaming site, renaming it Prime Gaming in another attempt to crack the video game market after failing a big-budget game effort.,
#  With Twitch Prime, users will be given a free subscription to Twitch, with free games from small studios and discounts for larger titles like Grand Theft Auto and League of Legends.,
#  On November 2, 2020, Twitch announced a virtual flagship conference and named it GlitchCon instead of TwitchCon to be held on November 14.,
#  The main aim of the conference will be to bring its numerous, disparate communities of streamers and fans together where they can be real-life confidants.,
#  Whole Foods Market is an American supermarket chain exclusively featuring foods without artificial preservatives, colors, flavors, sweeteners, and hydrogenated fats.,
#  Amazon acquired Whole Foods for $13.7 billion in August 2017.Other Amazon subsidiaries include:Amazon also has investments in renewable energy and plans to expand its position into the Canadian market through an investment in a new plant in Alberta.,
#  Amazon lobbies the United States federal government and state governments on multiple issues such as the enforcement of sales taxes on online sales, transportation safety, privacy and data protection and intellectual property.,
#  According to regulatory filings, Amazon.com focuses its lobbying on the United States Congress, the Federal Communications Commission and the Federal Reserve.,
#  Amazon.com spent roughly $3.5 million, $5 million and $9.5 million on lobbying, in 2013, 2014 and 2015, respectively.Amazon.com was a corporate member of the American Legislative Exchange Council (ALEC) until it dropped membership following protests at its shareholders' meeting on May 24, 2012.In 2014, Amazon expanded its lobbying practices as it prepared to lobby the Federal Aviation Administration to approve its drone delivery program, hiring the Akin Gump Strauss Hauer & Feld lobbying firm in June.,
#  Amazon and its lobbyists have visited with Federal Aviation Administration officials and aviation committees in Washington, D.C. to explain its plans to deliver packages.,
#  In September 2020 this moved one step closer with the granting of a critical certificate by the FAA.In 2019, it spent $16.8m and had a team of 104 lobbyists, up from $14.4m and 103 lobbyists in 2018.Amazon has attracted criticism for its actions, including: supplying law enforcement with facial recognition surveillance tools; forming cloud computing partnerships with the CIA; leading customers away from bookshops; adversely impacting the environment; placing a low priority on warehouse conditions for workers; actively opposing unionization efforts; remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its 1-Click technology; engaging in anti-competitive actions and price discrimination; and reclassifying LGBT books as adult content.,
#  Criticism has also concerned various decisions over whether to censor or publish content such as the WikiLeaks website, works containing libel and material facilitating dogfight, cockfight, or pedophile activities.,
#  In December 2011, Amazon faced a backlash from small businesses for running a one-day deal to promote its new Price Check app.,
#  Shoppers who used the app to check prices in a brick-and-mortar store were offered a 5% discount to purchase the same item from Amazon.,
#  Companies like Groupon, eBay and Taap.it countered Amazon's promotion by offering $10 off from their products.,
#  The company has also faced accusations of putting undue pressure on suppliers to maintain and extend its profitability.,
#  One effort to squeeze the most vulnerable book publishers was known within the company as the Gazelle Project, after Bezos suggested, according to Brad Stone, "that Amazon should approach these small publishers the way a cheetah would pursue a sickly gazelle.",
#  In July 2014, the Federal Trade Commission launched a lawsuit against the company alleging it was promoting in-app purchases to children, which were being transacted without parental consent.,
#  In 2019, Amazon banned selling skin-lightening and racist products that might affect the consumer's health.,
#  In 2022, a lawsuit filed by state attorney-general Letitia James was dismissed by the New York state court of appeals.]

# %%
sentence_scores = {}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# code here

sentence_scores
# Out:
# {Amazon.com, Inc. (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence.: 0.5555555555555556,
#  It has been referred to as "one of the most influential economic and cultural forces in the world", and is one of the world's most valuable brands.: 0.16296296296296298,
#  It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.: 0.11851851851851851,
#  Amazon was founded by Jeff Bezos from his garage in Bellevue, Washington, on July 5, 1994.: 0.07407407407407407,
#  Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store.: 0.36296296296296304,
#  It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D).: 0.525925925925926,
#  Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market.: 0.11851851851851851,
#  Its acquisition of Whole Foods in August 2017 for US$13.4 billion substantially increased its footprint as a physical retailer.: 0.3925925925925926,
#  Amazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures.: 0.1111111111111111,
#  As of 2021, it is the world's largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS, live-streaming service through Twitch, and Internet company as measured by revenue and market share.: 0.9925925925925927,
#  In 2021, it surpassed Walmart as the world's largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200 million subscribers worldwide.: 0.5555555555555556,
#  It is the second-largest private employer in the United States.: 0.08148148148148147,
#  Amazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units.: 0.2074074074074074,
#  It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022.: 0.2518518518518519,
#  It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.: 0.18518518518518517,
#  Amazon has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior.: 0.2370370370370371,
#  Amazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.: 0.10370370370370371,
#  Amazon went public in May 1997.: 0.06666666666666667,
#  It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany.: 0.41481481481481486,
#  The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.: 0.4888888888888889,
#  In 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon's ecommerce platform.: 0.4222222222222223,
#  In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service.: 0.5333333333333333,
#  AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006, and Elastic Compute Cloud (EC2) in 2008, allowing companies to rent data storage and computing power from Amazon.: 0.674074074074074,
#  In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon's warehouses and fulfillment infrastructure.: 0.8666666666666666,
#  Amazon purchased the Whole Foods Market supermarket chain in 2017.During the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020.: 0.45925925925925937,
#  The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022.: 0.28148148148148144,
#  Amazon also introduced temporary restrictions on the sale of non-essential goods, and hired 100,000 more staff in the US and Canada.: 0.18518518518518523,
#  Some Amazon workers in the US, France, and Italy protested the company's decision to "run normal shifts" despite many positive COVID-19 cases.: 0.23703703703703707,
#  In Spain, the company has faced legal complaints over its policies.: 0.17777777777777778,
#  A group of US Senators wrote an open letter to Bezos in March 2020, expressing concerns about worker safety.: 0.17777777777777778,
#  On February 2, 2021, Amazon announced that Jeff Bezos would step down as CEO to become executive chair of Amazon's board in Q3 of 2021.: 0.24444444444444446,
#  Andy Jassy, previously CEO of AWS, became Amazon's CEO.Amazon.com is an ecommerce platform that sells many product lines, include media (books, movies, music, and software), apparel, baby products, consumer electronics, beauty products, gourmet food, groceries, health and personal care products, industrial & scientific supplies, kitchen items, jewelry, watches, lawn and garden items, musical instruments, sporting goods, tools, automotive items, toys and games, and farm supplies and consulting services.: 1.6148148148148136,
#  Amazon websites are country-specific (for example, amazon.com for the U.S. and amazon.fr for France), though some offer international shipping.: 0.17037037037037037,
#  Visits to amazon.com grew from 615 million annual visitors in 2008, to more than 2 billion per month in 2022.: 0.4666666666666666,
#  The company has invested heavily in server capacity and redundancy to handle increased traffic during the Christmas holiday season.: 0.2814814814814815,
#  The ecommerce platform is the 14th most visited website in the world.: 0.22962962962962963,
#  In 2000, U.S. toy retailer Toys "R" Us entered into a 10-year agreement with Amazon, valued at $50 million per year plus a cut of sales, under which Toys "R" Us would be the exclusive supplier of toys and baby products on the service, and the chain's website would redirect to Amazon's Toys & Games category.: 1.2740740740740737,
#  In 2004, Toys "R" Us sued Amazon, claiming that because of a perceived lack of variety in Toys "R" Us stock, Amazon had knowingly allowed third-party sellers to offer items on the service in categories that Toys "R" Us had been granted exclusivity.: 0.5407407407407407,
#  In 2006, a court ruled in favor of Toys "R" Us, giving it the right to unwind its agreement with Amazon and establish its independent e-commerce website.: 0.33333333333333337,
#  The company was later awarded $51 million in damages.: 0.2666666666666667,
#  In 2001, Amazon entered into a similar agreement with Borders Group, under which Amazon would comanage Borders.com as a co-branded service.: 0.28148148148148144,
#  Borders pulled out of the arrangement in 2007, with plans to also launch its own online store.: 0.2074074074074074,
#  On October 18, 2011, Amazon.com announced a partnership with DC Comics for the exclusive digital rights to many popular comics, including Superman, Batman, Green Lantern, The Sandman, and Watchmen.: 0.2814814814814815,
#  The partnership has caused well-known bookstores like Barnes & Noble to remove these titles from their shelves.: 0.1777777777777778,
#  In November 2013, Amazon announced a partnership with the United States Postal Service to begin delivering orders on Sundays.: 0.29629629629629634,
#  The service, included in Amazon's standard shipping rates, initiated in metropolitan areas of Los Angeles and New York because of the high-volume and inability to deliver in a timely way, with plans to expand into Dallas, Houston, New Orleans and Phoenix by 2014.In June 2017, Nike agreed to sell products through Amazon in exchange for better policing of counterfeit goods.: 0.8518518518518519,
#  This proved unsuccessful and Nike withdrew from the partnership in November 2019.: 0.11851851851851852,
#  Companies including IKEA and Birkenstock also stopped selling through Amazon around the same time, citing similar frustrations over business practices and counterfeit goods.: 0.3777777777777778,
#  In September 2017, Amazon ventured with one of its sellers JV Appario Retail owned by Patni Group which has recorded a total income of US$ 104.44 million (₹ 759 crore) in financial year 2017–2018.As of October 11, 2017[update], AmazonFresh sold a range of Booths branded products for home delivery in selected areas.: 1.0666666666666667,
#  In November 2018, Amazon reached an agreement with Apple Inc. to sell selected products through the service, via the company and selected Apple Authorized Resellers.: 0.6222222222222222,
#  As a result of this partnership, only Apple Authorized Resellers may sell Apple products on Amazon effective January 4, 2019.Amazon sells many products under its own brand names, including phone chargers, batteries, an diaper wipes.: 0.6592592592592594,
#  The AmazonBasics brand was introduced in 2009, and now features hundreds of product lines, including smartphone cases, computer mice, batteries, dumbbells, and dog crates.: 0.3925925925925927,
#  Amazon owned 34 private-label brands as of 2019.: 0.14074074074074075,
#  These brands account for 0.15% of Amazon's global sales, whereas the average for other large retailers is 18%.: 0.29629629629629634,
#  Other Amazon retail brands include Presto!, Mama Bear, and Amazon Essentials.: 0.08888888888888889,
#  Amazon derives many of its sales (around 40% in 2008) from third-party sellers who sell products on Amazon.: 0.5851851851851853,
#  Some other large e-commerce sellers use Amazon to sell their products in addition to selling them through their websites.: 0.5481481481481482,
#  The sales are processed through Amazon.com and end up at individual sellers for processing and order fulfillment and Amazon leases space for these retailers.: 0.4518518518518519,
#  Small sellers of used and new goods go to Amazon Marketplace to offer goods at a fixed price.: 0.3851851851851852,
#  Publishers can signup as affiliates and receive a commission for referring customers to Amazon by placing links to Amazon on their websites if the referral results in a sale.: 0.26666666666666666,
#  Worldwide, Amazon has "over 900,000 members" in its affiliate programs.: 0.05185185185185186,
#  In the middle of 2014, the Amazon Affiliate Program is used by 1.2% of all websites and it is the second most popular advertising network after Google Ads.: 0.20740740740740737,
#  It is frequently used by websites and non-profits to provide a way for supporters to earn them a commission.: 0.1851851851851852,
#  Associates can access the Amazon catalog directly on their websites by using the Amazon Web Services (AWS) XML service.: 0.3925925925925926,
#  A new affiliate product, aStore, allows Associates to embed a subset of Amazon products within another website, or linked to another website.: 0.5777777777777778,
#  In June 2010, Amazon Seller Product Suggestions was launched (rumored to be internally called "Project Genesis") to provide more transparency to sellers by recommending specific products to third-party sellers to sell on Amazon.: 0.762962962962963,
#  Products suggested are based on customers' browsing history.: 0.31851851851851853,
#  In 2019, Amazon launched a bigger local online store in Singapore to expand its product selection in the face of intensifying competition with competitors in the region.: 0.42222222222222233,
#  In July 2019, the 3rd U.S. City Court of Appeals in Philadelphia ruled that Amazon can be held accountable for faulty third-party sales.: 0.34814814814814815,
#  The decision ran counter to a past lower court ruling that had favored Amazon.: 0.10370370370370369,
#  Heather Oberdorf had sued the company in 2016 over a dog leash that snapped, causing permanent loss of vision in one eye.: 0.22222222222222227,
#  If upheld, the decision would expose Amazon and similar platform businesses to strict liability lawsuits for defective products, which represents a major change in the law.: 0.4074074074074075,
#  The panel sent the case back to the lower court, to decide whether the leash was defective.: 0.10370370370370369,
#  Amazon allows users to submit reviews to the web page of each product.: 0.28888888888888886,
#  Reviewers must rate the product on a rating scale from one to five stars.: 0.14814814814814817,
#  Amazon provides a badging option for reviewers which indicates the real name of the reviewer (based on confirmation of a credit card account) or which indicates that the reviewer is one of the top reviewers by popularity.: 0.30370370370370375,
#  As of December 16, 2020, Amazon removed the ability of sellers and customers to comment on product reviews and purged their websites of all posted product review comments.: 0.6296296296296298,
#  In an email to sellers Amazon gave its rationale for removing this feature: "... the comments feature on customer reviews was rarely used.": 0.3555555555555556,
#  The remaining review response options are to indicate whether the reader finds the review helpful or to report that it violates Amazon policies (abuse).: 0.16296296296296298,
#  If a review is given enough "helpful" hits, it appears on the front page of the product.: 0.17777777777777776,
#  In 2010, Amazon was reported as being the largest single source of Internet consumer reviews.: 0.21481481481481482,
#  When publishers asked Bezos why Amazon would publish negative reviews, he defended the practice by claiming that Amazon.com was "taking a different approach ...: 0.24444444444444444,
#  we want to make every book available—the good, the bad and the ugly ... to let truth loose".: 0.14814814814814817,
#  There have been cases of positive reviews being written and posted by public relations companies on behalf of their clients and instances of writers using pseudonyms to leave negative reviews of their rivals' worksThe Amazon sales rank (ASR) indicates the popularity of a product sold on any Amazon locale.: 0.6814814814814817,
#  It is a relative indicator of popularity that is updated hourly.: 0.05925925925925926,
#  Effectively, it is a "best sellers list" for the millions of products stocked by Amazon.: 0.31851851851851853,
#  While the ASR has no direct effect on the sales of a product, it is used by Amazon to determine which products to include in its bestsellers lists.: 0.5333333333333333,
#  Products that appear in these lists enjoy additional exposure on the Amazon website and this may lead to an increase in sales.: 0.5555555555555556,
#  In particular, products that experience large jumps (up or down) in their sales ranks may be included within Amazon's lists of "movers and shakers"; such a listing provides additional exposure that might lead to an increase in sales.: 0.7481481481481482,
#  For competitive reasons, Amazon does not release actual sales figures to the public.: 0.26666666666666666,
#  However, Amazon has now begun to release point of sale data via the Nielsen BookScan service to verified authors.: 0.2888888888888889,
#  While the ASR has been the source of much speculation by publishers, manufacturers, and marketers, Amazon itself does not release the details of its sales rank calculation algorithm.: 0.2962962962962963,
#  Some companies have analyzed Amazon sales data to generate sales estimates based on the ASR, though Amazon states:Please keep in mind that our sales rank figures are simply meant to be a guide of general interest for the customer and not definitive sales information for publishers—we assume you have this information regularly from your distribution sources"Search Inside the Book" is a feature which allows customers to search for keywords in the full text of many books in the catalog.: 1.37037037037037,
#  The feature started with 120,000 titles (or 33 million pages of text) on October 23, 2003.In November 2020, the company started an online delivery service dedicated to prescription drugs.: 0.9037037037037038,
#  The service provides discounts up to 80% for generic drugs and up to 40% for branded drugs for Prime subscribe users.: 0.36296296296296293,
#  The products can be purchased on the company's website or at over 50,000 bricks-and-mortar pharmacies in the United States.: 0.4888888888888889,
#  In November 2015, Amazon opened a physical Amazon Books store in University Village in Seattle.: 0.19999999999999998,
#  The store is 5,500 square feet and prices for all products match those on its website.: 0.3851851851851852,
#  Amazon will open its tenth physical book store in 2017; media speculation suggests Amazon plans to eventually roll out 300 to 400 bookstores around the country.: 0.3407407407407408,
#  In June 2018, it was reported that Amazon planned to open brick and mortar bookstores in Germany.: 0.13333333333333336,
#  In August 2019, Amazon applied to have a liquor store in San Francisco, CA as a means to ship beer and alcohol within the city.: 0.162962962962963,
#  In 2020, Amazon Fresh opened several physical stores in the U.S. and the United Kingdom.: 0.17037037037037037,
#  In September 2020, Amazon launched Luxury Stores on its mobile app, where Oscar de la Renta become the first and only label to partner with the firm.: 0.2666666666666667,
#  Amazon Web Services (AWS) is a subsidiary of that provides on-demand cloud computing platforms and APIs to individuals, companies, and governments, on a metered pay-as-you-go basis.: 0.47407407407407415,
#  These cloud computing web services provide distributed computing processing capacity and software tools via AWS server farms.: 0.5481481481481483,
#  One of these services is Amazon Elastic Compute Cloud (EC2), which allows users to have at their disposal a virtual cluster of computers, available all the time, through the Internet.: 0.3555555555555555,
#  AWS's virtual computers emulate most of the attributes of a real computer, including hardware central processing units (CPUs) and graphics processing units (GPUs) for processing; local/RAM memory; hard-disk/SSD storage; a choice of operating systems; networking; and pre-loaded application software such as web servers, databases, and customer relationship management (CRM).AWS services are delivered to customers via a network of AWS server farms located throughout the world.: 1.0222222222222224,
#  Fees are based on a combination of usage (known as a "Pay-as-you-go" model), hardware, operating system, software, or networking features chosen by the subscriber required availability, redundancy, security, and service options.: 0.5703703703703704,
#  Subscribers can pay for a single virtual AWS computer, a dedicated physical computer, or clusters of either.: 0.3037037037037037,
#  Amazon provides select portions of security for subscribers (e.g. physical security of the data centers) while other aspects of security are the responsibility of the subscriber (e.g. account management, vulnerability scanning, patching).: 0.5185185185185186,
#  AWS operates from many global geographical regions including 6 in North America.: 0.11851851851851851,
#  Amazon markets AWS to subscribers as a way of obtaining large-scale computing capacity more quickly and cheaply than building an actual physical server farm.: 0.3555555555555556,
#  All services are billed based on usage, but each service measures usage in varying ways.: 0.362962962962963,
#  As of 2021 Q4, AWS has 33% market share for cloud infrastructure while the next two competitors Microsoft Azure and Google Cloud have 21%, and 10% respectively, according to Synergy Group.: 0.33333333333333337,
#  Amazon has a number of products and services available, including its digital assistant Alexa, Amazon Music and Prime Video for music and videos respectively, the Amazon Appstore for Android apps, and its Kindle hardware line of e-readers and tablets.: 0.6592592592592594,
#  Audible provides audiobooks for purchase and listening.: 0.07407407407407408,
#  In September 2021, Amazon announced the launch of Astro, its first household robot, powered by its Alexa smart home technology.: 0.2518518518518519,
#  This can be remote-controlled when not at home, to check on pets, people, or home security.: 0.1851851851851852,
#  It will send owners a notification if it detects something unusual.: 0.037037037037037035,
#  Amazon uses many different transportation services to deliver packages.: 0.17777777777777778,
#  Amazon-branded services include:Amazon directly employs people to work at its warehouses, bulk distribution centers, staffed "Amazon Hub Locker+" locations, and delivery stations where drivers pick up packages.: 0.5037037037037038,
#  As of December 2020, it is not hiring delivery drivers as employees.: 0.19999999999999998,
#  Rakuten Intelligence estimated that in 2020 in the United States, the proportion of last-mile deliveries was 56% by Amazon's directly contracted services (mostly in urban areas), 30% by the U.S. Postal Service (mostly in rural areas), and 14% by UPS.: 0.5333333333333334,
#  In April 2021, Amazon reported to investors it had increased its in-house delivery capacity by 50% in the last 12 months (which included the first year of the COVID-19 pandemic in the United States).Amazon first launched its distribution network in 1997 with two fulfillment centers in Seattle and New Castle, Delaware.: 0.6444444444444446,
#  Amazon has several types of distribution facilities consisting of cross-dock centers, fulfillment centers, sortation centers, delivery stations, Prime now hubs, and Prime air hubs.: 0.47407407407407415,
#  There are 75 fulfillment centers and 25 sortation centers with over 125,000 employees.: 0.2740740740740741,
#  Employees are responsible for five basic tasks: unpacking and inspecting incoming goods; placing goods in storage and recording their location; picking goods from their computer recorded locations to make up an individual shipment; sorting and packing orders; and shipping.: 0.540740740740741,
#  A computer that records the location of goods and maps out routes for pickers plays a key role: employees carry hand-held computers which communicate with the central computer and monitor their rate of progress.: 0.3925925925925927,
#  Some warehouses are partially automated with systems built by Amazon Robotics.: 0.05925925925925926,
#  In September 2006, Amazon launched a program called FBA (Fulfillment By Amazon) whereby it could handle storage, packing and distribution of products and services for small sellers.Amazon.fr fulfillment center in Lauwin-Planque, FranceAmazon.es fulfillment center in San Fernando de Henares, SpainAmazon.co.uk fulfillment center in Glenrothes, Scotland, UKAmazon.de fulfillment center in Graben, GermanyAmazon.co.jp fulfillment center in Ichikawa, JapanAmazon fulfillment center in Macon, Georgia, U.S.During his tenure, Jeff Bezos had become renowned for his annual shareholder letters, which have gained similar notability to those of Warren Buffett.: 1.548148148148148,
#  These annual letters gave an "invaluable window" into the famously "secretive" company, and revealed Bezos's perspectives and strategic focus.: 0.2592592592592593,
#  A common theme of these letters is Bezos's desire to instill customer-centricity (in his words, "customer obsession") at all levels of Amazon, notably by making all senior executives field customer support queries for a short time at Amazon call centers.: 0.41481481481481486,
#  He also read many emails addressed by customers to his public email address.: 0.13333333333333333,
#  One of Bezos's most well-known internal memos was his mandate for "all teams" to "expose their data and functionality" through service interfaces "designed from the ground up to be externalizable".: 0.3407407407407408,
#  This process, commonly known as a service-oriented architecture (SOA), resulted in mandatory dogfooding of services that would later be commercialized as part of AWS.As of June 2022[update], Amazon's board of directors were:Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products.: 1.5703703703703702,
#  As of 2018[update], Amazon.com is ranked 8th on the Fortune 500 rankings of the largest United States corporations by total revenue.: 0.14814814814814814,
#  For the fiscal year 2021, Amazon reported earnings of US$33.36 billion, with an annual revenue of US$469.82 billion, an increase of 21.7% over the previous fiscal cycle.: 0.7111111111111111,
#  Since 2007 sales increased from 14.835 billion to 469.822 billion, due to continued business expansion.: 0.6666666666666666,
#  Amazon's market capitalization went over US$1 trillion again in early February 2020 after the announcement of the fourth quarter 2019 results.: 0.4370370370370371,
#  Amazon owns over 40 subsidiaries, including Amazon Web Services, Audible, Diapers.com, Goodreads, IMDb, Kiva Systems (now Amazon Robotics), Shopbop, Teachstreet, Twitch, Zappos, and Zoox.: 0.2962962962962963,
#  Goodreads is a "social cataloging" website founded in December 2006 and launched in January 2007 by Otis Chandler, a software engineer, and entrepreneur, and Elizabeth Khuri.: 0.3333333333333333,
#  The website allows individuals to freely search Goodreads' extensive user-populated database of books, annotations, and reviews.: 0.3407407407407408,
#  Users can sign up and register books to generate library catalogs and reading lists.: 0.18518518518518523,
#  They can also create their groups of book suggestions and discussions.: 0.05925925925925926,
#  In December 2007, the site had over 650,000 members, and over a million books had been added.: 0.2518518518518519,
#  Amazon bought the company in March 2013.Kuiper Systems LLC, is a subsidiary of Amazon, set up to deploy a broadband satellite internet constellation with an announced 3,236 Low Earth orbit satellites to provide satellite based Internet connectivity.: 0.4296296296296297,
#  Ring is a home automation company founded by Jamie Siminoff in 2013.: 0.2296296296296296,
#  It is primarily known for its WiFi powered smart doorbells, but manufactures other devices such as security cameras.: 0.20000000000000004,
#  Amazon bought Ring for US$1 billion in 2018.Twitch is a live streaming platform for video, primarily oriented towards video gaming content.: 0.5407407407407407,
#  The service was first established as a spin-off of a general-interest streaming service known as Justin.tv.: 0.45185185185185184,
#  Its prominence was eclipsed by that of Twitch, and Justin.tv was eventually shut down by its parent company in August 2014 in order to focus exclusively on Twitch.: 0.25925925925925924,
#  Later that month, Twitch was acquired by Amazon for $970 million.: 0.3037037037037037,
#  Through Twitch, Amazon also owns Curse, Inc., an operator of video gaming communities and a provider of VoIP services for gaming.: 0.22962962962962963,
#  Since the acquisition, Twitch began to sell games directly through the platform, and began offering special features for Amazon Prime subscribers.: 0.3333333333333333,
#  The site's rapid growth had been boosted primarily by the prominence of major esports competitions on the service, leading GameSpot senior esports editor Rod Breslau to have described the service as "the ESPN of esports".: 0.525925925925926,
#  As of 2015[update], the service had over 1.5 million broadcasters and 100 million monthly viewers.: 0.6814814814814816,
#  On August 10, 2020, Amazon announced the rebranding of Twitch Prime, the live-streaming site, renaming it Prime Gaming in another attempt to crack the video game market after failing a big-budget game effort.: 0.4666666666666668,
#  With Twitch Prime, users will be given a free subscription to Twitch, with free games from small studios and discounts for larger titles like Grand Theft Auto and League of Legends.: 0.2518518518518519,
#  On November 2, 2020, Twitch announced a virtual flagship conference and named it GlitchCon instead of TwitchCon to be held on November 14.: 0.28148148148148155,
#  The main aim of the conference will be to bring its numerous, disparate communities of streamers and fans together where they can be real-life confidants.: 0.1185185185185185,
#  Whole Foods Market is an American supermarket chain exclusively featuring foods without artificial preservatives, colors, flavors, sweeteners, and hydrogenated fats.: 0.17037037037037042,
#  Amazon acquired Whole Foods for $13.7 billion in August 2017.Other Amazon subsidiaries include:Amazon also has investments in renewable energy and plans to expand its position into the Canadian market through an investment in a new plant in Alberta.: 0.33333333333333337,
#  Amazon lobbies the United States federal government and state governments on multiple issues such as the enforcement of sales taxes on online sales, transportation safety, privacy and data protection and intellectual property.: 0.5851851851851853,
#  According to regulatory filings, Amazon.com focuses its lobbying on the United States Congress, the Federal Communications Commission and the Federal Reserve.: 0.12592592592592594,
#  Amazon.com spent roughly $3.5 million, $5 million and $9.5 million on lobbying, in 2013, 2014 and 2015, respectively.Amazon.com was a corporate member of the American Legislative Exchange Council (ALEC) until it dropped membership following protests at its shareholders' meeting on May 24, 2012.In 2014, Amazon expanded its lobbying practices as it prepared to lobby the Federal Aviation Administration to approve its drone delivery program, hiring the Akin Gump Strauss Hauer & Feld lobbying firm in June.: 1.281481481481481,
#  Amazon and its lobbyists have visited with Federal Aviation Administration officials and aviation committees in Washington, D.C. to explain its plans to deliver packages.: 0.16296296296296295,
#  In September 2020 this moved one step closer with the granting of a critical certificate by the FAA.In 2019, it spent $16.8m and had a team of 104 lobbyists, up from $14.4m and 103 lobbyists in 2018.Amazon has attracted criticism for its actions, including: supplying law enforcement with facial recognition surveillance tools; forming cloud computing partnerships with the CIA; leading customers away from bookshops; adversely impacting the environment; placing a low priority on warehouse conditions for workers; actively opposing unionization efforts; remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its 1-Click technology; engaging in anti-competitive actions and price discrimination; and reclassifying LGBT books as adult content.: 1.4592592592592586,
#  Criticism has also concerned various decisions over whether to censor or publish content such as the WikiLeaks website, works containing libel and material facilitating dogfight, cockfight, or pedophile activities.: 0.25185185185185194,
#  In December 2011, Amazon faced a backlash from small businesses for running a one-day deal to promote its new Price Check app.: 0.22962962962962963,
#  Shoppers who used the app to check prices in a brick-and-mortar store were offered a 5% discount to purchase the same item from Amazon.: 0.21481481481481482,
#  Companies like Groupon, eBay and Taap.it countered Amazon's promotion by offering $10 off from their products.: 0.3259259259259259,
#  The company has also faced accusations of putting undue pressure on suppliers to maintain and extend its profitability.: 0.20740740740740748,
#  One effort to squeeze the most vulnerable book publishers was known within the company as the Gazelle Project, after Bezos suggested, according to Brad Stone, "that Amazon should approach these small publishers the way a cheetah would pursue a sickly gazelle.": 0.46666666666666673,
#  In July 2014, the Federal Trade Commission launched a lawsuit against the company alleging it was promoting in-app purchases to children, which were being transacted without parental consent.: 0.34814814814814815,
#  In 2019, Amazon banned selling skin-lightening and racist products that might affect the consumer's health.: 0.3777777777777778,
#  In 2022, a lawsuit filed by state attorney-general Letitia James was dismissed by the New York state court of appeals.: 0.2}

# %% [markdown]
# ### Step 3: Summarization

# %%
# Calculating 30% of the total number of sentences
select_length = int(len(sentence_tokens) * 0.3)
select_length
# Out:
# 52

# %%
from heapq import nlargest

# %%
summary = nlargest(select_length, sentence_scores, key = sentence_scores.get)
final_summary = [word.text for word in summary]
final_text = " ".join(final_summary)
final_text
# Out:
# 'Andy Jassy, previously CEO of AWS, became Amazon\'s CEO.Amazon.com is an ecommerce platform that sells many product lines, include media (books, movies, music, and software), apparel, baby products, consumer electronics, beauty products, gourmet food, groceries, health and personal care products, industrial & scientific supplies, kitchen items, jewelry, watches, lawn and garden items, musical instruments, sporting goods, tools, automotive items, toys and games, and farm supplies and consulting services. This process, commonly known as a service-oriented architecture (SOA), resulted in mandatory dogfooding of services that would later be commercialized as part of AWS.As of June\xa02022[update], Amazon\'s board of directors were:Amazon.com is primarily a retail site with a sales revenue model; Amazon takes a small percentage of the sale price of each item that is sold through its website while also allowing companies to advertise their products by paying to be listed as featured products. In September 2006, Amazon launched a program called FBA (Fulfillment By Amazon) whereby it could handle storage, packing and distribution of products and services for small sellers.Amazon.fr fulfillment center in Lauwin-Planque, FranceAmazon.es fulfillment center in San Fernando de Henares, SpainAmazon.co.uk fulfillment center in Glenrothes, Scotland, UKAmazon.de fulfillment center in Graben, GermanyAmazon.co.jp fulfillment center in Ichikawa, JapanAmazon fulfillment center in Macon, Georgia, U.S.During his tenure, Jeff Bezos had become renowned for his annual shareholder letters, which have gained similar notability to those of Warren Buffett. In September 2020 this moved one step closer with the granting of a critical certificate by the FAA.In 2019, it\xa0spent $16.8m and had a team of 104 lobbyists, up from $14.4m and 103 lobbyists in 2018.Amazon has attracted criticism for its actions, including: supplying law enforcement with facial recognition surveillance tools; forming cloud computing partnerships with the CIA; leading customers away from bookshops; adversely impacting the environment; placing a low priority on warehouse conditions for workers; actively opposing unionization efforts; remotely deleting content purchased by Amazon Kindle users; taking public subsidies; seeking to patent its 1-Click technology; engaging in anti-competitive actions and price discrimination; and reclassifying LGBT books as adult content. Some companies have analyzed Amazon sales data to generate sales estimates based on the ASR, though Amazon states:Please keep in mind that our sales rank figures are simply meant to be a guide of general interest for the customer and not definitive sales information for publishers—we assume you have this information regularly from your distribution sources"Search Inside the Book" is a feature which allows customers to search for keywords in the full text of many books in the catalog. Amazon.com spent roughly $3.5\xa0million, $5\xa0million and $9.5\xa0million on lobbying, in 2013, 2014 and 2015, respectively.Amazon.com was a corporate member of the American Legislative Exchange Council (ALEC) until it dropped membership following protests at its shareholders\' meeting on May 24, 2012.In 2014, Amazon expanded its lobbying practices as it prepared to lobby the Federal Aviation Administration to approve its drone delivery program, hiring the Akin Gump Strauss Hauer & Feld lobbying firm in June. In 2000, U.S. toy retailer Toys "R" Us entered into a 10-year agreement with Amazon, valued at $50\xa0million per year plus a cut of sales, under which Toys "R" Us would be the exclusive supplier of toys and baby products on the service, and the chain\'s website would redirect to Amazon\'s Toys & Games category. In September 2017, Amazon ventured with one of its sellers JV Appario Retail owned by Patni Group which has recorded a total income of US$\u2009104.44\u2009million (₹\u2009759\u2009crore) in financial year 2017–2018.As of October ...

# %%
# original text
doc
# Out:
# Amazon.com, Inc. (/ˈæməzɒn/ AM-ə-zon) is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence. It has been referred to as "one of the most influential economic and cultural forces in the world", and is one of the world's most valuable brands. It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft.Amazon was founded by Jeff Bezos from his garage in Bellevue, Washington, on July 5, 1994. Initially an online marketplace for books, it has expanded into a multitude of product categories, a strategy that has earned it the moniker The Everything Store. It has multiple subsidiaries including Amazon Web Services (cloud computing), Zoox (autonomous vehicles), Kuiper Systems (satellite Internet), and Amazon Lab126 (computer hardware R&D). Its other subsidiaries include Ring, Twitch, IMDb, and Whole Foods Market. Its acquisition of Whole Foods in August 2017 for US$13.4 billion substantially increased its footprint as a physical retailer.Amazon has earned a reputation as a disruptor of well-established industries through technological innovation and "aggressive" reinvestment of profits into capital expenditures. As of 2021, it is the world's largest online retailer and marketplace, smart speaker provider, cloud computing service through AWS, live-streaming service through Twitch, and Internet company as measured by revenue and market share. In 2021, it surpassed Walmart as the world's largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200 million subscribers worldwide. It is the second-largest private employer in the United States.Amazon also distributes a variety of downloadable and streaming content through its Amazon Prime Video, Amazon Music, Twitch, and Audible units. It publishes books through its publishing arm, Amazon Publishing, film and television content through Amazon Studios, and has been the owner of film and television studio Metro-Goldwyn-Mayer since March 2022. It also produces consumer electronics—most notably, Kindle e-readers, Echo devices, Fire tablets, and Fire TVs.Amazon has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior.Amazon was founded in July 1994 by Jeff Bezos, who chose the Seattle area for its abundance of technical talent, as Microsoft was in the area.Amazon went public in May 1997. It began selling music and videos in 1998, and began international operations by acquiring online sellers of books in the United Kingdom and Germany. The following year, it began selling music, video games, consumer electronics, home improvement items, software, games, and toys.In 2002, it launched Amazon Web Services (AWS), which initially focused on providing APIs for web developers to build web applications on top of Amazon's ecommerce platform. In 2004, AWS was expanded to provide website popularity statistics and web crawler data from the Alexa Web Information Service. AWS later shifted toward providing enterprise services with Simple Storage Service (S3) in 2006, and Elastic Compute Cloud (EC2) in 2008, allowing companies to rent data storage and computing power from Amazon. In 2006, Amazon also launched the Fulfillment by Amazon program, which allowed individuals and small companies (called "third-party sellers") to sell products through Amazon's warehouses and fulfillment infrastructure.Amazon purchased the Whole Foods Market supermarket chain in 2017.During the COVID-19 pandemic, Amazon introduced a hazard pay of $2-per-hour, changes to overtime pay, and a policy of unlimited, unpaid time off until April 30, 2020. The hazard pay increase expired in June 2020, and the paid time-off policy in May 2022. Amazon also introduced temporary restrictions on the sale of non-essential goods, and hired 100,000 more staff in the US  ...

# %% [markdown]
# ## **PART 2**
# ### ABSTRACTIVE TEXT SUMMARY USING HUGGING FACE TRANSFORMERS LIBRARY 🤗

# %%
# importing the libraries
from transformers import pipeline

# %%
# pipeline for text summarization
# default model used is sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)

summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)

# %%
# doing text summary using the summarizer pipeline
hf_summary = summarizer(text, max_length = 400, min_length = 100, do_sample = False, truncation = True)

# %%
# Returning the summary text
hf_summary[0]['summary_text']
# Out:
# " Amazon.com, Inc. is an American multinational technology company that focuses on e-commerce, cloud computing, online advertising, digital streaming, and artificial intelligence . It is one of the Big Five American information technology companies, alongside Alphabet, Apple, Meta, and Microsoft . In 2021, it surpassed Walmart as the world's largest retailer outside of China, driven in large part by its paid subscription plan, Amazon Prime, which has over 200 million subscribers worldwide . It has been criticized for customer data collection practices, a toxic work culture, tax avoidance, and anti-competitive behavior ."
